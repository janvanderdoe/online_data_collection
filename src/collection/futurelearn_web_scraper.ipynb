# %% [markdown]
# # Webscraper FutureLearn
# FeatureLearn.com is an online learning platform, offering courses on a variety of subjects. This scraper scrapes all the courses available on futurelearn. The total run time is around an hour and a half.

# %% [markdown]
# ## 1 Importing packages

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import time
import csv

# %% [markdown]
# ## 2 Preparation

# %% [markdown]
# ### 2.1 Getting the categories and category numbers
# Although these could be collected manually too, the category numbers are quite arbitrarly and some are hidden and get redirected to the 'all courses' category. Hence, the category numbers were collected manually.

# %%
categories_numbers = [{'name': 'Business & Management', 'category_number': 8},
 {'name': 'Creative Arts & Media', 'category_number': 9},
 {'name': 'Nature & Environment', 'category_number': 10},
 {'name': 'Politics & Society', 'category_number': 11},
 {'name': 'Literature', 'category_number': 12},
 {'name': 'Healthcare & Medicine', 'category_number': 13},
 {'name': 'Science, Engineering & Maths', 'category_number': 14},
 {'name': 'Law', 'category_number': 15},
 {'name': 'History', 'category_number': 16},
 {'name': 'IT & Computer Science', 'category_number': 17},
 {'name': 'Teaching', 'category_number': 18},
 {'name': 'Language', 'category_number': 19},
 {'name': 'Study Skills', 'category_number': 21},
 {'name': 'Psychology & Mental Health', 'category_number': 22}]

# %% [markdown]
# ### 2.2 Getting the max page number
# To retrieve all the page numbers, we must first determine what the maximum page is per category.

# %%
def look_for_max_page_per_category(categories_numbers):    
    for category_number in categories_numbers:
        url = f"https://www.futurelearn.com/courses?filter_category={category_number['category_number']}&filter_course_type=open&filter_availability=started"
        r = requests.get(url)
        soup = BeautifulSoup(r.text, "html.parser")
        category_number['max_pages'] = int(soup.find('div', class_ = "a-content a-contiguous-top u-centered a-content--tight").find_all('li', class_="pagination-module_item__3XB-l")[-1].text)
        time.sleep(5)
    max_pages_per_category = categories_numbers
    return max_pages_per_category

# %%
max_pages_per_category = look_for_max_page_per_category(categories_numbers)
max_pages_per_category
# Out:
# [{'name': 'Business & Management', 'category_number': 8, 'max_pages': 30},
#  {'name': 'Creative Arts & Media', 'category_number': 9, 'max_pages': 10},
#  {'name': 'Nature & Environment', 'category_number': 10, 'max_pages': 9},
#  {'name': 'Politics & Society', 'category_number': 11, 'max_pages': 11},
#  {'name': 'Literature', 'category_number': 12, 'max_pages': 2},
#  {'name': 'Healthcare & Medicine', 'category_number': 13, 'max_pages': 19},
#  {'name': 'Science, Engineering & Maths',
#   'category_number': 14,
#   'max_pages': 15},
#  {'name': 'Law', 'category_number': 15, 'max_pages': 3},
#  {'name': 'History', 'category_number': 16, 'max_pages': 5},
#  {'name': 'IT & Computer Science', 'category_number': 17, 'max_pages': 16},
#  {'name': 'Teaching', 'category_number': 18, 'max_pages': 13},
#  {'name': 'Language', 'category_number': 19, 'max_pages': 6},
#  {'name': 'Study Skills', 'category_number': 21, 'max_pages': 5},
#  {'name': 'Psychology & Mental Health', 'category_number': 22, 'max_pages': 8}]

# %% [markdown]
# ### 2.3 Make the page urls
# This code does not require a html request since each link is predictable. The resulting dictionary contains the category name, page number and page url.

# %%
 def make_page_urls(max_pages_per_category):   
    page_urls = []
    for category in categories:
        for page in range(1, category['max_pages']+1):
            page_info = {}
            page_info['category'] = category['name']
            page_info['page'] = page
            page_info['page_url'] = f"https://www.futurelearn.com/courses?filter_category={category['category_number']}&filter_course_type=open&filter_availability=started&page={page}#courses-grid-start"
            page_urls.append(page_info)
    return page_urls

# %%
page_urls = make_page_urls(max_pages_per_category)
page_urls
# Out:
# [{'category': 'Business & Management',
#   'page': 1,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 2,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 3,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 4,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 5,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 6,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 7,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=7#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 8,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=8#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 9,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=9#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 10,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=10#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 11,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=11#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 12,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=12#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 13,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=13#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 14,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=14#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 15,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=15#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 16,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=16#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 17,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=17#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 18,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=18#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 19,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=19#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 20,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=20#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 21,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=21#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 22,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=22#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 23,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=23#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 24,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=24#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 25,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=25#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 26,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=26#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 27,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=27#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 28,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=28#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 29,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=29#courses-grid-start'},
#  {'category': 'Business & Management',
#   'page': 30,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=30#courses-grid-start'},
#  {'category': 'Creative Arts & Media',
#   'page': 1,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'},
#  {'category': 'Creative Arts & Media',
#   'page': 2,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'},
#  {'category': 'Creative Arts & Media',
#   'page': 3,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'},
#  {'category': 'Creative Arts & Media',
#   'page': 4,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'},
#  {'category': 'Creative Arts & Media',
#   'page': 5,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'},
#  {'category': 'Creative Arts & Media',
#   'page': 6,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'},
#  {'category': 'Creative Arts & Media',
#   'page': 7,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=7#courses-grid-start'},
#  {'category': 'Creative Arts & Media',
#   'page': 8,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=8#courses-grid-start'},
#  {'category': 'Creative Arts & Media',
#   'page': 9,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=9#courses-grid-start'},
#  {'category': 'Creative Arts & Media',
#   'page': 10,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=10#courses-grid-start'},
#  {'category': 'Nature & Environment',
#   'page': 1,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=10&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'},
#  {'category': 'Nature & Environment',
#   'page': 2,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=10&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'},
#  {'category': 'Nature & Environment',
#   'page': 3,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=10&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'},
#  {'category': 'Nature & Environment',
#   'page': 4,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=10&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'},
#  {'category': 'Nature & Environment',
#   'page': 5,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=10&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'},
#  {'category': 'Nature & Environment',
#   'page': 6,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=10&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'},
#  {'category': 'Nature & Environment',
#   'page': 7,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=10&filter_course_type=open&filter_availability=started&page=7#courses-grid-start'},
#  {'category': 'Nature & Environment',
#   'page': 8,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=10&filter_course_type=open&filter_availability=started&page=8#courses-grid-start'},
#  {'category': 'Nature & Environment',
#   'page': 9,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=10&filter_course_type=open&filter_availability=started&page=9#courses-grid-start'},
#  {'category': 'Politics & Society',
#   'page': 1,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'},
#  {'category': 'Politics & Society',
#   'page': 2,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'},
#  {'category': 'Politics & Society',
#   'page': 3,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'},
#  {'category': 'Politics & Society',
#   'page': 4,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'},
#  {'category': 'Politics & Society',
#   'page': 5,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'},
#  {'category': 'Politics & Society',
#   'page': 6,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'},
#  {'category': 'Politics & Society',
#   'page': 7,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=7#courses-grid-start'},
#  {'category': 'Politics & Society',
#   'page': 8,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=8#courses-grid-start'},
#  {'category': 'Politics & Society',
#   'page': 9,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=9#courses-grid-start'},
#  {'category': 'Politics & Society',
#   'page': 10,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=10#courses-grid-start'},
#  {'category': 'Politics & Society',
#   'page': 11,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=11#courses-grid-start'},
#  {'category': 'Literature',
#   'page': 1,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=12&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'},
#  {'category': 'Literature',
#   'page': 2,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=12&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'},
#  {'category': 'Healthcare & Medicine',
#   'page': 1,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'},
#  {'category': 'Healthcare & Medicine',
#   'page': 2,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'},
#  {'category': 'Healthcare & Medicine',
#   'page': 3,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'},
#  {'category': 'Healthcare & Medicine',
#   'page': 4,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'},
#  {'category': 'Healthcare & Medicine',
#   'page': 5,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'},
#  {'category': 'Healthcare & Medicine',
#   'page': 6,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'},
#  {'category': 'Healthcare & Medicine',
#   'page': 7,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=7#courses-grid-start'},
#  {'category': 'Healthcare & Medicine',
#   'page': 8,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=8#courses-grid-start'},
#  {'category': 'Healthcare & Medicine',
#   'page': 9,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=9#courses-grid-start'},
#  {'category': 'Healthcare & Medicine',
#   'page': 10,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=10#courses-grid-start'},
#  {'category': 'Healthcare & Medicine',
#   'page': 11,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=11#courses-grid-start'},
#  {'category': 'Healthcare & Medicine',
#   'page': 12,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=12#courses-grid-start'},
#  {'category': 'Healthcare & Medicine',
#   'page': 13,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=13#courses-grid-start'},
#  {'category': 'Healthcare & Medicine',
#   'page': 14,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=14#courses-grid-start'},
#  {'category': 'Healthcare & Medicine',
#   'page': 15,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=15#courses-grid-start'},
#  {'category': 'Healthcare & Medicine',
#   'page': 16,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=16#courses-grid-start'},
#  {'category': 'Healthcare & Medicine',
#   'page': 17,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=17#courses-grid-start'},
#  {'category': 'Healthcare & Medicine',
#   'page': 18,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=18#courses-grid-start'},
#  {'category': 'Healthcare & Medicine',
#   'page': 19,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=19#courses-grid-start'},
#  {'category': 'Science, Engineering & Maths',
#   'page': 1,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'},
#  {'category': 'Science, Engineering & Maths',
#   'page': 2,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'},
#  {'category': 'Science, Engineering & Maths',
#   'page': 3,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'},
#  {'category': 'Science, Engineering & Maths',
#   'page': 4,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'},
#  {'category': 'Science, Engineering & Maths',
#   'page': 5,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'},
#  {'category': 'Science, Engineering & Maths',
#   'page': 6,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'},
#  {'category': 'Science, Engineering & Maths',
#   'page': 7,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=7#courses-grid-start'},
#  {'category': 'Science, Engineering & Maths',
#   'page': 8,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=8#courses-grid-start'},
#  {'category': 'Science, Engineering & Maths',
#   'page': 9,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=9#courses-grid-start'},
#  {'category': 'Science, Engineering & Maths',
#   'page': 10,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=10#courses-grid-start'},
#  {'category': 'Science, Engineering & Maths',
#   'page': 11,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=11#courses-grid-start'},
#  {'category': 'Science, Engineering & Maths',
#   'page': 12,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=12#courses-grid-start'},
#  {'category': 'Science, Engineering & Maths',
#   'page': 13,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=13#courses-grid-start'},
#  {'category': 'Science, Engineering & Maths',
#   'page': 14,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=14#courses-grid-start'},
#  {'category': 'Science, Engineering & Maths',
#   'page': 15,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=15#courses-grid-start'},
#  {'category': 'Law',
#   'page': 1,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=15&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'},
#  {'category': 'Law',
#   'page': 2,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=15&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'},
#  {'category': 'Law',
#   'page': 3,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=15&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'},
#  {'category': 'History',
#   'page': 1,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=16&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'},
#  {'category': 'History',
#   'page': 2,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=16&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'},
#  {'category': 'History',
#   'page': 3,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=16&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'},
#  {'category': 'History',
#   'page': 4,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=16&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'},
#  {'category': 'History',
#   'page': 5,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=16&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'},
#  {'category': 'IT & Computer Science',
#   'page': 1,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'},
#  {'category': 'IT & Computer Science',
#   'page': 2,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'},
#  {'category': 'IT & Computer Science',
#   'page': 3,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'},
#  {'category': 'IT & Computer Science',
#   'page': 4,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'},
#  {'category': 'IT & Computer Science',
#   'page': 5,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'},
#  {'category': 'IT & Computer Science',
#   'page': 6,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'},
#  {'category': 'IT & Computer Science',
#   'page': 7,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=7#courses-grid-start'},
#  {'category': 'IT & Computer Science',
#   'page': 8,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=8#courses-grid-start'},
#  {'category': 'IT & Computer Science',
#   'page': 9,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=9#courses-grid-start'},
#  {'category': 'IT & Computer Science',
#   'page': 10,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=10#courses-grid-start'},
#  {'category': 'IT & Computer Science',
#   'page': 11,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=11#courses-grid-start'},
#  {'category': 'IT & Computer Science',
#   'page': 12,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=12#courses-grid-start'},
#  {'category': 'IT & Computer Science',
#   'page': 13,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=13#courses-grid-start'},
#  {'category': 'IT & Computer Science',
#   'page': 14,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=14#courses-grid-start'},
#  {'category': 'IT & Computer Science',
#   'page': 15,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=15#courses-grid-start'},
#  {'category': 'IT & Computer Science',
#   'page': 16,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=16#courses-grid-start'},
#  {'category': 'Teaching',
#   'page': 1,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'},
#  {'category': 'Teaching',
#   'page': 2,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'},
#  {'category': 'Teaching',
#   'page': 3,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'},
#  {'category': 'Teaching',
#   'page': 4,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'},
#  {'category': 'Teaching',
#   'page': 5,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'},
#  {'category': 'Teaching',
#   'page': 6,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'},
#  {'category': 'Teaching',
#   'page': 7,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=7#courses-grid-start'},
#  {'category': 'Teaching',
#   'page': 8,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=8#courses-grid-start'},
#  {'category': 'Teaching',
#   'page': 9,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=9#courses-grid-start'},
#  {'category': 'Teaching',
#   'page': 10,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=10#courses-grid-start'},
#  {'category': 'Teaching',
#   'page': 11,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=11#courses-grid-start'},
#  {'category': 'Teaching',
#   'page': 12,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=12#courses-grid-start'},
#  {'category': 'Language',
#   'page': 1,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=19&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'},
#  {'category': 'Language',
#   'page': 2,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=19&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'},
#  {'category': 'Language',
#   'page': 3,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=19&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'},
#  {'category': 'Language',
#   'page': 4,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=19&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'},
#  {'category': 'Language',
#   'page': 5,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=19&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'},
#  {'category': 'Language',
#   'page': 6,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=19&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'},
#  {'category': 'Study Skills',
#   'page': 1,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=21&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'},
#  {'category': 'Study Skills',
#   'page': 2,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=21&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'},
#  {'category': 'Study Skills',
#   'page': 3,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=21&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'},
#  {'category': 'Study Skills',
#   'page': 4,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=21&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'},
#  {'category': 'Study Skills',
#   'page': 5,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=21&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'},
#  {'category': 'Psychology & Mental Health',
#   'page': 1,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=22&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'},
#  {'category': 'Psychology & Mental Health',
#   'page': 2,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=22&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'},
#  {'category': 'Psychology & Mental Health',
#   'page': 3,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=22&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'},
#  {'category': 'Psychology & Mental Health',
#   'page': 4,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=22&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'},
#  {'category': 'Psychology & Mental Health',
#   'page': 5,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=22&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'},
#  {'category': 'Psychology & Mental Health',
#   'page': 6,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=22&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'},
#  {'category': 'Psychology & Mental Health',
#   'page': 7,
#   'page_url': 'https://www.futurelearn.com/courses?filter_category=22&filter_course_type=open&filter_availability=started&page=7#courses-grid-start'}]

# %% [markdown]
# ### 2.4 Getting the course urls
# Each page contains up to 15 courses. The following code retrieves these data and makes a csv file for later use. *Ik kon niet direct de csv schrijven omdat ik een gekke TypeError kreeg*

# %%
def make_course_urls(page_urls):
    course_urls = []
    #f = open("future_learn_page_urls.csv", "w", encoding = "UTF-8")
    #writer = csv.writer(f, delimiter = ";")
    #writer.writerow(['course_url', 'page', 'category']
    list_of_inaccessible_pages = []                
    for page_url in page_urls:
        try:
            r = requests.get(page_url['page_url'])
            soup = BeautifulSoup(r.text, "html.parser")
            courses = soup.find(class_="cardGrid-wrapper_2TvtF cardGrid-hasSideNav_1sLqj").find_all('div', class_="m-card Container-wrapper_1lZbP Container-grey_1l9VP")
            for course in courses:
                course_url = {}
                course_url['course_url'] = course.find_all('a')[0]['href']
                course_url['page'] = page_url['page']
                course_url['category'] = page_url['category']
                course_urls.append(course_url)
                #writer.writerow([course_url['course_url'], course_url['page'], course_url['category']]
        except:
            list_of_inaccessible_pages.append(page_url)
                
        time.sleep(1)
        print(f"Currently scraping page {page_url}")
    print(list_of_inaccessible_pages)
    print(f"Number of unaccessible pages: {len(list_of_inaccessible_pages)}")
    #f.close()
    return course_urls

# %%
course_urls = make_course_urls(page_urls)
course_urls
# Out:
# Currently scraping page {'category': 'Business & Management', 'page': 1, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 2, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 3, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 4, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 5, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 6, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 7, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=7#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 8, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=8#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 9, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=9#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 10, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=10#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 11, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=11#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 12, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=12#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 13, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=13#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 14, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=14#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 15, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=15#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 16, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=16#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 17, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=17#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 18, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=18#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 19, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=19#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 20, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=20#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 21, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=21#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 22, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=22#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 23, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=23#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 24, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=24#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 25, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=25#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 26, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=26#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 27, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=27#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 28, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=28#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 29, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=29#courses-grid-start'}
# Currently scraping page {'category': 'Business & Management', 'page': 30, 'page_url': 'https://www.futurelearn.com/courses?filter_category=8&filter_course_type=open&filter_availability=started&page=30#courses-grid-start'}
# Currently scraping page {'category': 'Creative Arts & Media', 'page': 1, 'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'}
# Currently scraping page {'category': 'Creative Arts & Media', 'page': 2, 'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'}
# Currently scraping page {'category': 'Creative Arts & Media', 'page': 3, 'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'}
# Currently scraping page {'category': 'Creative Arts & Media', 'page': 4, 'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'}
# Currently scraping page {'category': 'Creative Arts & Media', 'page': 5, 'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'}
# Currently scraping page {'category': 'Creative Arts & Media', 'page': 6, 'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'}
# Currently scraping page {'category': 'Creative Arts & Media', 'page': 7, 'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=7#courses-grid-start'}
# Currently scraping page {'category': 'Creative Arts & Media', 'page': 8, 'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=8#courses-grid-start'}
# Currently scraping page {'category': 'Creative Arts & Media', 'page': 9, 'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=9#courses-grid-start'}
# Currently scraping page {'category': 'Creative Arts & Media', 'page': 10, 'page_url': 'https://www.futurelearn.com/courses?filter_category=9&filter_course_type=open&filter_availability=started&page=10#courses-grid-start'}
# Currently scraping page {'category': 'Nature & Environment', 'page': 1, 'page_url': 'https://www.futurelearn.com/courses?filter_category=10&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'}
# Currently scraping page {'category': 'Nature & Environment', 'page': 2, 'page_url': 'https://www.futurelearn.com/courses?filter_category=10&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'}
# Currently scraping page {'category': 'Nature & Environment', 'page': 3, 'page_url': 'https://www.futurelearn.com/courses?filter_category=10&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'}
# Currently scraping page {'category': 'Nature & Environment', 'page': 4, 'page_url': 'https://www.futurelearn.com/courses?filter_category=10&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'}
# Currently scraping page {'category': 'Nature & Environment', 'page': 5, 'page_url': 'https://www.futurelearn.com/courses?filter_category=10&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'}
# Currently scraping page {'category': 'Nature & Environment', 'page': 6, 'page_url': 'https://www.futurelearn.com/courses?filter_category=10&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'}
# Currently scraping page {'category': 'Nature & Environment', 'page': 7, 'page_url': 'https://www.futurelearn.com/courses?filter_category=10&filter_course_type=open&filter_availability=started&page=7#courses-grid-start'}
# Currently scraping page {'category': 'Nature & Environment', 'page': 8, 'page_url': 'https://www.futurelearn.com/courses?filter_category=10&filter_course_type=open&filter_availability=started&page=8#courses-grid-start'}
# Currently scraping page {'category': 'Nature & Environment', 'page': 9, 'page_url': 'https://www.futurelearn.com/courses?filter_category=10&filter_course_type=open&filter_availability=started&page=9#courses-grid-start'}
# Currently scraping page {'category': 'Politics & Society', 'page': 1, 'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'}
# Currently scraping page {'category': 'Politics & Society', 'page': 2, 'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'}
# Currently scraping page {'category': 'Politics & Society', 'page': 3, 'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'}
# Currently scraping page {'category': 'Politics & Society', 'page': 4, 'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'}
# Currently scraping page {'category': 'Politics & Society', 'page': 5, 'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'}
# Currently scraping page {'category': 'Politics & Society', 'page': 6, 'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'}
# Currently scraping page {'category': 'Politics & Society', 'page': 7, 'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=7#courses-grid-start'}
# Currently scraping page {'category': 'Politics & Society', 'page': 8, 'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=8#courses-grid-start'}
# Currently scraping page {'category': 'Politics & Society', 'page': 9, 'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=9#courses-grid-start'}
# Currently scraping page {'category': 'Politics & Society', 'page': 10, 'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=10#courses-grid-start'}
# Currently scraping page {'category': 'Politics & Society', 'page': 11, 'page_url': 'https://www.futurelearn.com/courses?filter_category=11&filter_course_type=open&filter_availability=started&page=11#courses-grid-start'}
# Currently scraping page {'category': 'Literature', 'page': 1, 'page_url': 'https://www.futurelearn.com/courses?filter_category=12&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'}
# Currently scraping page {'category': 'Literature', 'page': 2, 'page_url': 'https://www.futurelearn.com/courses?filter_category=12&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'}
# Currently scraping page {'category': 'Healthcare & Medicine', 'page': 1, 'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'}
# Currently scraping page {'category': 'Healthcare & Medicine', 'page': 2, 'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'}
# Currently scraping page {'category': 'Healthcare & Medicine', 'page': 3, 'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'}
# Currently scraping page {'category': 'Healthcare & Medicine', 'page': 4, 'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'}
# Currently scraping page {'category': 'Healthcare & Medicine', 'page': 5, 'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'}
# Currently scraping page {'category': 'Healthcare & Medicine', 'page': 6, 'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'}
# Currently scraping page {'category': 'Healthcare & Medicine', 'page': 7, 'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=7#courses-grid-start'}
# Currently scraping page {'category': 'Healthcare & Medicine', 'page': 8, 'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=8#courses-grid-start'}
# Currently scraping page {'category': 'Healthcare & Medicine', 'page': 9, 'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=9#courses-grid-start'}
# Currently scraping page {'category': 'Healthcare & Medicine', 'page': 10, 'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=10#courses-grid-start'}
# Currently scraping page {'category': 'Healthcare & Medicine', 'page': 11, 'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=11#courses-grid-start'}
# Currently scraping page {'category': 'Healthcare & Medicine', 'page': 12, 'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=12#courses-grid-start'}
# Currently scraping page {'category': 'Healthcare & Medicine', 'page': 13, 'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=13#courses-grid-start'}
# Currently scraping page {'category': 'Healthcare & Medicine', 'page': 14, 'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=14#courses-grid-start'}
# Currently scraping page {'category': 'Healthcare & Medicine', 'page': 15, 'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=15#courses-grid-start'}
# Currently scraping page {'category': 'Healthcare & Medicine', 'page': 16, 'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=16#courses-grid-start'}
# Currently scraping page {'category': 'Healthcare & Medicine', 'page': 17, 'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=17#courses-grid-start'}
# Currently scraping page {'category': 'Healthcare & Medicine', 'page': 18, 'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=18#courses-grid-start'}
# Currently scraping page {'category': 'Healthcare & Medicine', 'page': 19, 'page_url': 'https://www.futurelearn.com/courses?filter_category=13&filter_course_type=open&filter_availability=started&page=19#courses-grid-start'}
# Currently scraping page {'category': 'Science, Engineering & Maths', 'page': 1, 'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'}
# Currently scraping page {'category': 'Science, Engineering & Maths', 'page': 2, 'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'}
# Currently scraping page {'category': 'Science, Engineering & Maths', 'page': 3, 'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'}
# Currently scraping page {'category': 'Science, Engineering & Maths', 'page': 4, 'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'}
# Currently scraping page {'category': 'Science, Engineering & Maths', 'page': 5, 'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'}
# Currently scraping page {'category': 'Science, Engineering & Maths', 'page': 6, 'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'}
# Currently scraping page {'category': 'Science, Engineering & Maths', 'page': 7, 'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=7#courses-grid-start'}
# Currently scraping page {'category': 'Science, Engineering & Maths', 'page': 8, 'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=8#courses-grid-start'}
# Currently scraping page {'category': 'Science, Engineering & Maths', 'page': 9, 'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=9#courses-grid-start'}
# Currently scraping page {'category': 'Science, Engineering & Maths', 'page': 10, 'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=10#courses-grid-start'}
# Currently scraping page {'category': 'Science, Engineering & Maths', 'page': 11, 'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=11#courses-grid-start'}
# Currently scraping page {'category': 'Science, Engineering & Maths', 'page': 12, 'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=12#courses-grid-start'}
# Currently scraping page {'category': 'Science, Engineering & Maths', 'page': 13, 'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=13#courses-grid-start'}
# Currently scraping page {'category': 'Science, Engineering & Maths', 'page': 14, 'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=14#courses-grid-start'}
# Currently scraping page {'category': 'Science, Engineering & Maths', 'page': 15, 'page_url': 'https://www.futurelearn.com/courses?filter_category=14&filter_course_type=open&filter_availability=started&page=15#courses-grid-start'}
# Currently scraping page {'category': 'Law', 'page': 1, 'page_url': 'https://www.futurelearn.com/courses?filter_category=15&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'}
# Currently scraping page {'category': 'Law', 'page': 2, 'page_url': 'https://www.futurelearn.com/courses?filter_category=15&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'}
# Currently scraping page {'category': 'Law', 'page': 3, 'page_url': 'https://www.futurelearn.com/courses?filter_category=15&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'}
# Currently scraping page {'category': 'History', 'page': 1, 'page_url': 'https://www.futurelearn.com/courses?filter_category=16&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'}
# Currently scraping page {'category': 'History', 'page': 2, 'page_url': 'https://www.futurelearn.com/courses?filter_category=16&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'}
# Currently scraping page {'category': 'History', 'page': 3, 'page_url': 'https://www.futurelearn.com/courses?filter_category=16&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'}
# Currently scraping page {'category': 'History', 'page': 4, 'page_url': 'https://www.futurelearn.com/courses?filter_category=16&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'}
# Currently scraping page {'category': 'History', 'page': 5, 'page_url': 'https://www.futurelearn.com/courses?filter_category=16&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'}
# Currently scraping page {'category': 'IT & Computer Science', 'page': 1, 'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'}
# Currently scraping page {'category': 'IT & Computer Science', 'page': 2, 'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'}
# Currently scraping page {'category': 'IT & Computer Science', 'page': 3, 'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'}
# Currently scraping page {'category': 'IT & Computer Science', 'page': 4, 'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'}
# Currently scraping page {'category': 'IT & Computer Science', 'page': 5, 'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'}
# Currently scraping page {'category': 'IT & Computer Science', 'page': 6, 'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'}
# Currently scraping page {'category': 'IT & Computer Science', 'page': 7, 'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=7#courses-grid-start'}
# Currently scraping page {'category': 'IT & Computer Science', 'page': 8, 'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=8#courses-grid-start'}
# Currently scraping page {'category': 'IT & Computer Science', 'page': 9, 'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=9#courses-grid-start'}
# Currently scraping page {'category': 'IT & Computer Science', 'page': 10, 'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=10#courses-grid-start'}
# Currently scraping page {'category': 'IT & Computer Science', 'page': 11, 'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=11#courses-grid-start'}
# Currently scraping page {'category': 'IT & Computer Science', 'page': 12, 'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=12#courses-grid-start'}
# Currently scraping page {'category': 'IT & Computer Science', 'page': 13, 'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=13#courses-grid-start'}
# Currently scraping page {'category': 'IT & Computer Science', 'page': 14, 'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=14#courses-grid-start'}
# Currently scraping page {'category': 'IT & Computer Science', 'page': 15, 'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=15#courses-grid-start'}
# Currently scraping page {'category': 'IT & Computer Science', 'page': 16, 'page_url': 'https://www.futurelearn.com/courses?filter_category=17&filter_course_type=open&filter_availability=started&page=16#courses-grid-start'}
# Currently scraping page {'category': 'Teaching', 'page': 1, 'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'}
# Currently scraping page {'category': 'Teaching', 'page': 2, 'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'}
# Currently scraping page {'category': 'Teaching', 'page': 3, 'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'}
# Currently scraping page {'category': 'Teaching', 'page': 4, 'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'}
# Currently scraping page {'category': 'Teaching', 'page': 5, 'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'}
# Currently scraping page {'category': 'Teaching', 'page': 6, 'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'}
# Currently scraping page {'category': 'Teaching', 'page': 7, 'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=7#courses-grid-start'}
# Currently scraping page {'category': 'Teaching', 'page': 8, 'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=8#courses-grid-start'}
# Currently scraping page {'category': 'Teaching', 'page': 9, 'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=9#courses-grid-start'}
# Currently scraping page {'category': 'Teaching', 'page': 10, 'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=10#courses-grid-start'}
# Currently scraping page {'category': 'Teaching', 'page': 11, 'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=11#courses-grid-start'}
# Currently scraping page {'category': 'Teaching', 'page': 12, 'page_url': 'https://www.futurelearn.com/courses?filter_category=18&filter_course_type=open&filter_availability=started&page=12#courses-grid-start'}
# Currently scraping page {'category': 'Language', 'page': 1, 'page_url': 'https://www.futurelearn.com/courses?filter_category=19&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'}
# Currently scraping page {'category': 'Language', 'page': 2, 'page_url': 'https://www.futurelearn.com/courses?filter_category=19&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'}
# Currently scraping page {'category': 'Language', 'page': 3, 'page_url': 'https://www.futurelearn.com/courses?filter_category=19&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'}
# Currently scraping page {'category': 'Language', 'page': 4, 'page_url': 'https://www.futurelearn.com/courses?filter_category=19&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'}
# Currently scraping page {'category': 'Language', 'page': 5, 'page_url': 'https://www.futurelearn.com/courses?filter_category=19&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'}
# Currently scraping page {'category': 'Language', 'page': 6, 'page_url': 'https://www.futurelearn.com/courses?filter_category=19&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'}
# Currently scraping page {'category': 'Study Skills', 'page': 1, 'page_url': 'https://www.futurelearn.com/courses?filter_category=21&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'}
# Currently scraping page {'category': 'Study Skills', 'page': 2, 'page_url': 'https://www.futurelearn.com/courses?filter_category=21&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'}
# Currently scraping page {'category': 'Study Skills', 'page': 3, 'page_url': 'https://www.futurelearn.com/courses?filter_category=21&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'}
# Currently scraping page {'category': 'Study Skills', 'page': 4, 'page_url': 'https://www.futurelearn.com/courses?filter_category=21&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'}
# Currently scraping page {'category': 'Study Skills', 'page': 5, 'page_url': 'https://www.futurelearn.com/courses?filter_category=21&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'}
# Currently scraping page {'category': 'Psychology & Mental Health', 'page': 1, 'page_url': 'https://www.futurelearn.com/courses?filter_category=22&filter_course_type=open&filter_availability=started&page=1#courses-grid-start'}
# Currently scraping page {'category': 'Psychology & Mental Health', 'page': 2, 'page_url': 'https://www.futurelearn.com/courses?filter_category=22&filter_course_type=open&filter_availability=started&page=2#courses-grid-start'}
# Currently scraping page {'category': 'Psychology & Mental Health', 'page': 3, 'page_url': 'https://www.futurelearn.com/courses?filter_category=22&filter_course_type=open&filter_availability=started&page=3#courses-grid-start'}
# Currently scraping page {'category': 'Psychology & Mental Health', 'page': 4, 'page_url': 'https://www.futurelearn.com/courses?filter_category=22&filter_course_type=open&filter_availability=started&page=4#courses-grid-start'}
# Currently scraping page {'category': 'Psychology & Mental Health', 'page': 5, 'page_url': 'https://www.futurelearn.com/courses?filter_category=22&filter_course_type=open&filter_availability=started&page=5#courses-grid-start'}
# Currently scraping page {'category': 'Psychology & Mental Health', 'page': 6, 'page_url': 'https://www.futurelearn.com/courses?filter_category=22&filter_course_type=open&filter_availability=started&page=6#courses-grid-start'}
# Currently scraping page {'category': 'Psychology & Mental Health', 'page': 7, 'page_url': 'https://www.futurelearn.com/courses?filter_category=22&filter_course_type=open&filter_availability=started&page=7#courses-grid-start'}
# [{'course_url': '/courses/sustainable-business',
#   'page': 1,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/omni-channel-retailing',
#   'page': 1,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/introduction-to-digital-marketing-digital-marketing-in-perspective',
#   'page': 1,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/introduction-to-digital-marketing-content-marketing',
#   'page': 1,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/introduction-to-digital-marketing-marketing-channel-objectives',
#   'page': 1,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/introduction-to-digital-marketing-personas-and-user-journeys',
#   'page': 1,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/edward-jenner-programme-course-0-an-introduction-to-personal-development',
#   'page': 1,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/advanced-good-pharmacy-practice-part1',
#   'page': 1,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/social-media-in-healthcare',
#   'page': 1,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/digital-skills-digital-marketing',
#   'page': 1,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/digital-skills-for-work-and-life',
#   'page': 1,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/digital-skills-mobile',
#   'page': 1,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/digital-skills-social-media',
#   'page': 1,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/digital-skills-web-analytics',
#   'page': 1,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/electrification-of-urban-mobility',
#   'page': 1,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/interviews',
#   'page': 1,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/engaging-adult-learners-with-active-learning',
#   'page': 2,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/lead-culturally-diverse-workplaces',
#   'page': 2,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/power-dressing-in-the-zoom-era',
#   'page': 2,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/governance-of-transformation',
#   'page': 2,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/educational-leadership-improving-schools-effective-leadership',
#   'page': 2,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/doing-economics-measuring-inequality',
#   'page': 2,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/conceptual-thinking',
#   'page': 2,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/the-design-thinking-toolbox',
#   'page': 2,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/school-for-change-agents-2',
#   'page': 2,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/innovation-enterprise',
#   'page': 2,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/crisis-leadership-course',
#   'page': 2,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/emotional-intelligence',
#   'page': 2,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/writing-applications',
#   'page': 2,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/competitive-advantage',
#   'page': 2,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/information-technology-ethics',
#   'page': 2,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/inclusive-leadership-and-management-skills',
#   'page': 2,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/investigating-innovation',
#   'page': 3,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/automated-vehicles-a-tool-for-people-centred-planning',
#   'page': 3,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/professional-resilience',
#   'page': 3,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/behavioural-economics-employee-and-customer-behaviour',
#   'page': 3,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/business-ethics',
#   'page': 3,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/cognitive-psychology-employee-and-customer-behaviour',
#   'page': 3,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/communication-and-interpersonal-skills-at-work',
#   'page': 3,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/digital-skills',
#   'page': 3,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/entrepreneurship-idea-to-action',
#   'page': 3,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/essential-skills-for-your-career-development',
#   'page': 3,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/managing-for-innovation',
#   'page': 3,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/fashion-innovation',
#   'page': 3,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/the-worlds-greatest-innovations',
#   'page': 3,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/introduction-to-business-management',
#   'page': 3,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/health-economics-1',
#   'page': 3,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/intercultural-studies-branding-culture',
#   'page': 3,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/social-psychology-employee-and-customer-behaviour',
#   'page': 4,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/starting-a-business-1',
#   'page': 4,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/starting-a-business-2',
#   'page': 4,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/starting-a-business-3',
#   'page': 4,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/starting-a-business-4',
#   'page': 4,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/starting-a-business-5',
#   'page': 4,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/starting-a-business-6',
#   'page': 4,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/business-opportunities-in-additive-manufacturing-applying-business-modelling-to-a-real-company-case',
#   'page': 4,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/create-a-robust-financial-plan-for-your-business',
#   'page': 4,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/create-a-robust-go-to-market-strategy',
#   'page': 4,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/crushing-your-competition',
#   'page': 4,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/essentials-in-arts-fundraising',
#   'page': 4,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/create-a-profitable-pricing-strategy',
#   'page': 4,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/social-entrepreneurship-in-educational-technology-concept-development-prototyping',
#   'page': 4,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/social-entrepreneurship-in-educational-technology-developing-business-plan',
#   'page': 4,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/social-entrepreneurship-in-educational-technology-ideation-market-research',
#   'page': 4,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/sustainable-energy-access-for-communities',
#   'page': 5,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/circular-business-models-for-sustainable-urban-food-systems',
#   'page': 5,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/fundraising-arts-culture',
#   'page': 5,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/intellectual-property-management-food',
#   'page': 5,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/supporting-individuals-with-health-conditions-into-work-delivering-ips',
#   'page': 5,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/intro-xero-online',
#   'page': 5,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/writing-and-editing-drafting',
#   'page': 5,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/writing-and-editing-revising',
#   'page': 5,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/writing-and-editing-structure-and-organization',
#   'page': 5,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/writing-and-editing-word-choice-and-word-order',
#   'page': 5,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/brand-strategy-communication',
#   'page': 5,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/creating-strategies-influencer-marketing',
#   'page': 5,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/extended-reality-creative-communications',
#   'page': 5,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/digital-playground-where-luxury-fashion-is-finding-its-sense-of-humor',
#   'page': 5,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/enabling-community-based-leadership-in-design-sustainable-development-of-historic-faith-buildings',
#   'page': 5,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/fashion-and-gaming-how-luxury-fashion-brands-use-gamification',
#   'page': 5,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/strategic-conversation-design-social-media',
#   'page': 6,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/creating-and-measuring-success-in-ecommerce',
#   'page': 6,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/diversity-through-research',
#   'page': 6,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/appropriation-vs-appreciation',
#   'page': 6,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/groupthink-the-need-for-a-diverse-workplace',
#   'page': 6,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/grow-and-scale-your-ecommerce-business',
#   'page': 6,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/how-to-get-started-in-ecommerce',
#   'page': 6,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/understand-ecommerce-customers-products-propositions',
#   'page': 6,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/service-science-and-sustainability',
#   'page': 6,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/innovation-in-healthcare',
#   'page': 6,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/brand-identity-jonathan-wilson',
#   'page': 6,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/brand-personality-jonathan-wilson',
#   'page': 6,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/brand-purpose-jonathan-wilson',
#   'page': 6,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/ethical-innovator',
#   'page': 6,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/global-shocks',
#   'page': 6,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/introduction-to-data-science-for-business',
#   'page': 6,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/successful-agile-for-digital-teams',
#   'page': 7,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/introduction-artificial-intelligence-tourism',
#   'page': 7,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/an-introduction-to-leading-with-compassion-and-kindness-in-health-and-social-care',
#   'page': 7,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/facebook-marketing',
#   'page': 7,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/finance-for-everyone-smart-tools-for-decision-making',
#   'page': 7,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/ultimate-google-analytics-course-for-beginners',
#   'page': 7,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/introduction-to-data-analytics-with-python',
#   'page': 7,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/human-leadership',
#   'page': 7,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/software-development-basics',
#   'page': 7,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/instagram-essentials-and-content-creation',
#   'page': 7,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/linkedin-marketing-essentials-and-content-creation',
#   'page': 7,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/social-media-strategy-essentials',
#   'page': 7,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/general-data-protection-regulation',
#   'page': 7,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/accounting-for-todays-dynamic-world',
#   'page': 7,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/uva-darden-marketing-analytics',
#   'page': 7,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/mindware-critical-thinking-for-the-information-age',
#   'page': 7,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/fitness-networking',
#   'page': 8,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/client-communities',
#   'page': 8,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/client-orientation',
#   'page': 8,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/fitness-for-older-people',
#   'page': 8,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/mental-health-for-fitness',
#   'page': 8,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/nutritional-advice',
#   'page': 8,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/workplace-health-and-safety-in-a-fitness-setting',
#   'page': 8,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/successful-negotiation',
#   'page': 8,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/the-science-of-success-what-researchers-know-that-you-should-know',
#   'page': 8,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/understanding-fashion-from-business-to-culture',
#   'page': 8,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/business-opportunities-in-additive-manufacturing',
#   'page': 8,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/career-management',
#   'page': 8,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/defi-exploring-decentralised-finance-with-blockchain-technologies',
#   'page': 8,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/unlocking-tourist-destinations',
#   'page': 8,
#   'category': 'Business & Management'},
#  {'course_url': '/courses/research-matters',
#   'page': 8,
#   'category': 'Business & Management'},
# ...
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/digital-wellbeing',
#   'page': 6,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/sport-for-sustainable-development',
#   'page': 6,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/global-disability-research-and-evidence',
#   'page': 6,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/policing-and-protest-in-manchester-the-moss-side-riots',
#   'page': 6,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/suicide-prevention',
#   'page': 6,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/freedom-of-movement-refugees-traffickers-and-smugglers',
#   'page': 7,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/law-and-the-framing-of-migrants-and-migration',
#   'page': 7,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/laws-absence-and-laws-failings',
#   'page': 7,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/global-resource-politics',
#   'page': 7,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/working-supportively-with-refugees',
#   'page': 7,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/black-agency-resistance-and-resilience',
#   'page': 7,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/building-professional-networks',
#   'page': 7,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/professional-etiquette',
#   'page': 7,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/society-and-bioeconomy',
#   'page': 7,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/clean-growth-and-cleaner-cities',
#   'page': 7,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/ethical-cities',
#   'page': 7,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/exploring-mentorship-and-community-change-with-the-compton-cowboys',
#   'page': 7,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/environmental-ethics-scarcity-conflict',
#   'page': 7,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/exploring-intersectionality-and-what-makes-you-unique-with-kiddy-smile',
#   'page': 7,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/politics-of-economics',
#   'page': 7,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/spanish-social-innovation-global-solutions-for-a-sustainable-future',
#   'page': 7,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/quality-of-life-and-public-policy',
#   'page': 8,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/tipping-points-climate-change-and-society',
#   'page': 8,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/us-anti-black-racism',
#   'page': 8,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/art-comes-first-exploring-the-intersection-of-style-and-identity',
#   'page': 8,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/social-change-marketing',
#   'page': 8,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/sustainable-development-humanitarian-action',
#   'page': 8,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/public-financial-management',
#   'page': 8,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/partnering-for-change',
#   'page': 8,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/teaching-black-british-history-a-guide-for-teachers',
#   'page': 8,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/governance-beyond-markets-and-states',
#   'page': 8,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/achieving-sustainable-development',
#   'page': 8,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/exploring-body-neutrality-jameela-jamil',
#   'page': 8,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/interpreting-for-refugees',
#   'page': 8,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/storytelling-for-social-change',
#   'page': 8,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/agriculture-economic-nature',
#   'page': 8,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/sustainability',
#   'page': 8,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/global-studies-cultures-organizations',
#   'page': 9,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/global-studies-risks-threats',
#   'page': 9,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/global-studies-global-exit',
#   'page': 9,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/how-politics-works-from-individual-to-international-scale',
#   'page': 9,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/understanding-politics-and-international-relations',
#   'page': 9,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/humanist-lives',
#   'page': 9,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/introducing-humanism',
#   'page': 9,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/global-tourism-development-trends',
#   'page': 9,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/culture-and-tourism',
#   'page': 9,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/global-prosperity',
#   'page': 9,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/migration-mobilities-bristol-online-short-course-essentials',
#   'page': 9,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/reimagining-education',
#   'page': 9,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/understanding-gender-inequality',
#   'page': 9,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/making-babies',
#   'page': 9,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/biosecurity',
#   'page': 9,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/why-religion-matters',
#   'page': 9,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/a-global-history-of-sex-and-gender',
#   'page': 10,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/who-made-my-clothes',
#   'page': 10,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/womens-rights',
#   'page': 10,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/global-ethics',
#   'page': 10,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/the-european-union-crisis-and-recovery',
#   'page': 10,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/happiness-and-quality-of-life',
#   'page': 10,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/social-innovation-global-solutions-for-a-sustainable-future',
#   'page': 10,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/international-development',
#   'page': 10,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/media-data',
#   'page': 10,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/population-10-billion',
#   'page': 10,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/negotiation-for-women-in-the-workplace',
#   'page': 10,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/anthropology-social-media',
#   'page': 10,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/medical-peace-work-global-health',
#   'page': 10,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/human-rights-and-international-criminal-law',
#   'page': 10,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/inequalities-in-personal-finance',
#   'page': 10,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/designing-a-feminist-chatbot',
#   'page': 10,
#   'category': 'Politics & Society'},
#  {'course_url': '/courses/fairy-tales', 'page': 1, 'category': 'Literature'},
#  {'course_url': '/courses/robert-burns', 'page': 1, 'category': 'Literature'},
#  {'course_url': '/courses/introduction-to-samuel-johnsons-rasselas',
#   'page': 1,
#   'category': 'Literature'},
#  {'course_url': '/courses/how-to-read-a-novel',
#   'page': 1,
#   'category': 'Literature'},
#  {'course_url': '/courses/start-writing-fiction',
#   'page': 1,
#   'category': 'Literature'},
#  {'course_url': '/courses/explore-english-shakespeare',
#   'page': 1,
#   'category': 'Literature'},
#  {'course_url': '/courses/how-to-read-french-poetry',
#   'page': 1,
#   'category': 'Literature'},
#  {'course_url': '/courses/picturebooks', 'page': 1, 'category': 'Literature'},
#  {'course_url': '/courses/screenwriting', 'page': 1, 'category': 'Literature'},
#  {'course_url': '/courses/shakespeares-language',
#   'page': 1,
#   'category': 'Literature'},
#  {'course_url': '/courses/how-to-read-a-poem-york',
#   'page': 1,
#   'category': 'Literature'},
#  {'course_url': '/courses/pictures-of-youth-introduction-childrens-visual-culture',
#   'page': 1,
#   'category': 'Literature'},
#  {'course_url': '/courses/reading-digital',
#   'page': 1,
#   'category': 'Literature'},
#  {'course_url': '/courses/japanese-book-paper',
#   'page': 1,
#   'category': 'Literature'},
#  {'course_url': '/courses/country-house-literature',
#   'page': 1,
#   'category': 'Literature'},
#  {'course_url': '/courses/shakespeare-context-and-stagecraft',
#   'page': 1,
#   'category': 'Literature'},
#  {'course_url': '/courses/william-wordsworth',
#   'page': 2,
#   'category': 'Literature'},
#  {'course_url': '/courses/japanese-rare-books-sino',
#   'page': 2,
#   'category': 'Literature'},
#  {'course_url': '/courses/what-is-korean-philosophy',
#   'page': 2,
#   'category': 'Literature'},
#  {'course_url': '/courses/book-of-kells', 'page': 2, 'category': 'Literature'},
#  {'course_url': '/courses/shakespeare', 'page': 2, 'category': 'Literature'},
#  {'course_url': '/courses/japanese-rare-books-culture',
#   'page': 2,
#   'category': 'Literature'},
#  {'course_url': '/courses/cbt-older-people',
#   'page': 1,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/cancer-survivorship',
#   'page': 1,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/remote-and-triage-consultations',
#   'page': 1,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/complex-healthcare-interventions',
#   'page': 1,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/edward-jenner-programme-course-0-an-introduction-to-personal-development',
#   'page': 1,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/principles-of-evidence-based-medicine-in-clinical-pharmacy',
#   'page': 1,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/fam-pregnancy',
#   'page': 1,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/good-pharmacy-practice-the-moderate-part2',
#   'page': 1,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/good-pharmacy-practice-the-moderate',
#   'page': 1,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/advanced-good-pharmacy-practice-part1',
#   'page': 1,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/advanced-good-pharmacy-practice-part2',
#   'page': 1,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/nutrition-food-safety',
#   'page': 1,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/translational-research',
#   'page': 1,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/medical-humanity',
#   'page': 1,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/nutrition-disease-prevention',
#   'page': 1,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/eating-while-enjoying-life',
#   'page': 1,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/pharmacokinetics-and-dosing-regimen-in-renal-disease',
#   'page': 2,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/social-media-in-healthcare',
#   'page': 2,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/tools-to-support-growth-disorders-through-telemedicine-in-post-covid-era',
#   'page': 2,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/clinical-supervision-with-confidence',
#   'page': 2,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/african-contributions-to-global-health',
#   'page': 2,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/anatomy',
#   'page': 2,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/food-and-mood',
#   'page': 2,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/food-choice-and-behaviour',
#   'page': 2,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/lifestyle-medicine',
#   'page': 2,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/obesity-and-healthy-weight-loss',
#   'page': 2,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/peak-spanish',
#   'page': 2,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/transgender-in-healthcare',
#   'page': 2,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/infection-control-antimicrobial-resistance',
#   'page': 2,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/what-drives-the-body',
#   'page': 2,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/ai-and-big-data-global-health-improvement',
#   'page': 2,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/agriculture-and-nutrition',
#   'page': 2,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/consciousness',
#   'page': 3,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/artificial-intelligence-for-healthcare-opportunities-and-challenges',
#   'page': 3,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/pharmacy-preceptor',
#   'page': 3,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/health-promotion',
#   'page': 3,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/clinical-pharmacokinetic',
#   'page': 3,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/digital-cancer-management',
#   'page': 3,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/good-pharmacy-practice',
#   'page': 3,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/statistical-shape-modelling',
#   'page': 3,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/urban-mobility-for-liveability',
#   'page': 3,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/cbt-for-back-pain',
#   'page': 3,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/end-of-life-care',
#   'page': 3,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/prevention-of-shoulder-problems-prosper-programme',
#   'page': 3,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/school-for-change-agents-2',
#   'page': 3,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/exploring-the-landscape-of-antibiotic-resistance-in-microbiomes',
#   'page': 3,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/the-body-and-dna',
#   'page': 3,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/train-the-healthcare-trainer',
#   'page': 3,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/airway-matters',
#   'page': 4,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/older-people',
#   'page': 4,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/dementia-inclusive-hospitals-from-a-universal-design-approach',
#   'page': 4,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/digital-clinical-trials',
#   'page': 4,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/infant-nutrition',
#   'page': 4,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/introduction-to-anatomy',
#   'page': 4,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/randomised-controlled-trials',
#   'page': 4,
#   'category': 'Healthcare & Medicine'},
#  {'course_url': '/courses/neurological-disorders-east-anglia',
#   'page': 4,
#   'category': 'Healthcare & Medicine'},
#  ...]

# %%
with open("../../gen/input/futurelearn_course_urls.csv", "w", encoding = "UTF-8") as csv_file:
    writer = csv.writer(csv_file, delimiter = ";")
    writer.writerow(['course_url', 'page', 'category'])
    for course_url in course_urls:
        writer.writerow([course_url['course_url'], course_url['page'], course_url['category']])

# %% [markdown]
# ## 3 Data Collection

# %% [markdown]
# ### 3.1 Getting the course info
# The following function retrieves the following data on each page:
# - Url: The complete url of the course
# - Time: The exact time the data were scraped
# - Page: The page from the category
# - Header: The header of the course
# - Enrollment: The number of enrollments of the course. Note that new courses do not have the information yet
# - New: Dummy showing whether the course is new
# - Review_count: Variable showing how many reviews there are
# - Description: Short description of the course
# - Duration: Duration of the course in weeks
# - Weekly_study: Study time required on a weekly bases
# - Unlimited: Dummy showing whether you can access this course with a so-called "unlimited" subscription. Not_present means that's not the case
# - 100_online: Dummy showing whether the course is for 100% online
# - Free: Dummy showing whether the course is for free. Not_present meaning it's not free
# - Part_of_expert: Dummy showing whether the course is part of a larger expert course. Not_present means it's not the case
# - Name_school: The name of the school that teaches the course
# - Endorsed: Dummy showing whether the course is endorsed by third parties.
#
# Although the course page contained more information (e.g. in-depth course descriptions, numerous teachers), the variables above are relevant for an analysis. The sleep time is 1 second per retrieval

# %%
def get_course_info(course_url):
    course_info = {}
    complete_url = f"https://www.futurelearn.com{course_url['course_url']}"
    r = requests.get(complete_url)
    soup = BeautifulSoup(r.text, "html.parser")
    
    #META-DATA
    ##url
    course_info['url'] = complete_url
    
    ##time
    course_info['Time'] = datetime.now()
    
    ##page
    course_info['page'] = course_url['page']
    
    ##category
    course_info['category'] = course_url['category']
    
    #HEADER
    try:
        course_info['Header'] = soup.find('h1').text
    except:
        course_info['Header'] = ''
        
    #NUMBER OF ENROLLMENTS
    try:
        course_info['Enrollments'] = soup.find('div', class_="spacer-module_default__3N2H9 spacer-module_vertical-4__5ZLo8").find('p', class_ = "text-module_wrapper__FfvIV text-module_black__2u5Rt text-module_sBreakpointSizexsmall__2Jlmd text-module_sBreakpointAlignmentleft__1MvbB text-module_isRegular__1K97K").text
    except:
        course_info['Enrollments'] = ''
    
    #NEW COURSE
    try:
        if soup.find('span', class_ = "Ribbon-module_wrapper__312EV Ribbon-module_coral__B1J53 Ribbon-module_isUppercase__1NTSw").text == 'New':
            course_info['New'] = 'yes'
        else:
            course_info['New'] = 'no' 
    except:
        course_info['New'] = 'no'

    #STAR RATING
    try:
        course_info['star_rating'] = soup.find(class_="spacer-module_default__3N2H9 spacer-module_left-1__1AJxh").text.split()[0]
    except:
        course_info['star_rating'] = ''
    
    #NUM OF REVIEWS
    try:
        course_info['review_count'] = soup.find('div', class_="ReviewStars-text_mSEFD").find('span').text
    except:
        course_info['review_count'] = ''
        
    #DESCRIPTION
    try:
        course_info['description'] = soup.find('div', class_ = "stack-module_wrapper__3ZERF").find(class_="text-module_wrapper__FfvIV text-module_black__2u5Rt text-module_sBreakpointSizemedium__2qitW text-module_mBreakpointSizemedium__1_OnK text-module_lBreakpointSizemedium__1Yq39 text-module_xlBreakpointSizemedium__1nNCx text-module_xxlBreakpointSizelarge__1uhrp text-module_sBreakpointAlignmentleft__1MvbB text-module_isRegular__1K97K").text
    except:
        course_info['description'] = ''
    
    #INFO COURSE
    try:
        for li in soup.find('div', class_ = "PageHeader-keyInfoWrapper_39HpT").find_all(class_="keyInfo-module_itemText__3w63w"):
            ## Top part of cell
            table_header = li.find(class_ = "text-module_wrapper__FfvIV text-module_mediumGrey__1uvOt text-module_sBreakpointSizesmall__3K4b4 text-module_sBreakpointAlignmentleft__1MvbB text-module_isInline__m5cFK text-module_isRegular__1K97K").text
            ## Lower part of cell
            table_text = li.find(class_ = "keyInfo-module_content__1K_85").text
            if table_header == 'Duration':
                course_info['Duration'] = table_text
            if table_header == 'Weekly study':
                course_info['Weekly_study'] = table_text
            if table_header == 'Unlimited':
                course_info['Unlimited'] = 'yes'
            if table_header == '100% online':
                course_info['100_online'] = 'yes'
            if table_header == 'Digital upgrade':
                course_info['Free'] = 'yes'
            if table_header == 'Accreditation':
                course_info['Accreditation'] = table_text
            if table_header == "Included in an ExpertTrack":
                course_info['Part_of_Expert'] = 'yes'
        table_headers_options = ['Duration', 'Weekly_study', 'Unlimited', '100_online', 'Free', 'Accreditation', 'Part_of_Expert']
        ##Looks whether a cell is missing
        for table_headers_option in table_headers_options:
            if table_headers_option not in course_info:
                course_info[table_headers_option] = 'Not_present'
    ##If there's an error in loading the table, place empty values
    except:
        for table_headers_option in table_headers_options:
            course_info[table_headers_option] = ''
    
    #NAME SCHOOL
    try:
        course_info['Name_school'] = soup.find('h2', class_="heading-module_wrapper__2dcxt heading-module_sBreakpointAlignmentleft__pCA_Y heading-module_sBreakpointSizelarge__SiUxO heading-module_black__Uge9G heading-module_isRegular__2NZyV").text
    except:
        course_info['Name_school'] = ''
    print(f"Currently scraping: {course_info['Header']}")
    
    #ENDORSERS (Check how often present)
    try:
        if soup.find('h2', class_ = "heading-module_wrapper__2dcxt heading-module_sBreakpointAlignmentcenter__2R3nG heading-module_sBreakpointSizelarge__SiUxO heading-module_black__Uge9G heading-module_isRegular__2NZyV").text == 'Endorsers and supporters':
            course_info['Endorsed'] = 'yes'
        else:
            course_info['Endorsed'] = 'no'
    except:
        course_info['Endorsed'] = 'no'
    time.sleep(1)
    return course_info

# %% [markdown]
# ### 3.2 Scraping each course page and saving it in csv
# The following code uses the function above to retrieve the relevant data of each page and stores it into a csv file. Note the delimiter is a ';'. The length of the list of inaccessable courses was 0 during the last run. It took 1 hour and 7 minutes to complete.

# %%
def write_data(course_urls):
    courses_info = []
    list_of_inaccessable_courses = []
    counter = 1
    with open("../../gen/output/futurelearn_data.csv", "w", encoding = "UTF-8") as csv_file:
        writer = csv.writer(csv_file, delimiter = ";")
        writer.writerow(['Url', 'Time', 'Page', 'Category', 'Header', 'Enrollments', 'New', 'Star_rating', 'Review_count', 'Description', 'Duration', 'Weekly_study', 'Unlimited', '100_online', 'Free', 'Accreditation', 'Part_of_Expert', 'Name_school', 'Endorsed'])
        for course_url in course_urls:
            try:
                course_info = get_course_info(course_url)
                courses_info.append(course_info)
                writer.writerow([course_info['url'], course_info['Time'], course_info['page'], course_info['category'], course_info['Header'], course_info['Enrollments'], course_info['New'], course_info['star_rating'], course_info['review_count'], course_info['description'], course_info['Duration'], course_info['Weekly_study'], course_info['Unlimited'], course_info['100_online'], course_info['Free'], course_info['Accreditation'], course_info['Part_of_Expert'], course_info['Name_school'], course_info['Endorsed']])
            except:
                list_of_inaccessable_courses.append(course_url)
            print(f'Processing... [{counter}/{len(course_urls)}]')
            counter += 1
    print(list_of_inaccessable_courses)
    print(f"Couldn't access {len(list_of_inaccessable_courses)} courses")
    return courses_info

# %%
start_time = datetime.now()
data = write_data(course_urls)
end_time = datetime.now()
print("Time it took to scrape: " + str(end_time - start_time))
# Out:
# Currently scraping: Business Futures: Sustainable Business Through Green HR
# Currently scraping: Business Futures: Understanding Omni-channel Retailing and Supply Chains
# Currently scraping: Digital Marketing in Perspective
# Currently scraping: Digital Marketing: Content Marketing
# Currently scraping: Digital Marketing: Marketing Channel Objectives
# Currently scraping: Digital Marketing: Personas and User Journeys
# Currently scraping: Edward Jenner: 0 - An Introduction to Personal Development
# Currently scraping: Good Pharmacy Practice: Medication Management
# Currently scraping: Social Media in Healthcare: Opportunities and Challenges
# Currently scraping: Digital Skills: Digital Marketing
# Currently scraping: Digital Skills: Digital Skills for Work and Life
# Currently scraping: Digital Skills: Mobile
# Currently scraping: Digital Skills: Social Media
# Currently scraping: Digital Skills: Web Analytics
# Currently scraping: Electrification of Urban Mobility: How to Get it Right
# Currently scraping: How to Succeed at: Interviews
# Currently scraping: Innovative Teaching: Engaging Adult Learners with Active Learning
# Currently scraping: Leading Culturally Diverse Teams in the Workplace
# Currently scraping: Power Dressing in the Zoom Era
# Currently scraping: Transforming Urban Mobility: Governing the Transformation to Sustainable Systems
# Currently scraping: Educational Leadership: Improving Schools through Effective Leadership
# Currently scraping: Measuring Economic Inequality in Today’s World
# Currently scraping: Conceptual Thinking in Practice
# Currently scraping: The Design Thinking Toolbox
# Currently scraping: The School for Change Agents
# Currently scraping: Unleash Your Potential: Innovation and Enterprise
# Currently scraping: Crisis Leadership
# Currently scraping: Emotional Intelligence in Practice
# Currently scraping: How to Succeed at: Writing Applications
# Currently scraping: Competitive Advantage: Using Information to Build Business Success
# Currently scraping: IT Ethics: Professionalism and Ethics in Computing
# Currently scraping: Inclusive Management and Leadership Skills
# Currently scraping: Investigating Innovation
# Currently scraping: Planning for Autonomous Vehicles: A People-Centred Approach
# Currently scraping: Professional Resilience: Building Skills to Thrive at Work
# Currently scraping: Behavioural Economics: Employee and Customer Behaviour
# Currently scraping: Business Ethics: Exploring Big Data and Tax Avoidance
# Currently scraping: Cognitive Psychology: Employee and Customer Behaviour
# Currently scraping: Communication and Interpersonal Skills at Work
# Currently scraping: Digital Skills: Embracing Digital Technology
# Currently scraping: Entrepreneurship: From Business Idea to Action
# Currently scraping: Essential Skills for Your Career Development
# Currently scraping: Innovation Management: Winning in the Age of Disruption
# Currently scraping: Innovation: the Fashion Industry
# Currently scraping: Innovation: the World's Greatest
# Currently scraping: Introduction to Business Management
# Currently scraping: Introduction to Health Economics
# Currently scraping: Introduction to Intercultural Studies: The Branding of Culture
# Currently scraping: Social Psychology: Employee and Customer Behaviour
# Currently scraping: Starting a Business 1: Vision and Opportunity
# Currently scraping: Starting a Business 2: People and Networks
# Currently scraping: Starting a Business 3: Customers and Competitors
# Currently scraping: Starting a Business 4: Business Processes
# Currently scraping: Starting a Business 5: Managing Finances
# Currently scraping: Starting a Business 6: Funding Your Business
# Currently scraping: Business Opportunities in Additive Manufacturing
# Currently scraping: Complete Guide to Financial Planning for Your Business
# Currently scraping: Create a Robust Go to Market Strategy
# Currently scraping: Crushing your Competition: Competitive Strategies to Make your Business Stand Out
# Currently scraping: Essentials in Arts Fundraising
# Currently scraping: How to Create a Profitable Pricing Strategy
# Currently scraping: Social Entrepreneurship in Educational Technology: Concept Development and Prototyping
# Currently scraping: Social Entrepreneurship in Educational Technology: Developing a Business Plan
# Currently scraping: Social Entrepreneurship in Educational Technology: Ideation and Market Research
# Currently scraping: Sustainable Energy Access for Communities
# Currently scraping: Circular Business Models for Sustainable Urban Food Systems
# Currently scraping: Effective Fundraising and Leadership in Arts and Culture
# Currently scraping: Intellectual Property Management in the Food Sector: Safeguarding Your Trademarks in the Global Marketplace
# Currently scraping: Supporting People with Health Conditions Into Work: Individual Placement and Support (IPS)
# Currently scraping: Accounting With Xero: A Beginner’s Guide
# Currently scraping: Writing and Editing: Drafting
# Currently scraping: Writing and Editing: Revising
# Currently scraping: Writing and Editing: Structure and Organisation
# Currently scraping: Writing and Editing: Word Choice and Word Order
# Currently scraping: Brand Strategy and Communication
# Currently scraping: Creating Strategies for Influencer Marketing
# Currently scraping: Creative Communication Beyond VR and AR
# Currently scraping: Digital Playground: Where Luxury Fashion is Finding its Sense of Humour
# Currently scraping: Enabling Community-Based Leadership in Design: Sustainable Development of Historic Faith Buildings
# Currently scraping: Fashion and Gaming: How Luxury Fashion Brands Use Gamification
# Currently scraping: Strategic Design for Social Media
# Currently scraping: Creating and Measuring Success in eCommerce
# Currently scraping: Cultivating Diversity through Research and Insights
# Currently scraping: Cultural Appropriation vs Cultural Appreciation
# Currently scraping: Groupthink: Understanding the Need for a Diverse Workplace
# Currently scraping: Grow and Scale Your eCommerce Business
# Currently scraping: How to Get Started in eCommerce
# Currently scraping: Research and Prepare: Understand eCommerce Customers, Products, and Propositions
# Currently scraping: Service Science and Sustainability
# Currently scraping: An Introduction to Innovation in Healthcare
# Currently scraping: Brand Identity: How Branding Works and Building Your Personal Brand
# Currently scraping: Brand Personality: How to Tell Your Story with Authenticity and Relevance
# Currently scraping: Brand Purpose: Marketing Yourself and Building Meaningful Connections
# Currently scraping: Ethical Practices to Guide Innovation
# Currently scraping: Global Shocks: How to Manage Change in the Global Business Environment
# Currently scraping: Introduction to Data Science for Business
# Currently scraping: Successful Agile for Digital Teams
# Currently scraping: An Introduction to Artificial Intelligence in the Tourism Industry
# Currently scraping: An Introduction to Leading with Kindness and Compassion in Health and Social Care
# Currently scraping: Facebook Marketing: Organic Reach and Paid Advertising
# Currently scraping: Finance for Everyone: Smart Tools for Decision-Making
# Currently scraping: Google Analytics Course: The Ultimate Beginner’s Guide
# Currently scraping: Introduction to Data Analytics with Python
# Currently scraping: Leadership Training: Human Leadership
# Currently scraping: Software Development Basics
# Currently scraping: Instagram Marketing: Instagram Essentials and Content Creation
# Currently scraping: LinkedIn Marketing: LinkedIn Essentials and Content Creation
# Currently scraping: Social Media Marketing Strategy: Objective Setting and Strategic Planning Essentials
# Currently scraping: Understanding the GDPR
# Currently scraping: Accounting for Today’s Dynamic World
# Currently scraping: Marketing Analytics
# Currently scraping: Mindware: Critical Thinking for the Information Age
# Currently scraping: Personal Trainer's Toolkit: Build a Health and Fitness Business Network
# Currently scraping: Personal Trainer's Toolkit: Building a Fitness Community, Client Retention for Trainers
# Currently scraping: Personal Trainer's Toolkit: Client Onboarding and Fitness Testing
# Currently scraping: Personal Trainer's Toolkit: Developing Fitness Programs for Older People
# Currently scraping: Personal Trainer's Toolkit: Mental Health First Aid for Fitness Trainers
# Currently scraping: Personal Trainer's Toolkit: Providing Nutritional Advice to Your Clients
# Currently scraping: Personal Trainer's Toolkit: Workplace Health and Safety in a Fitness Setting
# Currently scraping: Successful Negotiation: Essential Strategies and Skills
# Currently scraping: The Science of Success: What Researchers Know that You Should Know
# Currently scraping: Understanding Fashion: From Business to Culture
# Currently scraping: Additive Manufacturing for Business: Practices and Ecosystem
# Currently scraping: Career Management for Early Career Academic Researchers
# Currently scraping: Decentralised Finance: Blockchain, Ethereum, and The Future of Banking
# Currently scraping: Placemaking and Public Space Design: Unlocking Tourist Destinations
# Currently scraping: Why Research Matters
# Currently scraping: Fundamentals of Digital Marketing
# Currently scraping: Product Management Essentials
# Currently scraping: University and Your Future: Career Planning and Making the Most of Your Degree
# Currently scraping: Doing Business in Conflict Zones
# Currently scraping: Doing Good in a Conflict Zone
# Currently scraping: An Introduction to Financial Management in Construction
# Currently scraping: Career Skills for the 2020s: Navigating the Online World of Work
# Currently scraping: Digital Skills: Reimagine Your Career
# Currently scraping: Emergency Planning and Preparedness: An Introduction
# Currently scraping: Emotional Intelligence at Work
# Currently scraping: Foundations of Project Management
# Currently scraping: Get Started With Digital Marketing
# Currently scraping: International Human Resources Management: An Introduction
# Currently scraping: Introduction to Digital Transformation and E-Commerce
# Currently scraping: Understanding Systems Thinking in Healthcare
# Currently scraping: How to Measure, Reduce, and Offset your Company’s Carbon Footprint
# Currently scraping: Using AI to Gain a Competitive Edge for your Customer Experience (CX)
# Currently scraping: Introduction to Agile Project Management
# Currently scraping: Introduction to Digital Transformation: Understand and Manage Digital Transformation in the Workplace
# Currently scraping: Introduction to HACCP for Food Safety
# Currently scraping: Introduction to UX Design
# Currently scraping: Organising for the Sustainable Development Goals (SDGs)
# Currently scraping: Artificial Intelligence and Machine Learning for Business
# Currently scraping: Drafting and Negotiating Commercial Contracts: A guide to contract law for non-lawyers
# Currently scraping: Principles of Wealth Management
# Currently scraping: Strategic planning for professional service firms in the time of COVID-19
# Currently scraping: The Essential Financial Management Toolbox for Film, Screen and Broadcast
# Currently scraping: UX Design Fundamentals: Business Value Through User Experience (UX) Design
# Currently scraping: UX Design Fundamentals: Creating Business Outcomes
# Currently scraping: UX Design Fundamentals: Delivering Value to Users
# Currently scraping: Collaborative Coding with Git
# Currently scraping: Data Analytics and Python Fundamentals
# Currently scraping: Data Wrangling and Ingestion using Python
# Currently scraping: Design and Create Custom Dashboards in Excel
# Currently scraping: Digital Fashion Media
# Currently scraping: Digital Marketing: Storytelling in the New Communication Landscape
# Currently scraping: Effective Questioning for Call Handlers
# Currently scraping: Ethics and Diversity in Fashion
# Currently scraping: Fashion and Sustainability: Understanding Luxury Fashion in a Changing World
# Currently scraping: How to Use Pivot Tables to Analyse Data in Excel
# Currently scraping: Introduction to Excel Charts for Data Visualisation
# Currently scraping: Leading Strategic Innovation: How to Lead with Purpose
# Currently scraping: Python Packages: NumPy and Pandas Dataframe
# Currently scraping: Social Impact in Business: How to Build a Brand that Matters
# Currently scraping: Sustainable Luxury Fashion
# Currently scraping: The Business of Beauty: Introduction to the Beauty Industry
# Currently scraping: The Future of Fashion
# Currently scraping: The Human Face of User Research: How to do User Research Online and Offline
# Currently scraping: What is Leadership?
# Currently scraping: Data Analysis and Fundamental Statistics
# Currently scraping: Excel for Data Analysis
# Currently scraping: SQL for Data Analysis
# Currently scraping: Data Visualisation: Creating charts and complex visualisations in Tableau
# Currently scraping: Data Visualisation: Data Dashboards and Storytelling with Tableau
# Currently scraping: Data Visualisation: Data Visualisation with Tableau Fundamentals
# Currently scraping: Build a Leading Innovation Strategy
# Currently scraping: Customer Experience Design for Customer Success: CX Impact and Strategic Insights
# Currently scraping: Customer Experience Design for Customer Success: Designing Great Customer Experiences
# Currently scraping: Customer Experience Design for Customer Success: Ensuring Customer Success
# Currently scraping: EFQM Foundation Online Certificate
# Currently scraping: Introduction to Business Improvement: Lean Six Sigma, Kaizen, and Problem Solving
# Currently scraping: Introduction to User Experience Principles and Processes
# Currently scraping: Pathways to Property: Starting Your Career in Real Estate
# Currently scraping: Project Management: Beyond the Basics
# Currently scraping: Sustainability in the New Zealand Wine Industry
# Currently scraping: Demystifying Business Models for New Entrepreneurs
# Currently scraping: Empresas Exponenciales: Guía Para Comenzar
# Currently scraping: Grow Your Workforce: How to Teach Adult Learners
# Currently scraping: Introduction to Organisational Development
# Currently scraping: Workplace Wellbeing: How to Build Confidence and Manage Stress
# Currently scraping: Design Thinking for Sustainable Development
# Currently scraping: Leading Sustainable Communities and Organisations
# Currently scraping: Multiculturalism In ASEAN
# Currently scraping: Drive Business Improvement with the EFQM Model
# Currently scraping: Beauty Decoded: Strategy in the Global Beauty Business
# Currently scraping: Power, Politics, and Influence at Work
# Currently scraping: Communicating with Diverse Audiences
# Currently scraping: Plan for Project Success: Project Planning and Management
# Currently scraping: Responsible Marketing and the Fundamentals of Corporate Social Responsibility
# Currently scraping: Sport for Sustainable Development: Designing Effective Policies and Programmes
# Currently scraping: Digital Product Management
# Currently scraping: Fundamentals of Project Planning and Management
# Currently scraping: Getting Started with Agile and Design Thinking
# Currently scraping: How to Build Your Creative Resilience
# Currently scraping: How to Enhance Your Creative Empathy
# Currently scraping: How to Improve Your Creative Collaboration
# Currently scraping: Building Your Career in Tomorrow’s Workplace
# Currently scraping: Capital: crear un plan para conseguir inversionistas
# Currently scraping: Crecimiento: nunca es temprano para hacer crecer tu negocio
# Currently scraping: Educational Leadership: Working for Good
# Currently scraping: Ejecución: experimentos, recursos y puesta en marcha
# Currently scraping: Excel Skills to Make an Impression
# Currently scraping: Introduction to Studying Business
# Currently scraping: Master Digital Marketing: Introduction to Marketing
# Currently scraping: Master Digital Marketing: Marketing Fundamentals
# Currently scraping: Master Digital Marketing: Marketing Strategy
# Currently scraping: Master Digital Marketing: The Marketing Mix
# Currently scraping: Producto: valida y entrega tu propuesta de valor
# Currently scraping: Visión: la estrategia para alcanzar tu propósito
# Currently scraping: How to Fundraise: A Guide to Fundraising for Non-Fundraisers
# Currently scraping: Awareness and Confidence for Effective Leadership
# Currently scraping: Becoming An Expert Or Practitioner In Wellness
# Currently scraping: Becoming a Team Leader
# Currently scraping: Build Trust and Grow your Self-Confidence
# Currently scraping: Building Effective Professional Networks and Relationships
# Currently scraping: Business Etiquette: Master Communication and Soft Skills
# Currently scraping: Collaborative Working in a Remote Team
# Currently scraping: Collective Resilience: From Group to Team
# Currently scraping: Create a Professional Online Presence
# Currently scraping: Create a Social Media Marketing Campaign
# Currently scraping: Decision Making: How to Choose the Right Problem to Solve
# Currently scraping: Design your Purpose as a Leader
# Currently scraping: Evidence and Data Collection for Problem Solving
# Currently scraping: Get Creative with People to Solve Problems
# Currently scraping: How to Create Great Online Content
# Currently scraping: How to Deliver Results as a Team Leader
# Currently scraping: Introduction to Marketing: Fundamentals of Marketing
# Currently scraping: Introduction to Marketing: Omnichannel Marketing and Analysis
# Currently scraping: Introduction to Marketing: Understanding your Customers
# Currently scraping: Job Opportunities in Wellness
# Currently scraping: Launching and Growing a Business in Wellness
# Currently scraping: Leading a Team: Coaching Techniques and Team Performance Management
# Currently scraping: Learn about Current Digital Workplace Trends
# Currently scraping: Presenting Your Work with Impact: Presentation Skills Training
# Currently scraping: Wellbeing and Resilience at Work
# Currently scraping: Your Future in the Wellness Industry
# Currently scraping: Business Management and Leadership
# Currently scraping: Business Planning to Grow Successful Companies
# Currently scraping: Electrical Industry: Production and Economics
# Currently scraping: Managing Innovation: Learning to Prototype for Business
# Currently scraping: Research Impact: Making a Difference
# Currently scraping: Understanding Marketing Basics
# Currently scraping: Creative Problem Solving: Design Thinking in Health and Social Care
# Currently scraping: Work Ready Skills: Job Searches, Writing a CV and Interviewing
# Currently scraping: Advertising and Creative Marketing with Advertising Week
# Currently scraping: Coaching Skills: A changing landscape
# Currently scraping: Coaching Skills: An athlete-centred approach
# Currently scraping: Coaching Skills: Leadership and self-awareness
# Currently scraping: Coaching Skills: Team culture
# Currently scraping: Coaching Skills: The mental game
# Currently scraping: Creative Branding with Advertising Week and Fernando Machado
# Currently scraping: Innovación Social: Soluciones Globales para un Mundo Sostenible
# Currently scraping: Intercultural Communication: Dynamics of cultural identities in global interaction
# Currently scraping: Radio and Podcast Marketing with Advertising Week
# Currently scraping: Social Media Marketing with Advertising Week
# Currently scraping: Workplace Wellbeing: Stress and Productivity at Work
# Currently scraping: Artificial Intelligence (AI) in Hospitality: Challenges and Business Opportunities
# Currently scraping: Business Etiquette
# Currently scraping: Digital Marketing for Hoteliers
# Currently scraping: How to Open a Restaurant
# Currently scraping: How to Plan a Wedding
# Currently scraping: Mastering Wine Tasting
# Currently scraping: Methodologies for Service Design
# Currently scraping: Nutrition: Healthy Cooking, Healthy Living
# Currently scraping: Big Data Analytics: Opportunities, Challenges, and the Future
# Currently scraping: Epargner et Investir
# Currently scraping: Fashion Management: Brands, Communication & Distribution
# Currently scraping: Fashion Management: Defining Markets, Business Models & Trends
# Currently scraping: Fashion Management: Innovation, Entrepreneurship & Sustainability
# Currently scraping: Fashion Management: Products and Collections
# Currently scraping: Influencing People
# Currently scraping: Inspiring and Motivating Individuals
# Currently scraping: Le Développement Durable Dans L'Action Humanitaire
# Currently scraping: Leading People and Teams Capstone
# Currently scraping: Leading Teams
# Currently scraping: Managing Talent
# Currently scraping: People Studying People: Research Ethics in Society
# Currently scraping: Risk Management in the Global Economy
# Currently scraping: Social Change: How Can Marketing Help?
# Currently scraping: Understanding Public Financial Management: How Is Your Money Spent?
# Currently scraping: International Marketing: Challenges and Opportunities
# Currently scraping: International Marketing: Product Adaptation vs Standardisation
# Currently scraping: International Marketing: Selection and Market Entry Strategies
# Currently scraping: The Power of Data in Health and Social Care
# Currently scraping: Workplace Training: Delivery and Assessment Methods
# Currently scraping: Workplace Training: Introduction to the Training Cycle
# Currently scraping: Workplace Training: Planning and Designing Training Solutions
# Currently scraping: Workplace Training: Training Evaluation and Measuring Effectiveness
# Currently scraping: Drone Safety for Managers (UK)
# Currently scraping: International Marketing: Cultural Factors
# Currently scraping: International Marketing: Definition and Strategy
# Currently scraping: Supply Chain Innovation: How Technology Can Create a Sustainable Future
# Currently scraping: Technology Entrepreneurship: How to Start a New Venture
# Currently scraping: The Future of Human Resource Management (HRM)
# Currently scraping: An Introduction to Medical Ethics: The Impact of Disability Screening
# Currently scraping: Distribution Network: Sustainable and Green Logistics
# Currently scraping: International Logistics: A Beginner’s Guide to Logistics Management
# Currently scraping: Inventory Management and Economic Order Quantity
# Currently scraping: Lean Logistics: Decision Making in Supply Chain Management
# Currently scraping: Multimodal Transport: Sourcing and Procurement in Logistics
# Currently scraping: Advanced Cyber Security Training: Hands-On Password Attacks
# Currently scraping: Advanced Cyber Security Training: Network Security
# Currently scraping: Advanced Cyber Security Training: OWASP Top 10 and Web Application Fundamentals
# Currently scraping: Introduction to Process Mining with ProM
# Currently scraping: Storytelling for Social Change
# Currently scraping: Teach like an Entrepreneur: Bringing Entrepreneurship into the Classroom
# Currently scraping: Content Marketing Strategy with Advertising Week
# Currently scraping: Data Visualisation with Python: Bokeh and Advanced Layouts
# Currently scraping: Data Visualisation with Python: Matplotlib and Visual Analysis
# Currently scraping: Data Visualisation with Python: Seaborn and Scatter Plots
# Currently scraping: Dynamics 365: Customer Engagement for Sales
# Currently scraping: Dynamics 365: Implementing Power Platform Integrations
# Currently scraping: Dynamics 365: Testing and Deploying Power Platform Applications
# Currently scraping: Dynamics 365: Using Power Platform Applications
# Currently scraping: Dynamics 365: Working with Power Platform Automation
# Currently scraping: Essential Mathematics for Data Science and Machine Learning: Using R
# Currently scraping: Global Studies: Cultures and Organizations in International Relations
# Currently scraping: Marketing Strategy with Advertising Week
# Currently scraping: Microsoft Dynamics 365 Fundamentals
# Currently scraping: Quantum Marketing with Raja Rajamannar
# Currently scraping: Strategic Brand Management with Advertising Week
# Currently scraping: UX Design Strategy and Application: Customer Journey Mapping
# Currently scraping: UX Design Strategy and Application: Customer Profiling and Design Sprints
# Currently scraping: UX Design Strategy and Application: Strategy, Innovation and the Future of Work
# Currently scraping: Applied Artificial Intelligence: Natural Language Processing
# Currently scraping: Applied Artificial Intelligence: Speech Recognition Systems
# Currently scraping: Getting Started with Digital Marketing
# Currently scraping: International Leadership: Ethical Leadership and Decision-Making
# Currently scraping: International Leadership: Managing Culture as Leaders
# Currently scraping: International Leadership: Politics and Philosophy in Leadership
# Currently scraping: International Leadership: Reflective Practice in Leadership
# Currently scraping: International Leadership: The Evolution of Management and Leadership Theory
# Currently scraping: Microsoft Future Ready: Ethics and Law in Data and Analytics
# Currently scraping: Microsoft Future Ready: Principles of Machine Learning with Python Programming
# Currently scraping: Microsoft Future Ready: Using Python Programming to Explore the Principles of Machine Learning
# Currently scraping: Systems Thinking for Sustainability: Analyzing and Transitioning Complex Systems
# Currently scraping: Systems Thinking for Sustainability: Drawing Complexity on a Paper
# Currently scraping: Systems Thinking for Sustainability: Practical Application of the SiD Method
# Currently scraping: An Introduction to Macro Environmental Analysis and Business Strategy
# Currently scraping: Competitor Analysis: From Business Level Strategy to Organisational Structures
# Currently scraping: HR Fundamentals
# Currently scraping: Internal Analysis of a Company: From Value Chain to SWOT Analysis
# Currently scraping: Strategic Goals: How to Master Corporate Strategy
# Currently scraping: AI and Machine Learning Algorithms Using Python
# Currently scraping: Break-Even Analysis Unlocked: How to Understand the Profit and Loss Statement
# Currently scraping: Build a Growth Mindset & Career Success with Advice from Female Founders
# Currently scraping: CRM Fundamentals and Practice: Introduction to Salesforce
# Currently scraping: CRM Fundamentals and Practice: Salesforce Automation and Best Practice
# Currently scraping: CRM Fundamentals and Practice: Salesforce Reports, Objects, and Data Management
# Currently scraping: Career Coaching for Women: Supercharge Your Career with AllBright
# Currently scraping: China’s Role in Global Tourism Development
# Currently scraping: Cold Email Mastery: The Ultimate B2B Lead Generation Course
# Currently scraping: Creativity and Innovation: Their Role in Becoming an Entrepreneur
# Currently scraping: Data Science Ethics
# Currently scraping: Data Visualisation Fundamentals for Absolute Beginners
# Currently scraping: Deep Learning on Azure with Python: Introduction to Deep Learning
# Currently scraping: Deep Learning on Azure with Python: Introduction to Machine Learning
# Currently scraping: Deep Learning on Azure with Python: Reinforcement Learning
# Currently scraping: Deep Learning on Azure with Python: The Basics of Python Programming
# Currently scraping: Divisional Performance Measurement: How to Achieve Operational Excellence
# Currently scraping: Essential Mathematics for Data Analysis in Microsoft Excel
# Currently scraping: Financial Analysis for Business Decisions: Cash Flow Management
# Currently scraping: Financial Analysis for Business Decisions: How to Use Tableau and Financial Modelling
# Currently scraping: Financial Analysis for Business Performance: Data-Driven Decision Making
# Currently scraping: Financial Analysis for Business Performance: Planning, Budgeting, and Forecasting
# Currently scraping: Financial Analysis for Business Performance: Reporting and Stakeholder Management
# Currently scraping: Financial Statements Unlocked: How to Understand Corporate Finance and Financial Management
# Currently scraping: Google Ads Course for Beginners - From Zero to PPC Hero
# Currently scraping: Green Innovation and Business Ethics: The Future of Entrepreneurship
# Currently scraping: How to Make Better Capital Investment Decisions and Recognise Investment Opportunities
# Currently scraping: How to Master Financial Statements: Financial Ratio Analysis and Interpretation
# Currently scraping: How to Use Microsoft Excel for Data Analysis
# Currently scraping: Implementing Your Business Ideas: From Risk Identification to SWOT Analysis
# Currently scraping: Introduction to Artificial Intelligence and Machine Learning
# Currently scraping: Introduction to Data Analysis using Excel for Absolute Beginners
# Currently scraping: Mastering Cloud Computing for AI: How to Use Microsoft Azure
# Currently scraping: Microsoft Future Ready: Ethics and Laws in Data and Analytics
# Currently scraping: Organisations and Project Management: P3M and Knowledge Management
# Currently scraping: Project Management: Agile Manifesto Principles
# Currently scraping: Project Management: How to be a Successful Project Manager
# Currently scraping: Project Planning and Communication: Mastering Gantt Charts and Stakeholder Management
# Currently scraping: Research Methods in Tourism Studies
# Currently scraping: Sisterhood Works: How to Build a More Meaningful Network
# Currently scraping: Software Development Fundamentals: Project Management
# Currently scraping: Success and Failure in Entrepreneurship: Discover the Key to Business Success
# Currently scraping: The Ultimate SEO and Wordpress Training Course for 2022: Rank #1
# Currently scraping: Tourism Policy and Planning
# Currently scraping: Uncovering Your Entrepreneurial Potential
# Currently scraping: Unlocking the Risk Matrix: Project Risk and the Change Management Process
# Currently scraping: Cryptocurrency and Blockchain Technology Explained
# Currently scraping: Ethical Management and Decision Making
# Currently scraping: Google My Business: Complete Listing Optimisation Training
# Currently scraping: How To Start and Run Your Own SEO Business From Home: The Complete Blueprint
# Currently scraping: How to Develop Your Social Media Content Strategy
# Currently scraping: Influencing and Communication Skills for Managers
# Currently scraping: Innovations in Investment Technology: Artificial Intelligence
# Currently scraping: Local SEO: A Definitive Guide to Local Business Marketing
# Currently scraping: Raising Capital: Credit Tech, Coin Offerings, and Crowdfunding
# Currently scraping: Running a Social Media Campaign: Customers, Influencer Engagement, Analytics
# Currently scraping: Strategic Marketing: Segmentation, Targeting, Positioning
# Currently scraping: The Future of Payment Technology
# Currently scraping: Understanding Social Media Strategy
# Currently scraping: Workplace Essentials: Health and Safety
# Currently scraping: An Introduction to Systems Thinking for Sustainability: SiD Theory I
# Currently scraping: Leading and Managing People-Centred Change
# Currently scraping: Collecting and Using Data for Disease Control and Global Health Decision-Making
# Currently scraping: High Stakes Leadership: Leading in Times of Crisis
# Currently scraping: Logical and Critical Thinking
# Currently scraping: Making Successful Decisions through the Strategy, Law & Ethics Model
# Currently scraping: Complete Guide To Link Building: Building High-Quality Backlinks for SEO
# Currently scraping: Introducing Personal Lines Insurance
# Currently scraping: Become a Better Presenter: Improve Your Public Speaking Skills
# Currently scraping: Build a Startup from Scratch: the Venture Design Process
# Currently scraping: People Management Skills
# Currently scraping: Planning and Managing Global Health Programmes: Promoting Quality, Accountability, and Equity
# Currently scraping: Social Innovation: Global Solutions for a Sustainable Future
# Currently scraping: Upcycling: From Green Ideas to Starting a Business
# Currently scraping: How to Get A Graduate Job
# Currently scraping: Innovative Leadership: Developing Curiosity
# Currently scraping: Online Recruitment and Onboarding: Providing Continuity for Business and Candidates
# Currently scraping: Introduction to Data for Business Leaders
# Currently scraping: Making Sense of Data in the Media
# Currently scraping: Salary Negotiation for Women in the Workplace
# Currently scraping: Social Enterprise: Business Doing Good
# Currently scraping: Social Enterprise: Growing a Sustainable Business
# Currently scraping: Social Enterprise: Turning Ideas into Action
# Currently scraping: Social Innovation in South Korea
# Currently scraping: Introduction to Innovation and Technology in Legal Services
# Currently scraping: Sustainable Construction and Development
# Currently scraping: Construction Ethics and Compliance
# Currently scraping: Lever des Fonds pour ma Startup
# Currently scraping: Quality in Construction
# Currently scraping: Raising Funds for Your Startup
# Currently scraping: Impact Investing
# Currently scraping: Mergers and Acquisitions: Accounting Principles
# Currently scraping: Why We Post: the Anthropology of Social Media
# Currently scraping: Mergers and Acquisitions: Free Cash Flow Modeling
# Currently scraping: The Mind is Flat: The Shocking Shallowness of Human Psychology
# Currently scraping: English for the Workplace
# Currently scraping: Mergers and Acquisitions: Structuring the Deal
# Currently scraping: Understanding Data in the Tourism Industry
# Currently scraping: Fashion's Future: The Sustainable Development Goals
# Currently scraping: Project Management Principles, Practices and Systems
# Currently scraping: Challenging Wealth and Income Inequality
# Currently scraping: Mergers and Acquisitions: Advanced Theory
# Currently scraping: Understanding Modern Business and Organisations
# Currently scraping: Introduction to Humanitarian Logistics
# Currently scraping: Mergers and Acquisitions: Concepts and Theories
# Currently scraping: Social Innovation in Rural Areas
# Currently scraping: Introduction to Financial Accounting
# Currently scraping: Introduction to the Travel & Tourism Industry: Passport to the World
# Currently scraping: Digital Marketing in Perspective
# Currently scraping: Digital Marketing: Content Marketing
# Currently scraping: Digital Marketing: Marketing Channel Objectives
# Currently scraping: Digital Marketing: Personas and User Journeys
# Currently scraping: A Reporter’s Toolkit for the Digital Age
# Currently scraping: Becoming a Better Music Teacher
# Currently scraping: Digital Skills: User Experience
# Currently scraping: Medicine and the Arts: Humanising Healthcare
# Currently scraping: Power Dressing in the Zoom Era
# Currently scraping: Low-Budget Video Production: Visual Communication for Small Charities
# Currently scraping: Music and Intelligence: Can Music Make You Smarter?
# Currently scraping: Playing with Poetry: Creative Writing and Poetics
# Currently scraping: The Design Thinking Toolbox
# Currently scraping: Filmmaking and Animation Online and in the Classroom
# Currently scraping: String Music Appreciation
# Currently scraping: Using Film to Teach Literacy Online and in the Classroom
# Currently scraping: Innovation: the Fashion Industry
# Currently scraping: Lights, Camera, Computer - Action! How Digital Technology is Transforming Film, TV, and Gaming
# Currently scraping: MedTech: Trends and Product Design
# Currently scraping: Motion Capture: The Art of Studying Human Activity
# Currently scraping: Music Moves: Why Does Music Make You Move?
# Currently scraping: Physical Theatre: Exploring the Slap
# Currently scraping: WW1 Heroism: Through Art and Film
# Currently scraping: Essentials in Arts Fundraising
# Currently scraping: Introduction to Acting
# Currently scraping: Start Writing Fiction
# Currently scraping: Compassion in Fashion: Sustainability and the Global Fur Trade
# Currently scraping: Creating Audio Description: Equality, Diversity, and Inclusion
# Currently scraping: Effective Fundraising and Leadership in Arts and Culture
# Currently scraping: Brand Strategy and Communication
# Currently scraping: Creating Strategies for Influencer Marketing
# Currently scraping: Creative Communication Beyond VR and AR
# Currently scraping: Digital Playground: Where Luxury Fashion is Finding its Sense of Humour
# Currently scraping: Fashion and Gaming: How Luxury Fashion Brands Use Gamification
# Currently scraping: Placemaking and Public Space Design: Unlocking Place Potential
# Currently scraping: Strategic Design for Social Media
# Currently scraping: Fashion Values: Economy
# Currently scraping: Fashion and the Climate Crisis: An Introduction to Sustainability
# Currently scraping: Improving Your Image: Dental Photography in Practice
# Currently scraping: Music Psychology: Why Does "Bohemian Rhapsody" Feel so Good?
# Currently scraping: Anarchy in the UK: A History of Punk from 1976-78
# Currently scraping: Women in Arts: From 1900 until today
# Currently scraping: Design and Prototype Embedded Computer Systems
# Currently scraping: Ethical Practices to Guide Innovation
# Currently scraping: Facebook Marketing: Organic Reach and Paid Advertising
# Currently scraping: Feature Writing
# Currently scraping: Introduction to Journalism and Reporting
# Currently scraping: Placemaking and Public Space Design: Unlocking Design Potential
# Currently scraping: Instagram Marketing: Instagram Essentials and Content Creation
# Currently scraping: LinkedIn Marketing: LinkedIn Essentials and Content Creation
# Currently scraping: Social Media Marketing Strategy: Objective Setting and Strategic Planning Essentials
# Currently scraping: Explore and Understand the Gaming Industry
# Currently scraping: How to Create Everlasting Experiences Through Gaming
# Currently scraping: How to Understand the Gaming Audience
# Currently scraping: Understanding Fashion: From Business to Culture
# Currently scraping: An Introduction to the Nordoff Robbins approach to Music Therapy
# Currently scraping: Placemaking and Public Space Design: Unlocking Tourist Destinations
# Currently scraping: Healthy House Plants: A Complete Guide to Gardening Indoors
# Currently scraping: Stylistics: Using Linguistics to Explore Texts and Meaning
# Currently scraping: Sustainable Fashion Ecologies: Sustainable Practices Across the Fashion Ecosystem
# Currently scraping: Dementia and the Arts: Sharing Practice, Developing Understanding and Enhancing Lives
# Currently scraping: A History of Royal Fashion
# Currently scraping: Introduction to Production Design for Film and Screen
# Currently scraping: The Essential Financial Management Toolbox for Film, Screen and Broadcast
# Currently scraping: UX Design Fundamentals: Business Value Through User Experience (UX) Design
# Currently scraping: UX Design Fundamentals: Creating Business Outcomes
# Currently scraping: UX Design Fundamentals: Delivering Value to Users
# Currently scraping: Introduction to 3D Animation using Blender
# Currently scraping: Digital Fashion Media
# Currently scraping: Digital Marketing: Storytelling in the New Communication Landscape
# Currently scraping: Ethics and Diversity in Fashion
# Currently scraping: Fashion and Sustainability: Understanding Luxury Fashion in a Changing World
# Currently scraping: Fibre, Fermentation & the Gut with BBC Good Food
# Currently scraping: Healthy Cooking Made Easy with BBC Good Food
# Currently scraping: Healthy Vegan Cooking with BBC Good Food
# Currently scraping: Social Impact in Business: How to Build a Brand that Matters
# Currently scraping: Special Diets: Cooking for Allergies and Intolerances with BBC Good Food
# Currently scraping: Sustainable Luxury Fashion
# Currently scraping: Sweet Tooth: Understanding Sugar and the Body with BBC Good Food
# Currently scraping: The Business of Beauty: Introduction to the Beauty Industry
# Currently scraping: The Future of Fashion
# Currently scraping: Video Game Design and Development: A Bit-by-Bit History of Video Game Music: Video Game Sound and Music
# Currently scraping: Visualizing Women's Work: Using Art Media for Social Justice
# Currently scraping: An Introduction to Screenwriting
# Currently scraping: How Plants Grow: The Essentials
# Currently scraping: How to Grow Healthy Plants
# Currently scraping: Customer Experience Design for Customer Success: CX Impact and Strategic Insights
# Currently scraping: Evaluating Designs with Users
# Currently scraping: Introduction to 3D Modeling
# Currently scraping: Professional Knife Skills
# Currently scraping: UX Design: From Concept to Prototype
# Currently scraping: Video Game Design and Development: Introduction to Game Programming
# Currently scraping: Black Performance as Social Protest
# Currently scraping: Food Safety and Personal Hygiene in a Professional Kitchen
# Currently scraping: Introduction to Sustainable Practices in Food Service
# Currently scraping: Film Education: A User's Guide
# Currently scraping: Learn How to Bake Afternoon Tea with BBC Good Food
# Currently scraping: Learn How to Bake Pies and Tarts with BBC Good Food
# Currently scraping: Learn How to Bake Showstopper Cakes with BBC Good Food
# Currently scraping: Learn How to Bake Sourdough with BBC Good Food
# Currently scraping: Short Film in Language Teaching
# Currently scraping: The Living Picture Craze: An Introduction to Victorian Film
# Currently scraping: Video Game Design and Development: Video Game Character Design
# Currently scraping: Introduction to Creative AI
# Currently scraping: Introduction to Indie Games
# Currently scraping: Introduction to UX and Accessible Design
# Currently scraping: Invitation to Ex-Noguchi Room: Preservation and Utilization of Cultural Properties in Universities
# Currently scraping: Modern Building Design
# Currently scraping: Getting Started with Agile and Design Thinking
# Currently scraping: How to Build Your Creative Resilience
# Currently scraping: How to Enhance Your Creative Empathy
# Currently scraping: How to Improve Your Creative Collaboration
# Currently scraping: Story of a Wine: The Importance of Being Prosecco
# Currently scraping: How to Make and Sell Your First Immersive Experience
# Currently scraping: Master Digital Marketing: Introduction to Marketing
# Currently scraping: Master Digital Marketing: Marketing Fundamentals
# Currently scraping: Master Digital Marketing: Marketing Strategy
# Currently scraping: Master Digital Marketing: The Marketing Mix
# Currently scraping: Learn How to Bake with BBC Good Food
# Currently scraping: Creating a Great User Experience for Mobile Apps
# Currently scraping: Fashion Values: Nature
# Currently scraping: Get Creative with People to Solve Problems
# Currently scraping: Healthcare Selection and Recruitment: Design and Deliver Effective Multiple Mini Interviews (MMIs)
# Currently scraping: Exploring Mentorship and Community Change with the Compton Cowboys
# Currently scraping: Pictures of Youth: An Introduction to Children’s Visual Culture
# Currently scraping: Creative Branding with Advertising Week and Fernando Machado
# Currently scraping: Radio and Podcast Marketing with Advertising Week
# Currently scraping: The Art of Washi Paper in Japanese Rare Books
# Currently scraping: Art Comes First: Exploring the Intersection of Style and Identity
# Currently scraping: Fashion Management: Brands, Communication & Distribution
# Currently scraping: Fashion Management: Defining Markets, Business Models & Trends
# Currently scraping: Fashion Management: Innovation, Entrepreneurship & Sustainability
# Currently scraping: Fashion Management: Products and Collections
# Currently scraping: Drone Safety for Managers (Australia)
# Currently scraping: Drone Safety for Managers (India)
# Currently scraping: Drone Safety for Managers (Latin America)
# Currently scraping: Exploring Body Neutrality and Body Image with Jameela Jamil
# Currently scraping: Content Marketing Strategy with Advertising Week
# Currently scraping: Quantum Marketing with Raja Rajamannar
# Currently scraping: UX Design Strategy and Application: Customer Journey Mapping
# Currently scraping: UX Design Strategy and Application: Customer Profiling and Design Sprints
# Currently scraping: UX Design Strategy and Application: Strategy, Innovation and the Future of Work
# Currently scraping: Learn Jazz Piano: Advanced and Solo Playing
# Currently scraping: Learn Jazz Piano: Begin with the Blues
# Currently scraping: Learn Jazz Piano: Final Topics and Two Concerts
# Currently scraping: Learn Jazz Piano: Improvising on Jazz Standards
# Currently scraping: Design Computing: 3D Modeling in Rhinoceros with Python Rhinoscript
# Currently scraping: How to Write Your First Song
# Currently scraping: Who Made My Clothes?
# Currently scraping: Become a Better Presenter: Improve Your Public Speaking Skills
# Currently scraping: Build a Startup from Scratch: the Venture Design Process
# Currently scraping: Pop Art
# Currently scraping: Modern Sculpture: An Introduction to Art History
# Currently scraping: Fashion's Future: The Sustainable Development Goals
# Currently scraping: How To Start Your Career In Games Development
# Currently scraping: Exploring Japanese Avant-garde Art Through Butoh Dance
# Currently scraping: From Notation to Performance: Understanding Musical Scores
# Currently scraping: Business Futures: Sustainable Business Through Green HR
# Currently scraping: Environmental Challenges: Human Impact in the Natural Environment
# Currently scraping: Introduction to Humanitarian Aid
# Currently scraping: Introduction to Sustainability and Development
# Currently scraping: Making Climate Adaptation Happen: Governing Transformation Strategies for Climate Change
# Currently scraping: Carbon Markets: Examining EU Policies for Transnational Climate Action
# Currently scraping: Electrification of Urban Mobility: How to Get it Right
# Currently scraping: Extinctions: Past and Present
# Currently scraping: Teaching Climate and Sustainability in Primary Schools: An Outdoor Learning Approach
# Currently scraping: Vehicle-to-Grid Charging for Electric Cars
# Currently scraping: Agriculture and Nutrition
# Currently scraping: Environmental Challenges: Hierarchy in Property Rights
# Currently scraping: Indigeneity as a Global Concept
# Currently scraping: Teaching Climate Change
# Currently scraping: Moons
# Currently scraping: Solving Sustainability Challenges with Te Ao Māori (Māori World View)
# Currently scraping: Unleash Your Potential: Sustainable Futures
# Currently scraping: Environmental Challenges: Rights and Values in Ecosystem Services
# Currently scraping: Climate Change and Public Policy
# Currently scraping: Planning for Autonomous Vehicles: A People-Centred Approach
# Currently scraping: Smart Cities: Social Change Through Technology
# Currently scraping: Sustainability and Biculturalism: Their Interrelationships and Impacts
# Currently scraping: Climate Change and Resilience in Food Systems
# Currently scraping: Ecology and Wildlife Conservation
# Currently scraping: Environmental Challenges: Justice in Natural Resource Management
# Currently scraping: Exploring Possible Futures: Modeling in Environmental and Energy Economics
# Currently scraping: Food Safety and Nutrition: A Global Approach to Public Health
# Currently scraping: Life Below Water: Conservation, Current Issues, Possible Solutions
# Currently scraping: Additive Manufacturing in the Industry: Impact on Sustainability
# Currently scraping: A Nutritional Approach to Agriculture and Food Security
# Currently scraping: Communicative Planning for Urban Mobility
# Currently scraping: Compassion in Fashion: Sustainability and the Global Fur Trade
# Currently scraping: Sustainable Energy Access for Communities
# Currently scraping: Sustainable Transport and Shared Mobility
# Currently scraping: Animal Feed Production: Feed Quality
# Currently scraping: Animal Feed Production: Feed Safety
# Currently scraping: Circular Business Models for Sustainable Urban Food Systems
# Currently scraping: Consumer and Environmental Safety: Food Packaging and Kitchenware
# Currently scraping: Engaging with Controversies in the Food System
# Currently scraping: Explore How Farmers Produce Food Sustainably
# Currently scraping: Farm to Fork: Sustainable Food Production in a Changing Environment
# Currently scraping: From Waste to Value: How to Tackle Food Waste
# Currently scraping: How Food is Made. Understanding Food Processing Technologies
# Currently scraping: Improving Food Production with Agricultural Technology and Plant Biotechnology
# Currently scraping: Innovation in Arable Farming: Technologies for Sustainable Farming Systems
# ...
# Currently scraping: A Beginner's Guide to Writing in English for University Study
# Currently scraping: English Language Learning Through Sustainability
# Currently scraping: An Introduction to Sociolinguistics: Accents, Attitudes and Identity
# Currently scraping: EAL: English Language for Nature Conservation and Sustainability
# Currently scraping: Shakespeare's Language: Revealing Meanings and Exploring Myths
# Currently scraping: Exploring English: Food and Culture
# Currently scraping: Introduction to Korean
# Currently scraping: Introduction to Italian
# Currently scraping: Te Reo Māori: Introduction to Pronunciation
# Currently scraping: Foundations of Portuguese for Global Communication
# Currently scraping: Learn English Through TV Drama Series: Skipper's Pass
# Currently scraping: Let's Learn Portuguese Language
# Currently scraping: Communicating with Diverse Audiences
# Currently scraping: Learn Chinese: Introduction to Chinese Conversation
# Currently scraping: Learn Chinese: Introduction to Chinese Grammar
# Currently scraping: Learn Chinese: Introduction to Chinese Pronunciation and Tone
# Currently scraping: English Pronunciation in a Global World
# Currently scraping: Let's Learn Thai Language
# Currently scraping: Intercultural Communication: Dynamics of cultural identities in global interaction
# Currently scraping: Multilingual Learning for a Globalised World
# Currently scraping: PTE Success: The Skills You Need
# Currently scraping: Interpreting for Refugees: Contexts, Practices and Ethics
# Currently scraping: Understanding IELTS: Listening
# Currently scraping: Understanding IELTS: Reading
# Currently scraping: Understanding IELTS: Speaking
# Currently scraping: Understanding IELTS: Writing
# Currently scraping: Magna Carta
# Currently scraping: Tourism Policy and Planning
# Currently scraping: Foundations of French for Global Communication
# Currently scraping: Foundations of Spanish for Global Communication
# Currently scraping: Many Faces: Understanding the Complexities of Chinese Culture
# Currently scraping: Preparing for Graduate Study in the US: A Course for International Students
# Currently scraping: An Introduction to Japanese Subcultures
# Currently scraping: English Football: a Social History
# Currently scraping: Introduction to Korean Philosophy
# Currently scraping: English for the Workplace
# Currently scraping: Norwegian for Beginners 3
# Currently scraping: Norwegian for Beginners 2
# Currently scraping: The Korean Alphabet: An Introduction to Hangeul
# Currently scraping: Norwegian for Beginners 1
# Currently scraping: Developing and Testing Complex Healthcare Interventions
# Currently scraping: English for Academic Study
# Currently scraping: Digital Discovery
# Currently scraping: How to Succeed at: Writing Applications
# Currently scraping: Qualitative Research Methods for Mental Health in War and Conflict
# Currently scraping: Study UK: Preparing for work
# Currently scraping: Skills to Succeed at University
# Currently scraping: Basic English 1: Elementary
# Currently scraping: Basic English 2: Pre-Intermediate
# Currently scraping: Community Based Research: Getting Started
# Currently scraping: Critical Thinking at University: An Introduction
# Currently scraping: Discovering Science: Science Writing
# Currently scraping: Interdisciplinary Learning: Working Across Disciplines
# Currently scraping: Introduction to Research Ethics: Working with People
# Currently scraping: Learning Online: Communicating and Collaborating
# Currently scraping: Learning Online: Managing Your Online Identity
# Currently scraping: Learning Online: Researching Your Project
# Currently scraping: Learning Online: Studying and Reflecting
# Currently scraping: Preparing for University
# Currently scraping: Preparing to Learn Online at University
# Currently scraping: Digital Skills Awareness for Starting Higher Education
# Currently scraping: University Preparation Course: Getting Ready for Success at University
# Currently scraping: Science Communication and Public Engagement
# Currently scraping: Research Methods: A Practical Guide to Peer and Community Research
# Currently scraping: Writing and Editing: Drafting
# Currently scraping: Writing and Editing: Revising
# Currently scraping: Writing and Editing: Structure and Organisation
# Currently scraping: Writing and Editing: Word Choice and Word Order
# Currently scraping: Improving Your Study Techniques
# Currently scraping: Practise your PTE Academic Speaking Skills
# Currently scraping: Improve your IELTS Speaking score
# Currently scraping: Learn Spanish: Survival Spanish for Beginners
# Currently scraping: An Intermediate Guide to Writing in English for University Study
# Currently scraping: Career Management for Early Career Academic Researchers
# Currently scraping: Why Research Matters
# Currently scraping: How to Read French Poetry
# Currently scraping: University and Your Future: Career Planning and Making the Most of Your Degree
# Currently scraping: A Digital Edge: Essentials for the Online Learner
# Currently scraping: Academic Research Methodology for Master’s Students
# Currently scraping: Digital Skills: Reimagine Your Career
# Currently scraping: A Beginner's Guide to Writing in English for University Study
# Currently scraping: Becoming a Student Assistant: Teaching and Mentoring
# Currently scraping: Designing a Future Where Learning is a Lifestyle
# Currently scraping: Medicine Personal Statement Online Crash Course
# Currently scraping: Study Medicine: Applying for Medical School and Becoming a Medical Student
# Currently scraping: Analysing Data in Excel
# Currently scraping: Introduction to Phenomenology and its Application in Qualitative Research
# Currently scraping: Empresas Exponenciales: Guía Para Comenzar
# Currently scraping: Learn English Through TV Drama Series: Skipper's Pass
# Currently scraping: Capital: crear un plan para conseguir inversionistas
# Currently scraping: Crecimiento: nunca es temprano para hacer crecer tu negocio
# Currently scraping: Ejecución: experimentos, recursos y puesta en marcha
# Currently scraping: Introduction to Studying Business
# Currently scraping: Introduction to Studying Law
# Currently scraping: Preparing for an International Health Elective: Exploring Global Health, Ethics and Safety
# Currently scraping: Producto: valida y entrega tu propuesta de valor
# Currently scraping: Visión: la estrategia para alcanzar tu propósito
# Currently scraping: Critical Appraisal Techniques for Healthcare Literature
# Currently scraping: Research Impact: Making a Difference
# Currently scraping: Returning to Education as a Mature Student
# Currently scraping: Work Ready Skills: Job Searches, Writing a CV and Interviewing
# Currently scraping: A Parent and Supporter’s Guide to University Entry
# Currently scraping: People Studying People: Research Ethics in Society
# Currently scraping: Preparing for PTE Academic
# Currently scraping: PTE Success: The Skills You Need
# Currently scraping: Live Smart: Your Essential Guide to Living at University
# Currently scraping: Research Methods in Tourism Studies
# Currently scraping: Preparing for Graduate Study in the US: A Course for International Students
# Currently scraping: Education Research that Matters: Doing Research in Your Learning Community
# Currently scraping: How to Get A Graduate Job
# Currently scraping: How to Succeed in Your EPQ: the Nuts and Bolts of Completing Your Project
# Currently scraping: Technical Report Writing for Engineers
# Currently scraping: How to Succeed in Your Welsh Bacc: the Individual Project Essentials
# Currently scraping: Population 10 Billion: Researching Global Issues
# Currently scraping: How to Learn Online: Getting Started
# Currently scraping: Discovering Your PhD Potential: Writing a Research Proposal
# Currently scraping: Learning in the Network Age
# Currently scraping: Developing Your Research Project
# Currently scraping: Education Research That Matters: Ways of Researching
# Currently scraping: Education Research that Matters: Applying Research to Your Teaching Practice
# Currently scraping: An Anthropology of Smartphones: Communication, Ageing and Health
# Currently scraping: Teaching Students Who Have Suffered Complex Trauma
# Currently scraping: Food and Mood: Improving Mental Health Through Diet and Nutrition
# Currently scraping: Forensic Mental Health and Criminal Justice
# Currently scraping: Medicine and the Arts: Humanising Healthcare
# Currently scraping: Nutrition Science: Food Choice and Behaviour
# Currently scraping: PSHE Education: Helping Children Navigate a Complex World
# Currently scraping: What is a Mind?
# Currently scraping: Music and Intelligence: Can Music Make You Smarter?
# Currently scraping: Young People and Mental Health
# Currently scraping: Crisis Leadership
# Currently scraping: Emotional Intelligence in Practice
# Currently scraping: Qualitative Research Methods for Mental Health in War and Conflict
# Currently scraping: Self Care and Wellbeing: A Practical Guide for Health and Social Care
# Currently scraping: Trastorno por déficit de atención con hiperactividad (TDAH)
# Currently scraping: Behavioural Economics: Employee and Customer Behaviour
# Currently scraping: Cognitive Psychology: Employee and Customer Behaviour
# Currently scraping: Forensic Psychology: Witness Investigation
# Currently scraping: Social Psychology: Employee and Customer Behaviour
# Currently scraping: Understanding Autism
# Currently scraping: Understanding Human Behaviour: Introduction to Game Theory and Shared Resources
# Currently scraping: Childhood Adversity: The Impact of Childhood Maltreatment on Mental Health
# Currently scraping: Drug Use and Harm Reduction
# Currently scraping: Maintaining a Mindful Life
# Currently scraping: Mindfulness for Wellbeing and Peak Performance
# Currently scraping: Nutrition and Wellbeing
# Currently scraping: The Monday Campaigns: Lessons in Public Health Promotion
# Currently scraping: Introduction to Behavioural Activation for Depression
# Currently scraping: Understanding Anxiety, Depression and CBT
# Currently scraping: Food and Nutrition: The Truth Behind Food Headlines
# Currently scraping: Food for Thought: The Relationship Between Food, Gut and Brain
# Currently scraping: Supporting People with Health Conditions Into Work: Individual Placement and Support (IPS)
# Currently scraping: City Liveability: The Intersections of Place, Mobility, and Health
# Currently scraping: Research Methods: A Practical Guide to Peer and Community Research
# Currently scraping: Research Methods in Psychology: Using Animal Models to Understand Human Behaviour
# Currently scraping: Music Psychology: Why Does "Bohemian Rhapsody" Feel so Good?
# Currently scraping: People, Networks and Neighbours: Understanding Social Dynamics
# Currently scraping: Loss of a Baby in Multiple Pregnancy: Supporting Grieving Parents
# Currently scraping: Addressing Postnatal Depression as a Healthcare Professional
# Currently scraping: Understanding ADHD: Current Research and Practice
# Currently scraping: Managing Mental Health and Stress
# Currently scraping: Mindware: Critical Thinking for the Information Age
# Currently scraping: The Science of Success: What Researchers Know that You Should Know
# Currently scraping: An Introduction to the Nordoff Robbins approach to Music Therapy
# Currently scraping: Caring with Music: Can Music Do More In Adult Care Settings?
# Currently scraping: Supporting Adolescent Learners: Social and Emotional Wellbeing
# Currently scraping: Dementia and the Arts: Sharing Practice, Developing Understanding and Enhancing Lives
# Currently scraping: Emotional Intelligence at Work
# Currently scraping: Identifying and Responding to Domestic Violence and Abuse (DVA) in Pregnancy
# Currently scraping: Identifying and Responding to Drug and Alcohol Addiction in Nursing, Midwifery and Allied Healthcare Practice
# Currently scraping: Understanding Addiction
# Currently scraping: Unlocking The Creative Brain: Develop and Teach Skills For Creative Thinking
# Currently scraping: End-of-Life Care for People with Dementia
# Currently scraping: Nature Connectedness with the University of Derby
# Currently scraping: Demystifying Mindfulness
# Currently scraping: Introduction to Cognitive Psychology: An Experimental Science
# Currently scraping: Social Network Analysis: The Networks Connecting People
# Currently scraping: Bushfires: Response, Relief, and Resilience
# Currently scraping: COVID-19 Critical Care: Understanding and Application
# Currently scraping: Workplace Wellbeing: How to Build Confidence and Manage Stress
# Currently scraping: Physiotherapy Exercise and Physical Activity for Knee Osteoarthritis (PEAK)
# Currently scraping: Youth Mental Health: Supporting Young People Using a Trauma Informed Practice
# Currently scraping: Step into Social Care
# Currently scraping: Understanding Depression and Low Mood in Young People
# Currently scraping: Digital Wellbeing
# Currently scraping: Understanding Suicide and Suicide Prevention Strategies in a Global Context
# Currently scraping: Mental Skills Training for Sport and Health
# Currently scraping: Psychological First Aid: Supporting Children and Young People
# Currently scraping: Developing Clinical Empathy: Making a Difference in Patient Care
# Currently scraping: Understanding Epilepsy and its Neuropsychology
# Currently scraping: Coping with Changes: Social-Emotional Learning Through Play
# Currently scraping: Social Care During COVID-19: Coping with Self-Isolation and Social Distancing
# Currently scraping: Good Practice in Autism Education
# Currently scraping: Coaching Skills: A changing landscape
# Currently scraping: Coaching Skills: An athlete-centred approach
# Currently scraping: Coaching Skills: Leadership and self-awareness
# Currently scraping: Coaching Skills: Team culture
# Currently scraping: Coaching Skills: The mental game
# Currently scraping: Quality of Life Studies and Public Policy
# Currently scraping: Workplace Wellbeing: Stress and Productivity at Work
# Currently scraping: Introduction to Health Psychology
# Currently scraping: Exploring Sustainable Living and Loving with Mogli
# Currently scraping: COVID-19: Psychological First Aid in Africa
# Currently scraping: Integrating Care: Depression, Anxiety and Physical Illness
# Currently scraping: Foundations in Dementia
# Currently scraping: Supporting Victims of Domestic Violence
# Currently scraping: Mindfulness: A Focus on Adolescents
# Currently scraping: Post-Traumatic Stress Disorder (PTSD) in the Global Context
# Currently scraping: Orientation to Educational Neuroscience
# Currently scraping: Sisterhood Works: How to Build a More Meaningful Network
# Currently scraping: The Many Faces of Dementia
# Currently scraping: Ethical Management and Decision Making
# Currently scraping: Influencing and Communication Skills for Managers
# Currently scraping: Introduction to Psychology: Biological Psychology
# Currently scraping: Introduction to Psychology: Developmental Psychology
# Currently scraping: Introduction to Psychology: Sensation and Perception
# Currently scraping: Introduction to Psychology: The History and Science of Psychology
# Currently scraping: Introduction to Psychology: The Psychology of Learning
# Currently scraping: Introduction to Psychology: The Psychology of Personality
# Currently scraping: Logical and Critical Thinking
# Currently scraping: Personalised Care: Peer Leadership Foundation - Step One
# Currently scraping: Mental Health in Construction
# Currently scraping: Integrated Healthcare for Children with Developmental Disabilities
# Currently scraping: The Path to Happiness and Good Quality of Life
# Currently scraping: Innovative Leadership: Developing Curiosity
# Currently scraping: Exploring Play: The Importance of Play in Everyday Life
# Currently scraping: Understanding Mental Health: Continuum, Culture and Social Media
# Currently scraping: COVID-19: Psychological First Aid
# Currently scraping: The Mind is Flat: The Shocking Shallowness of Human Psychology
# Currently scraping: Anxiety in Children and Young People during COVID-19
# Currently scraping: Addressing Violence Through Patient Care
# Currently scraping: Health and Wellbeing in the Ancient World
# []
# Couldn't access 0 courses
# Time it took to scrape: 1:07:26.354415
