# %% [markdown]
# # Webscraper FutureLearn
# FeatureLearn.com is an online learning platform, offering courses on a variety of subjects. This scraper scrapes all the courses available on futurelearn. The total run time is around an hour and a half.

# %% [markdown]
# ## 1 Importing packages

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import time
import csv

# %% [markdown]
# ## 2 Preparation

# %% [markdown]
# ### 2.1 Getting the max page number
# Get the maximum number of pages in the 'all' category

# %%
#Start time so we know how long it takes to run the code
start_time = datetime.now()

#Request of the courses page showing all the courses. It scrapes the button on the bottom showing what the last page is
url = "https://www.futurelearn.com/courses"
r = requests.get(url)
soup = BeautifulSoup(r.text, "html.parser")
max_page = int(soup.find('div', class_ = "a-content a-contiguous-top u-centered a-content--tight").find_all('li', class_="pagination-module_item__3XB-l")[-1].text)
max_page
# Out:
# 95

# %% [markdown]
# ### 2.2 Make the page urls
# This code does not require a html request since each link is predictable. The resulting dictionary contains the page number and page url.

# %%
 def make_page_urls(max_page):   
    page_urls = []
    for page in range(1, max_page+1):
        page_info = {}
        page_info['page'] = page
        page_info['page_url'] = f"https://www.futurelearn.com/courses?&page={page}#courses-grid-start"
        page_urls.append(page_info)
    return page_urls

# %%
page_urls = make_page_urls(max_page)
page_urls
# Out:
# [{'page': 1,
#   'page_url': 'https://www.futurelearn.com/courses?&page=1#courses-grid-start'},
#  {'page': 2,
#   'page_url': 'https://www.futurelearn.com/courses?&page=2#courses-grid-start'},
#  {'page': 3,
#   'page_url': 'https://www.futurelearn.com/courses?&page=3#courses-grid-start'},
#  {'page': 4,
#   'page_url': 'https://www.futurelearn.com/courses?&page=4#courses-grid-start'},
#  {'page': 5,
#   'page_url': 'https://www.futurelearn.com/courses?&page=5#courses-grid-start'},
#  {'page': 6,
#   'page_url': 'https://www.futurelearn.com/courses?&page=6#courses-grid-start'},
#  {'page': 7,
#   'page_url': 'https://www.futurelearn.com/courses?&page=7#courses-grid-start'},
#  {'page': 8,
#   'page_url': 'https://www.futurelearn.com/courses?&page=8#courses-grid-start'},
#  {'page': 9,
#   'page_url': 'https://www.futurelearn.com/courses?&page=9#courses-grid-start'},
#  {'page': 10,
#   'page_url': 'https://www.futurelearn.com/courses?&page=10#courses-grid-start'},
#  {'page': 11,
#   'page_url': 'https://www.futurelearn.com/courses?&page=11#courses-grid-start'},
#  {'page': 12,
#   'page_url': 'https://www.futurelearn.com/courses?&page=12#courses-grid-start'},
#  {'page': 13,
#   'page_url': 'https://www.futurelearn.com/courses?&page=13#courses-grid-start'},
#  {'page': 14,
#   'page_url': 'https://www.futurelearn.com/courses?&page=14#courses-grid-start'},
#  {'page': 15,
#   'page_url': 'https://www.futurelearn.com/courses?&page=15#courses-grid-start'},
#  {'page': 16,
#   'page_url': 'https://www.futurelearn.com/courses?&page=16#courses-grid-start'},
#  {'page': 17,
#   'page_url': 'https://www.futurelearn.com/courses?&page=17#courses-grid-start'},
#  {'page': 18,
#   'page_url': 'https://www.futurelearn.com/courses?&page=18#courses-grid-start'},
#  {'page': 19,
#   'page_url': 'https://www.futurelearn.com/courses?&page=19#courses-grid-start'},
#  {'page': 20,
#   'page_url': 'https://www.futurelearn.com/courses?&page=20#courses-grid-start'},
#  {'page': 21,
#   'page_url': 'https://www.futurelearn.com/courses?&page=21#courses-grid-start'},
#  {'page': 22,
#   'page_url': 'https://www.futurelearn.com/courses?&page=22#courses-grid-start'},
#  {'page': 23,
#   'page_url': 'https://www.futurelearn.com/courses?&page=23#courses-grid-start'},
#  {'page': 24,
#   'page_url': 'https://www.futurelearn.com/courses?&page=24#courses-grid-start'},
#  {'page': 25,
#   'page_url': 'https://www.futurelearn.com/courses?&page=25#courses-grid-start'},
#  {'page': 26,
#   'page_url': 'https://www.futurelearn.com/courses?&page=26#courses-grid-start'},
#  {'page': 27,
#   'page_url': 'https://www.futurelearn.com/courses?&page=27#courses-grid-start'},
#  {'page': 28,
#   'page_url': 'https://www.futurelearn.com/courses?&page=28#courses-grid-start'},
#  {'page': 29,
#   'page_url': 'https://www.futurelearn.com/courses?&page=29#courses-grid-start'},
#  {'page': 30,
#   'page_url': 'https://www.futurelearn.com/courses?&page=30#courses-grid-start'},
#  {'page': 31,
#   'page_url': 'https://www.futurelearn.com/courses?&page=31#courses-grid-start'},
#  {'page': 32,
#   'page_url': 'https://www.futurelearn.com/courses?&page=32#courses-grid-start'},
#  {'page': 33,
#   'page_url': 'https://www.futurelearn.com/courses?&page=33#courses-grid-start'},
#  {'page': 34,
#   'page_url': 'https://www.futurelearn.com/courses?&page=34#courses-grid-start'},
#  {'page': 35,
#   'page_url': 'https://www.futurelearn.com/courses?&page=35#courses-grid-start'},
#  {'page': 36,
#   'page_url': 'https://www.futurelearn.com/courses?&page=36#courses-grid-start'},
#  {'page': 37,
#   'page_url': 'https://www.futurelearn.com/courses?&page=37#courses-grid-start'},
#  {'page': 38,
#   'page_url': 'https://www.futurelearn.com/courses?&page=38#courses-grid-start'},
#  {'page': 39,
#   'page_url': 'https://www.futurelearn.com/courses?&page=39#courses-grid-start'},
#  {'page': 40,
#   'page_url': 'https://www.futurelearn.com/courses?&page=40#courses-grid-start'},
#  {'page': 41,
#   'page_url': 'https://www.futurelearn.com/courses?&page=41#courses-grid-start'},
#  {'page': 42,
#   'page_url': 'https://www.futurelearn.com/courses?&page=42#courses-grid-start'},
#  {'page': 43,
#   'page_url': 'https://www.futurelearn.com/courses?&page=43#courses-grid-start'},
#  {'page': 44,
#   'page_url': 'https://www.futurelearn.com/courses?&page=44#courses-grid-start'},
#  {'page': 45,
#   'page_url': 'https://www.futurelearn.com/courses?&page=45#courses-grid-start'},
#  {'page': 46,
#   'page_url': 'https://www.futurelearn.com/courses?&page=46#courses-grid-start'},
#  {'page': 47,
#   'page_url': 'https://www.futurelearn.com/courses?&page=47#courses-grid-start'},
#  {'page': 48,
#   'page_url': 'https://www.futurelearn.com/courses?&page=48#courses-grid-start'},
#  {'page': 49,
#   'page_url': 'https://www.futurelearn.com/courses?&page=49#courses-grid-start'},
#  {'page': 50,
#   'page_url': 'https://www.futurelearn.com/courses?&page=50#courses-grid-start'},
#  {'page': 51,
#   'page_url': 'https://www.futurelearn.com/courses?&page=51#courses-grid-start'},
#  {'page': 52,
#   'page_url': 'https://www.futurelearn.com/courses?&page=52#courses-grid-start'},
#  {'page': 53,
#   'page_url': 'https://www.futurelearn.com/courses?&page=53#courses-grid-start'},
#  {'page': 54,
#   'page_url': 'https://www.futurelearn.com/courses?&page=54#courses-grid-start'},
#  {'page': 55,
#   'page_url': 'https://www.futurelearn.com/courses?&page=55#courses-grid-start'},
#  {'page': 56,
#   'page_url': 'https://www.futurelearn.com/courses?&page=56#courses-grid-start'},
#  {'page': 57,
#   'page_url': 'https://www.futurelearn.com/courses?&page=57#courses-grid-start'},
#  {'page': 58,
#   'page_url': 'https://www.futurelearn.com/courses?&page=58#courses-grid-start'},
#  {'page': 59,
#   'page_url': 'https://www.futurelearn.com/courses?&page=59#courses-grid-start'},
#  {'page': 60,
#   'page_url': 'https://www.futurelearn.com/courses?&page=60#courses-grid-start'},
#  {'page': 61,
#   'page_url': 'https://www.futurelearn.com/courses?&page=61#courses-grid-start'},
#  {'page': 62,
#   'page_url': 'https://www.futurelearn.com/courses?&page=62#courses-grid-start'},
#  {'page': 63,
#   'page_url': 'https://www.futurelearn.com/courses?&page=63#courses-grid-start'},
#  {'page': 64,
#   'page_url': 'https://www.futurelearn.com/courses?&page=64#courses-grid-start'},
#  {'page': 65,
#   'page_url': 'https://www.futurelearn.com/courses?&page=65#courses-grid-start'},
#  {'page': 66,
#   'page_url': 'https://www.futurelearn.com/courses?&page=66#courses-grid-start'},
#  {'page': 67,
#   'page_url': 'https://www.futurelearn.com/courses?&page=67#courses-grid-start'},
#  {'page': 68,
#   'page_url': 'https://www.futurelearn.com/courses?&page=68#courses-grid-start'},
#  {'page': 69,
#   'page_url': 'https://www.futurelearn.com/courses?&page=69#courses-grid-start'},
#  {'page': 70,
#   'page_url': 'https://www.futurelearn.com/courses?&page=70#courses-grid-start'},
#  {'page': 71,
#   'page_url': 'https://www.futurelearn.com/courses?&page=71#courses-grid-start'},
#  {'page': 72,
#   'page_url': 'https://www.futurelearn.com/courses?&page=72#courses-grid-start'},
#  {'page': 73,
#   'page_url': 'https://www.futurelearn.com/courses?&page=73#courses-grid-start'},
#  {'page': 74,
#   'page_url': 'https://www.futurelearn.com/courses?&page=74#courses-grid-start'},
#  {'page': 75,
#   'page_url': 'https://www.futurelearn.com/courses?&page=75#courses-grid-start'},
#  {'page': 76,
#   'page_url': 'https://www.futurelearn.com/courses?&page=76#courses-grid-start'},
#  {'page': 77,
#   'page_url': 'https://www.futurelearn.com/courses?&page=77#courses-grid-start'},
#  {'page': 78,
#   'page_url': 'https://www.futurelearn.com/courses?&page=78#courses-grid-start'},
#  {'page': 79,
#   'page_url': 'https://www.futurelearn.com/courses?&page=79#courses-grid-start'},
#  {'page': 80,
#   'page_url': 'https://www.futurelearn.com/courses?&page=80#courses-grid-start'},
#  {'page': 81,
#   'page_url': 'https://www.futurelearn.com/courses?&page=81#courses-grid-start'},
#  {'page': 82,
#   'page_url': 'https://www.futurelearn.com/courses?&page=82#courses-grid-start'},
#  {'page': 83,
#   'page_url': 'https://www.futurelearn.com/courses?&page=83#courses-grid-start'},
#  {'page': 84,
#   'page_url': 'https://www.futurelearn.com/courses?&page=84#courses-grid-start'},
#  {'page': 85,
#   'page_url': 'https://www.futurelearn.com/courses?&page=85#courses-grid-start'},
#  {'page': 86,
#   'page_url': 'https://www.futurelearn.com/courses?&page=86#courses-grid-start'},
#  {'page': 87,
#   'page_url': 'https://www.futurelearn.com/courses?&page=87#courses-grid-start'},
#  {'page': 88,
#   'page_url': 'https://www.futurelearn.com/courses?&page=88#courses-grid-start'},
#  {'page': 89,
#   'page_url': 'https://www.futurelearn.com/courses?&page=89#courses-grid-start'},
#  {'page': 90,
#   'page_url': 'https://www.futurelearn.com/courses?&page=90#courses-grid-start'},
#  {'page': 91,
#   'page_url': 'https://www.futurelearn.com/courses?&page=91#courses-grid-start'},
#  {'page': 92,
#   'page_url': 'https://www.futurelearn.com/courses?&page=92#courses-grid-start'},
#  {'page': 93,
#   'page_url': 'https://www.futurelearn.com/courses?&page=93#courses-grid-start'},
#  {'page': 94,
#   'page_url': 'https://www.futurelearn.com/courses?&page=94#courses-grid-start'},
#  {'page': 95,
#   'page_url': 'https://www.futurelearn.com/courses?&page=95#courses-grid-start'}]

# %% [markdown]
# ### 2.3 Getting the course urls
# Each page contains up to 15 courses. The following code retrieves these data and makes a csv file for later use. The sleep time is 1 second. The list of inaccessible page was 0 during the last run. The list of inaccessible pages is included in the code in case the website changes and the code doesn't work anymore

# %%
def make_course_urls(page_urls):
    course_urls = []
    list_of_inaccessible_pages = []                
    for page_url in page_urls:
        try:
            r = requests.get(page_url['page_url'])
            soup = BeautifulSoup(r.text, "html.parser")
            courses = soup.find(class_="cardGrid-wrapper_2TvtF cardGrid-hasSideNav_1sLqj").find_all('div', class_="m-card Container-wrapper_1lZbP Container-grey_1l9VP")
            for course in courses:
                course_url = {}
                course_url['course_url'] = course.find_all('a')[0]['href']
                course_url['page'] = page_url['page']
                course_urls.append(course_url)
        except:
            list_of_inaccessible_pages.append(page_url)
                
        time.sleep(1)
        print(f"Currently scraping page {page_url}")
    print(f"Inaccessible pages: {list_of_inaccessible_pages}")
    print(f"Number of unaccessible pages: {len(list_of_inaccessible_pages)}")
    print(f"Number of courses: {len(course_urls)}")
    print(f"First few courses: {course_urls[0:5]}")
    return course_urls

# %%
course_urls = make_course_urls(page_urls)
# Out:
# Currently scraping page {'page': 1, 'page_url': 'https://www.futurelearn.com/courses?&page=1#courses-grid-start'}
# Currently scraping page {'page': 2, 'page_url': 'https://www.futurelearn.com/courses?&page=2#courses-grid-start'}
# Currently scraping page {'page': 3, 'page_url': 'https://www.futurelearn.com/courses?&page=3#courses-grid-start'}
# Currently scraping page {'page': 4, 'page_url': 'https://www.futurelearn.com/courses?&page=4#courses-grid-start'}
# Currently scraping page {'page': 5, 'page_url': 'https://www.futurelearn.com/courses?&page=5#courses-grid-start'}
# Currently scraping page {'page': 6, 'page_url': 'https://www.futurelearn.com/courses?&page=6#courses-grid-start'}
# Currently scraping page {'page': 7, 'page_url': 'https://www.futurelearn.com/courses?&page=7#courses-grid-start'}
# Currently scraping page {'page': 8, 'page_url': 'https://www.futurelearn.com/courses?&page=8#courses-grid-start'}
# Currently scraping page {'page': 9, 'page_url': 'https://www.futurelearn.com/courses?&page=9#courses-grid-start'}
# Currently scraping page {'page': 10, 'page_url': 'https://www.futurelearn.com/courses?&page=10#courses-grid-start'}
# Currently scraping page {'page': 11, 'page_url': 'https://www.futurelearn.com/courses?&page=11#courses-grid-start'}
# Currently scraping page {'page': 12, 'page_url': 'https://www.futurelearn.com/courses?&page=12#courses-grid-start'}
# Currently scraping page {'page': 13, 'page_url': 'https://www.futurelearn.com/courses?&page=13#courses-grid-start'}
# Currently scraping page {'page': 14, 'page_url': 'https://www.futurelearn.com/courses?&page=14#courses-grid-start'}
# Currently scraping page {'page': 15, 'page_url': 'https://www.futurelearn.com/courses?&page=15#courses-grid-start'}
# Currently scraping page {'page': 16, 'page_url': 'https://www.futurelearn.com/courses?&page=16#courses-grid-start'}
# Currently scraping page {'page': 17, 'page_url': 'https://www.futurelearn.com/courses?&page=17#courses-grid-start'}
# Currently scraping page {'page': 18, 'page_url': 'https://www.futurelearn.com/courses?&page=18#courses-grid-start'}
# Currently scraping page {'page': 19, 'page_url': 'https://www.futurelearn.com/courses?&page=19#courses-grid-start'}
# Currently scraping page {'page': 20, 'page_url': 'https://www.futurelearn.com/courses?&page=20#courses-grid-start'}
# Currently scraping page {'page': 21, 'page_url': 'https://www.futurelearn.com/courses?&page=21#courses-grid-start'}
# Currently scraping page {'page': 22, 'page_url': 'https://www.futurelearn.com/courses?&page=22#courses-grid-start'}
# Currently scraping page {'page': 23, 'page_url': 'https://www.futurelearn.com/courses?&page=23#courses-grid-start'}
# Currently scraping page {'page': 24, 'page_url': 'https://www.futurelearn.com/courses?&page=24#courses-grid-start'}
# Currently scraping page {'page': 25, 'page_url': 'https://www.futurelearn.com/courses?&page=25#courses-grid-start'}
# Currently scraping page {'page': 26, 'page_url': 'https://www.futurelearn.com/courses?&page=26#courses-grid-start'}
# Currently scraping page {'page': 27, 'page_url': 'https://www.futurelearn.com/courses?&page=27#courses-grid-start'}
# Currently scraping page {'page': 28, 'page_url': 'https://www.futurelearn.com/courses?&page=28#courses-grid-start'}
# Currently scraping page {'page': 29, 'page_url': 'https://www.futurelearn.com/courses?&page=29#courses-grid-start'}
# Currently scraping page {'page': 30, 'page_url': 'https://www.futurelearn.com/courses?&page=30#courses-grid-start'}
# Currently scraping page {'page': 31, 'page_url': 'https://www.futurelearn.com/courses?&page=31#courses-grid-start'}
# Currently scraping page {'page': 32, 'page_url': 'https://www.futurelearn.com/courses?&page=32#courses-grid-start'}
# Currently scraping page {'page': 33, 'page_url': 'https://www.futurelearn.com/courses?&page=33#courses-grid-start'}
# Currently scraping page {'page': 34, 'page_url': 'https://www.futurelearn.com/courses?&page=34#courses-grid-start'}
# Currently scraping page {'page': 35, 'page_url': 'https://www.futurelearn.com/courses?&page=35#courses-grid-start'}
# Currently scraping page {'page': 36, 'page_url': 'https://www.futurelearn.com/courses?&page=36#courses-grid-start'}
# Currently scraping page {'page': 37, 'page_url': 'https://www.futurelearn.com/courses?&page=37#courses-grid-start'}
# Currently scraping page {'page': 38, 'page_url': 'https://www.futurelearn.com/courses?&page=38#courses-grid-start'}
# Currently scraping page {'page': 39, 'page_url': 'https://www.futurelearn.com/courses?&page=39#courses-grid-start'}
# Currently scraping page {'page': 40, 'page_url': 'https://www.futurelearn.com/courses?&page=40#courses-grid-start'}
# Currently scraping page {'page': 41, 'page_url': 'https://www.futurelearn.com/courses?&page=41#courses-grid-start'}
# Currently scraping page {'page': 42, 'page_url': 'https://www.futurelearn.com/courses?&page=42#courses-grid-start'}
# Currently scraping page {'page': 43, 'page_url': 'https://www.futurelearn.com/courses?&page=43#courses-grid-start'}
# Currently scraping page {'page': 44, 'page_url': 'https://www.futurelearn.com/courses?&page=44#courses-grid-start'}
# Currently scraping page {'page': 45, 'page_url': 'https://www.futurelearn.com/courses?&page=45#courses-grid-start'}
# Currently scraping page {'page': 46, 'page_url': 'https://www.futurelearn.com/courses?&page=46#courses-grid-start'}
# Currently scraping page {'page': 47, 'page_url': 'https://www.futurelearn.com/courses?&page=47#courses-grid-start'}
# Currently scraping page {'page': 48, 'page_url': 'https://www.futurelearn.com/courses?&page=48#courses-grid-start'}
# Currently scraping page {'page': 49, 'page_url': 'https://www.futurelearn.com/courses?&page=49#courses-grid-start'}
# Currently scraping page {'page': 50, 'page_url': 'https://www.futurelearn.com/courses?&page=50#courses-grid-start'}
# Currently scraping page {'page': 51, 'page_url': 'https://www.futurelearn.com/courses?&page=51#courses-grid-start'}
# Currently scraping page {'page': 52, 'page_url': 'https://www.futurelearn.com/courses?&page=52#courses-grid-start'}
# Currently scraping page {'page': 53, 'page_url': 'https://www.futurelearn.com/courses?&page=53#courses-grid-start'}
# Currently scraping page {'page': 54, 'page_url': 'https://www.futurelearn.com/courses?&page=54#courses-grid-start'}
# Currently scraping page {'page': 55, 'page_url': 'https://www.futurelearn.com/courses?&page=55#courses-grid-start'}
# Currently scraping page {'page': 56, 'page_url': 'https://www.futurelearn.com/courses?&page=56#courses-grid-start'}
# Currently scraping page {'page': 57, 'page_url': 'https://www.futurelearn.com/courses?&page=57#courses-grid-start'}
# Currently scraping page {'page': 58, 'page_url': 'https://www.futurelearn.com/courses?&page=58#courses-grid-start'}
# Currently scraping page {'page': 59, 'page_url': 'https://www.futurelearn.com/courses?&page=59#courses-grid-start'}
# Currently scraping page {'page': 60, 'page_url': 'https://www.futurelearn.com/courses?&page=60#courses-grid-start'}
# Currently scraping page {'page': 61, 'page_url': 'https://www.futurelearn.com/courses?&page=61#courses-grid-start'}
# Currently scraping page {'page': 62, 'page_url': 'https://www.futurelearn.com/courses?&page=62#courses-grid-start'}
# Currently scraping page {'page': 63, 'page_url': 'https://www.futurelearn.com/courses?&page=63#courses-grid-start'}
# Currently scraping page {'page': 64, 'page_url': 'https://www.futurelearn.com/courses?&page=64#courses-grid-start'}
# Currently scraping page {'page': 65, 'page_url': 'https://www.futurelearn.com/courses?&page=65#courses-grid-start'}
# Currently scraping page {'page': 66, 'page_url': 'https://www.futurelearn.com/courses?&page=66#courses-grid-start'}
# Currently scraping page {'page': 67, 'page_url': 'https://www.futurelearn.com/courses?&page=67#courses-grid-start'}
# Currently scraping page {'page': 68, 'page_url': 'https://www.futurelearn.com/courses?&page=68#courses-grid-start'}
# Currently scraping page {'page': 69, 'page_url': 'https://www.futurelearn.com/courses?&page=69#courses-grid-start'}
# Currently scraping page {'page': 70, 'page_url': 'https://www.futurelearn.com/courses?&page=70#courses-grid-start'}
# Currently scraping page {'page': 71, 'page_url': 'https://www.futurelearn.com/courses?&page=71#courses-grid-start'}
# Currently scraping page {'page': 72, 'page_url': 'https://www.futurelearn.com/courses?&page=72#courses-grid-start'}
# Currently scraping page {'page': 73, 'page_url': 'https://www.futurelearn.com/courses?&page=73#courses-grid-start'}
# Currently scraping page {'page': 74, 'page_url': 'https://www.futurelearn.com/courses?&page=74#courses-grid-start'}
# Currently scraping page {'page': 75, 'page_url': 'https://www.futurelearn.com/courses?&page=75#courses-grid-start'}
# Currently scraping page {'page': 76, 'page_url': 'https://www.futurelearn.com/courses?&page=76#courses-grid-start'}
# Currently scraping page {'page': 77, 'page_url': 'https://www.futurelearn.com/courses?&page=77#courses-grid-start'}
# Currently scraping page {'page': 78, 'page_url': 'https://www.futurelearn.com/courses?&page=78#courses-grid-start'}
# Currently scraping page {'page': 79, 'page_url': 'https://www.futurelearn.com/courses?&page=79#courses-grid-start'}
# Currently scraping page {'page': 80, 'page_url': 'https://www.futurelearn.com/courses?&page=80#courses-grid-start'}
# Currently scraping page {'page': 81, 'page_url': 'https://www.futurelearn.com/courses?&page=81#courses-grid-start'}
# Currently scraping page {'page': 82, 'page_url': 'https://www.futurelearn.com/courses?&page=82#courses-grid-start'}
# Currently scraping page {'page': 83, 'page_url': 'https://www.futurelearn.com/courses?&page=83#courses-grid-start'}
# Currently scraping page {'page': 84, 'page_url': 'https://www.futurelearn.com/courses?&page=84#courses-grid-start'}
# Currently scraping page {'page': 85, 'page_url': 'https://www.futurelearn.com/courses?&page=85#courses-grid-start'}
# Currently scraping page {'page': 86, 'page_url': 'https://www.futurelearn.com/courses?&page=86#courses-grid-start'}
# Currently scraping page {'page': 87, 'page_url': 'https://www.futurelearn.com/courses?&page=87#courses-grid-start'}
# Currently scraping page {'page': 88, 'page_url': 'https://www.futurelearn.com/courses?&page=88#courses-grid-start'}
# Currently scraping page {'page': 89, 'page_url': 'https://www.futurelearn.com/courses?&page=89#courses-grid-start'}
# Currently scraping page {'page': 90, 'page_url': 'https://www.futurelearn.com/courses?&page=90#courses-grid-start'}
# Currently scraping page {'page': 91, 'page_url': 'https://www.futurelearn.com/courses?&page=91#courses-grid-start'}
# Currently scraping page {'page': 92, 'page_url': 'https://www.futurelearn.com/courses?&page=92#courses-grid-start'}
# Currently scraping page {'page': 93, 'page_url': 'https://www.futurelearn.com/courses?&page=93#courses-grid-start'}
# Currently scraping page {'page': 94, 'page_url': 'https://www.futurelearn.com/courses?&page=94#courses-grid-start'}
# Currently scraping page {'page': 95, 'page_url': 'https://www.futurelearn.com/courses?&page=95#courses-grid-start'}
# Inaccessible pages: []
# Number of unaccessible pages: 0
# Number of courses: 1513
# First few courses: [{'course_url': '/courses/anatomy-know-your-abdomen', 'page': 1}, {'course_url': '/courses/atmospheric-chemistry-planets-and-life-beyond-earth', 'page': 1}, {'course_url': '/courses/business-ethics', 'page': 1}, {'course_url': '/courses/human-disease-exploring-cancer-genetic-disease', 'page': 1}, {'course_url': '/courses/human-disease-lifestyle-environment', 'page': 1}]

# %%
with open("../../gen/input/futurelearn_course_urls.csv", "w", encoding = "UTF-8") as csv_file:
    writer = csv.writer(csv_file, delimiter = ";")
    writer.writerow(['course_url', 'page'])
    for course_url in course_urls:
        writer.writerow([course_url['course_url'], course_url['page']])

# %% [markdown]
# ## 3 Data Collection

# %% [markdown]
# ### 3.1 Getting the course info
# The following function retrieves the following data on each page:
# - Url: The complete url of the course
# - Time: The exact time the data were scraped
# - Page: The page from the category
# - Category: The name of the category
# - Header: The header of the course
# - Enrollment: The number of enrollments of the course. Note that new courses do not have the information yet
# - New: Dummy showing whether the course is new
# - Star_rating: The number of stars in a given course
# - Review_count: Variable showing how many reviews there are
# - Description: Short description of the course
# - Duration: Duration of the course in weeks
# - Weekly_study: Study time required on a weekly bases
# - Unlimited: Dummy showing whether you can access this course with a so-called "unlimited" subscription
# - 100_online: Dummy showing whether the course is for 100% online
# - Free: Dummy showing whether the course is for free. Not_present meaning it's not free
# - Accreditation: Dummy showing whether the course is eligible for accreditation
# - Part_of_expert: Dummy showing whether the course is part of a larger expert course
# - Name_school: The name of the school that teaches the course
# - Endorsed: Dummy showing whether the course is endorsed by third parties.
#
# Although the course page contained more information (e.g. in-depth course descriptions, numerous teachers), the variables above are relevant for an analysis. The sleep time is 1 second per retrieval

# %%
def get_course_info(course_url):
    course_info = {}
    complete_url = f"https://www.futurelearn.com{course_url['course_url']}"
    r = requests.get(complete_url)
    soup = BeautifulSoup(r.text, "html.parser")
    
    #META-DATA
    ##url
    course_info['url'] = complete_url
    
    ##time
    course_info['Time'] = datetime.now()
    
    ##page
    course_info['page'] = course_url['page']
    
    ##category
    try:
        course_info['category'] = soup.find_all('li', class_ = "breadcrumbs-module_item__3SxlK")[1].text
    except:
        course_info['category'] = ''
    
    #HEADER
    try:
        course_info['Header'] = soup.find('h1').text
    except:
        course_info['Header'] = ''
        
    #NUMBER OF ENROLLMENTS
    try:
        course_info['Enrollments'] = soup.find('div', class_="spacer-module_default__3N2H9 spacer-module_vertical-4__5ZLo8").find('p', class_ = "text-module_wrapper__FfvIV text-module_black__2u5Rt text-module_sBreakpointSizexsmall__2Jlmd text-module_sBreakpointAlignmentleft__1MvbB text-module_isRegular__1K97K").text
    except:
        course_info['Enrollments'] = ''
    
    #NEW COURSE
    try:
        if soup.find('span', class_ = "Ribbon-module_wrapper__312EV Ribbon-module_coral__B1J53 Ribbon-module_isUppercase__1NTSw").text == 'New':
            course_info['New'] = 'yes'
        else:
            course_info['New'] = 'no' 
    except:
        course_info['New'] = 'no'

    #STAR RATING
    try:
        course_info['star_rating'] = soup.find(class_="spacer-module_default__3N2H9 spacer-module_left-1__1AJxh").text.split()[0]
    except:
        course_info['star_rating'] = ''
    
    #NUM OF REVIEWS
    try:
        course_info['review_count'] = soup.find('div', class_="ReviewStars-text_mSEFD").find('span').text
    except:
        course_info['review_count'] = ''
        
    #DESCRIPTION
    try:
        course_info['description'] = soup.find('div', class_ = "stack-module_wrapper__3ZERF").find(class_="text-module_wrapper__FfvIV text-module_black__2u5Rt text-module_sBreakpointSizemedium__2qitW text-module_mBreakpointSizemedium__1_OnK text-module_lBreakpointSizemedium__1Yq39 text-module_xlBreakpointSizemedium__1nNCx text-module_xxlBreakpointSizelarge__1uhrp text-module_sBreakpointAlignmentleft__1MvbB text-module_isRegular__1K97K").text
    except:
        course_info['description'] = ''
    
    #INFO COURSE
    try:
        for li in soup.find('div', class_ = "PageHeader-keyInfoWrapper_39HpT").find_all(class_="keyInfo-module_itemText__3w63w"):
            ## Top part of cell
            table_header = li.find(class_ = "text-module_wrapper__FfvIV text-module_mediumGrey__1uvOt text-module_sBreakpointSizesmall__3K4b4 text-module_sBreakpointAlignmentleft__1MvbB text-module_isInline__m5cFK text-module_isRegular__1K97K").text
            ## Lower part of cell
            table_text = li.find(class_ = "keyInfo-module_content__1K_85").text
            if table_header == 'Duration':
                course_info['Duration'] = table_text
            if table_header == 'Weekly study':
                course_info['Weekly_study'] = table_text
            if table_header == 'Unlimited':
                course_info['Unlimited'] = 'yes'
            if table_header == '100% online':
                course_info['100_online'] = 'yes'
            if table_header == 'Digital upgrade':
                course_info['Free'] = 'yes'
            if table_header == 'Accreditation':
                course_info['Accreditation'] = 'yes'
            if table_header == "Included in an ExpertTrack":
                course_info['Part_of_Expert'] = 'yes'
        table_headers_options = ['Duration', 'Weekly_study', 'Unlimited', '100_online', 'Free', 'Accreditation', 'Part_of_Expert']
        ##Looks whether a cell is missing
        for table_headers_option in table_headers_options:
            if table_headers_option not in course_info:
                course_info[table_headers_option] = 'no'
    ##If there's an error in loading the table, place empty values
    except:
        for table_headers_option in table_headers_options:
            course_info[table_headers_option] = ''
    
    #NAME SCHOOL
    try:
        course_info['Name_school'] = soup.find('h2', class_="heading-module_wrapper__2dcxt heading-module_sBreakpointAlignmentleft__pCA_Y heading-module_sBreakpointSizelarge__SiUxO heading-module_black__Uge9G heading-module_isRegular__2NZyV").text
    except:
        course_info['Name_school'] = ''
    print(f"Currently scraping: {course_info['Header']}")
    
    #ENDORSERS (Check how often present)
    try:
        if soup.find('h2', class_ = "heading-module_wrapper__2dcxt heading-module_sBreakpointAlignmentcenter__2R3nG heading-module_sBreakpointSizelarge__SiUxO heading-module_black__Uge9G heading-module_isRegular__2NZyV").text == 'Endorsers and supporters':
            course_info['Endorsed'] = 'yes'
        else:
            course_info['Endorsed'] = 'no'
    except:
        course_info['Endorsed'] = 'no'
    time.sleep(1)
    return course_info

# %% [markdown]
# ### 3.2 Scraping each course page and saving it in csv
# The following code uses the function above to retrieve the relevant data of each page and stores it into a csv file. Note the delimiter is a ';'. The length of the list of inaccessable courses was 0 during the last run. It takes about an hour to complete.

# %%
def write_data(course_urls):
    courses_info = []
    list_of_inaccessable_courses = []
    counter = 1
    length_course_urls = len(course_urls)
    with open("../../gen/output/futurelearn_data.csv", "w", encoding = "UTF-8") as csv_file:
        writer = csv.writer(csv_file, delimiter = ";")
        writer.writerow(['Url', 'Time', 'Page', 'Category', 'Header', 'Enrollments', 'New', 'Star_rating', 'Review_count', 'Description', 'Duration', 'Weekly_study', 'Unlimited', '100_online', 'Free', 'Accreditation', 'Part_of_Expert', 'Name_school', 'Endorsed'])
        for course_url in course_urls:
            try:
                course_info = get_course_info(course_url)
                courses_info.append(course_info)
                writer.writerow([course_info['url'], course_info['Time'], course_info['page'], course_info['category'], course_info['Header'], course_info['Enrollments'], course_info['New'], course_info['star_rating'], course_info['review_count'], course_info['description'], course_info['Duration'], course_info['Weekly_study'], course_info['Unlimited'], course_info['100_online'], course_info['Free'], course_info['Accreditation'], course_info['Part_of_Expert'], course_info['Name_school'], course_info['Endorsed']])
            except:
                list_of_inaccessable_courses.append(course_url)
            print(f'Processing... [{counter}/{length_course_urls}]')
            counter += 1
    print(f"Courses it couldn't access: {list_of_inaccessable_courses}")
    print(f"Couldn't access {len(list_of_inaccessable_courses)} courses")
    return courses_info

# %%
write_data(course_urls)
end_time = datetime.now()
print("Time it took to scrape: " + str(end_time - start_time))
# Out:
# Currently scraping: Anatomy: Know Your Abdomen
# Processing... [1/1513]
# Currently scraping: Atmospheric Chemistry: Planets and Life Beyond Earth
# Processing... [2/1513]
# Currently scraping: Business Ethics: Exploring Big Data and Tax Avoidance
# Processing... [3/1513]
# Currently scraping: Causes of Human Disease: Exploring Cancer and Genetic Disease
# Processing... [4/1513]
# Currently scraping: Causes of Human Disease: Nutrition and Environment
# Processing... [5/1513]
# Currently scraping: Causes of Human Disease: Transmitting and Fighting Infection
# Processing... [6/1513]
# Currently scraping: Causes of Human Disease: Understanding Cardiovascular Disease
# Processing... [7/1513]
# Currently scraping: Causes of Human Disease: Understanding Causes of Disease
# Processing... [8/1513]
# Currently scraping: Clinical Bioinformatics: Unlocking Genomics in Healthcare
# Processing... [9/1513]
# Currently scraping: Communication and Interpersonal Skills at Work
# Processing... [10/1513]
# Currently scraping: Community Based Research: Getting Started
# Processing... [11/1513]
# Currently scraping: Computer Programming for Everyone
# Processing... [12/1513]
# Currently scraping: Critical Thinking at University: An Introduction
# Processing... [13/1513]
# Currently scraping: Design Board Games for Socio-Political Change
# Processing... [14/1513]
# Currently scraping: Discovering Science: Atmospheric Chemistry
# Processing... [15/1513]
# Currently scraping: Discovering Science: Chemical Products
# Processing... [16/1513]
# Currently scraping: Discovering Science: Global Challenges
# Processing... [17/1513]
# Currently scraping: Discovering Science: Medicinal Chemistry
# Processing... [18/1513]
# Currently scraping: Discovering Science: Science Writing
# Processing... [19/1513]
# Currently scraping: Ecology and Wildlife Conservation
# Processing... [20/1513]
# Currently scraping: Environmental Challenges: Scarcity and Conflict in the Natural Environment
# Processing... [21/1513]
# Currently scraping: Essential Skills for Your Career Development
# Processing... [22/1513]
# Currently scraping: Essentials in Arts Fundraising
# Processing... [23/1513]
# Currently scraping: Exploring Cancer Medicines
# Processing... [24/1513]
# Currently scraping: Food Science and Nutrition: From the Farm to You
# Processing... [25/1513]
# Currently scraping: Incarceration: Are Prisons a Suitable Punishment?
# Processing... [26/1513]
# Currently scraping: Innovation: the Fashion Industry
# Processing... [27/1513]
# Currently scraping: Innovation: the World's Greatest
# Processing... [28/1513]
# Currently scraping: Instructional Design and Technology for Society
# Processing... [29/1513]
# Currently scraping: Interdisciplinary Learning: Working Across Disciplines
# Processing... [30/1513]
# Currently scraping: Introduction to Criminology
# Processing... [31/1513]
# Currently scraping: Introduction to Effective Network Analysis
# Processing... [32/1513]
# Currently scraping: Introduction to Intercultural Studies: Crossing Borders
# Processing... [33/1513]
# Currently scraping: Introduction to Intercultural Studies: Defining the Concept of Culture
# Processing... [34/1513]
# Currently scraping: Introduction to Intercultural Studies: Intercultural Contact
# Processing... [35/1513]
# Currently scraping: Introduction to Intercultural Studies: Language and Culture
# Processing... [36/1513]
# Currently scraping: Introduction to Intercultural Studies: The Branding of Culture
# Processing... [37/1513]
# Currently scraping: Introduction to Maintenance Engineering
# Processing... [38/1513]
# Currently scraping: Introduction to Research Ethics: Working with People
# Processing... [39/1513]
# Currently scraping: Learning Online: Communicating and Collaborating
# Processing... [40/1513]
# Currently scraping: Learning Online: Managing Your Online Identity
# Processing... [41/1513]
# Currently scraping: Learning Online: Researching Your Project
# Processing... [42/1513]
# Currently scraping: Learning Online: Studying and Reflecting
# Processing... [43/1513]
# Currently scraping: Maqasid Al-Shariah and Sustainable Development
# Processing... [44/1513]
# Currently scraping: MedTech: AI and Medical Robots
# Processing... [45/1513]
# Currently scraping: MedTech: Digital Health and Wearable Technology
# Processing... [46/1513]
# Currently scraping: MedTech: Exploring the Human Genome
# Processing... [47/1513]
# Currently scraping: MedTech: Orthopaedic Implants and Regenerative Medicine
# Processing... [48/1513]
# Currently scraping: MedTech: Trends and Product Design
# Processing... [49/1513]
# Currently scraping: Physical Theatre: Exploring the Slap
# Processing... [50/1513]
# Currently scraping: Preparing to Learn Online at University
# Processing... [51/1513]
# Currently scraping: Skills to Succeed at University
# Processing... [52/1513]
# Currently scraping: Starting a Business 1: Vision and Opportunity
# Processing... [53/1513]
# Currently scraping: Starting a Business 2: People and Networks
# Processing... [54/1513]
# Currently scraping: Starting a Business 3: Customers and Competitors
# Processing... [55/1513]
# Currently scraping: Starting a Business 4: Business Processes
# Processing... [56/1513]
# Currently scraping: Starting a Business 5: Managing Finances
# Processing... [57/1513]
# Currently scraping: Starting a Business 6: Funding Your Business
# Processing... [58/1513]
# Currently scraping: Transport Systems: Global Issues and Future Innovations
# Processing... [59/1513]
# Currently scraping: WW1 Heroism: Through Art and Film
# Processing... [60/1513]
# Currently scraping: William Wordsworth: Poetry, People and Place
# Processing... [61/1513]
# Currently scraping: Anti-Racist Approaches in Technology
# Processing... [62/1513]
# Currently scraping: Film Distribution: Connecting Films with Audiences
# Processing... [63/1513]
# Currently scraping: Gender and Labour in the Global South
# Processing... [64/1513]
# Currently scraping: Gender-Inclusive Approaches in Technology
# Processing... [65/1513]
# Currently scraping: HR Fundamentals
# Processing... [66/1513]
# Currently scraping: How To Support Young People Living with Parental Mental Illness
# Processing... [67/1513]
# Currently scraping: How to Succeed at: Writing Applications
# Processing... [68/1513]
# Currently scraping: Inclusive Education: Essential Knowledge for Success
# Processing... [69/1513]
# Currently scraping: Information Security for Beginners
# Processing... [70/1513]
# Currently scraping: Introduction to Data Science for Educators
# Processing... [71/1513]
# Currently scraping: Introduction to Norwegian 2
# Processing... [72/1513]
# Currently scraping: Investigating a Murder with Forensic Psychology
# Processing... [73/1513]
# Currently scraping: Learning for a Sustainable Future
# Processing... [74/1513]
# Currently scraping: Managing Big Data with R and Hadoop
# Processing... [75/1513]
# Currently scraping: Managing Change in a Healthcare Environment
# Processing... [76/1513]
# Currently scraping: Mysteries Of The Universe
# Processing... [77/1513]
# Currently scraping: Occupational Health in Developing Countries
# Processing... [78/1513]
# Currently scraping: People Management Skills
# Processing... [79/1513]
# Currently scraping: Supporting Diverse Innovation
# Processing... [80/1513]
# Currently scraping: Working with Translation: Theory and Practice
# Processing... [81/1513]
# Currently scraping: Advanced Agile with Scrum and Kanban
# Processing... [82/1513]
# Currently scraping: Agile for Beginners
# Processing... [83/1513]
# Currently scraping: An Anthropology of Smartphones: Communication, Ageing and Health
# Processing... [84/1513]
# Currently scraping: Business Futures: Sustainable Business Through Green HR
# Processing... [85/1513]
# Currently scraping: Business Futures: Understanding Omni-channel Retailing and Supply Chains
# Processing... [86/1513]
# Currently scraping: CBT with Older People
# Processing... [87/1513]
# Currently scraping: Cancer Survivorship for Primary Care Practitioners
# Processing... [88/1513]
# Currently scraping: Communicating across Cultures
# Processing... [89/1513]
# Currently scraping: Conducting Remote Consultations and Triage
# Processing... [90/1513]
# Currently scraping: Creating an Inclusive Classroom: Approaches to Supporting Learners with SEND in Computing
# Processing... [91/1513]
# Currently scraping: Data Representation in Computing: Bring Data to Life
# Processing... [92/1513]
# Currently scraping: Developing and Testing Complex Healthcare Interventions
# Processing... [93/1513]
# Currently scraping: Digital Marketing in Perspective
# Processing... [94/1513]
# Currently scraping: Digital Marketing: Content Marketing
# Processing... [95/1513]
# Currently scraping: Digital Marketing: Marketing Channel Objectives
# Processing... [96/1513]
# Currently scraping: Digital Marketing: Personas and User Journeys
# Processing... [97/1513]
# Currently scraping: Edward Jenner: 0 - An Introduction to Personal Development
# Processing... [98/1513]
# Currently scraping: English as a Medium of Instruction for Academics
# Processing... [99/1513]
# Currently scraping: Environmental Challenges: Human Impact in the Natural Environment
# Processing... [100/1513]
# Currently scraping: Evidence-Based Medicine in Clinical Pharmacy Practice
# Processing... [101/1513]
# Currently scraping: Gender and Development
# Processing... [102/1513]
# Currently scraping: Genealogy: Researching Your Family Tree
# Processing... [103/1513]
# Currently scraping: Good Pharmacy Practice: Introduction to Clinical Pharmacy Services
# Processing... [104/1513]
# Currently scraping: Good Pharmacy Practice: Introduction to Medication Delivery Systems
# Processing... [105/1513]
# Currently scraping: Good Pharmacy Practice: Medication Management
# Processing... [106/1513]
# Currently scraping: Good Pharmacy Practice: Pharmaceutical Services
# Processing... [107/1513]
# Currently scraping: Governing Religion: Global Challenges and Comparative Approaches
# Processing... [108/1513]
# Currently scraping: Introduction to Encryption and Cryptography
# Processing... [109/1513]
# Currently scraping: Introduction to Humanitarian Aid
# Processing... [110/1513]
# Currently scraping: Introduction to Nutrition and Food Safety
# Processing... [111/1513]
# Currently scraping: Introduction to Sustainability and Development
# Processing... [112/1513]
# Currently scraping: Introduction to Translational Research: Connecting Scientists and Medical Doctors
# Processing... [113/1513]
# Currently scraping: Irish 103: An Introduction to Irish Language and Culture
# Processing... [114/1513]
# Currently scraping: Irish 203: Irish Language and Culture for Adults
# Processing... [115/1513]
# Currently scraping: Making Climate Adaptation Happen: Governing Transformation Strategies for Climate Change
# Processing... [116/1513]
# Currently scraping: Medical Humanity: Engaging Patients and Communities in Healthcare
# Processing... [117/1513]
# Currently scraping: Nutrition and Disease Prevention
# Processing... [118/1513]
# Currently scraping: Nutrition: Eating to Live Well
# Processing... [119/1513]
# Currently scraping: Pharmacokinetics: Drug Dosing in Renal Disease
# Processing... [120/1513]
# Currently scraping: Scaled Agile
# Processing... [121/1513]
# Currently scraping: Social Media in Healthcare: Opportunities and Challenges
# Processing... [122/1513]
# Currently scraping: Study UK: A Guide for Education Agents
# Processing... [123/1513]
# Currently scraping: Teaching Phonics in Early Childhood
# Processing... [124/1513]
# Currently scraping: Teaching Physical Computing with Raspberry Pi and Python
# Processing... [125/1513]
# Currently scraping: Teaching Students Who Have Suffered Complex Trauma
# Processing... [126/1513]
# Currently scraping: Telemedicine: Tools to Support Growth Disorders in a Post-COVID Era
# Processing... [127/1513]
# Currently scraping: Transforming Digital Learning: Learning Design Meets Service Design
# Processing... [128/1513]
# Currently scraping: A Reporter’s Toolkit for the Digital Age
# Processing... [129/1513]
# Currently scraping: An Introduction to Digital Manufacturing and 3D Printing
# Processing... [130/1513]
# Currently scraping: Becoming a Better Music Teacher
# Processing... [131/1513]
# Currently scraping: Carbon Markets: Examining EU Policies for Transnational Climate Action
# Processing... [132/1513]
# Currently scraping: Clinical Supervision with Confidence
# Processing... [133/1513]
# Currently scraping: Decoding Forensics for Legal Professionals
# Processing... [134/1513]
# Currently scraping: Digital Skills: Artificial Intelligence
# Processing... [135/1513]
# Currently scraping: Digital Skills: Digital Marketing
# Processing... [136/1513]
# Currently scraping: Digital Skills: Digital Skills for Work and Life
# Processing... [137/1513]
# Currently scraping: Digital Skills: Mobile
# Processing... [138/1513]
# Currently scraping: Digital Skills: Social Media
# Processing... [139/1513]
# Currently scraping: Digital Skills: User Experience
# Processing... [140/1513]
# Currently scraping: Digital Skills: Web Analytics
# Processing... [141/1513]
# Currently scraping: Education for All: Disability, Diversity and Inclusion
# Processing... [142/1513]
# Currently scraping: Electrification of Urban Mobility: How to Get it Right
# Processing... [143/1513]
# Currently scraping: English Grammar for Teachers
# Processing... [144/1513]
# Currently scraping: Examining African Contributions to Global Health
# Processing... [145/1513]
# Currently scraping: Exploring Anatomy: the Human Abdomen
# Processing... [146/1513]
# Currently scraping: Extinctions: Past and Present
# Processing... [147/1513]
# Currently scraping: Food and Mood: Improving Mental Health Through Diet and Nutrition
# Processing... [148/1513]
# Currently scraping: Forensic Mental Health and Criminal Justice
# Processing... [149/1513]
# Currently scraping: Fun in Korea: Useful Expressions and Cultural Information for Travellers
# Processing... [150/1513]
# Currently scraping: How to Succeed at: Interviews
# Processing... [151/1513]
# Currently scraping: Innovative Teaching: Engaging Adult Learners with Active Learning
# Processing... [152/1513]
# Currently scraping: Introduction to VR Programming, Design, and Unity
# Processing... [153/1513]
# Currently scraping: Leading Culturally Diverse Teams in the Workplace
# Processing... [154/1513]
# Currently scraping: Medicine and the Arts: Humanising Healthcare
# Processing... [155/1513]
# Currently scraping: Nutrition Science: Food Choice and Behaviour
# Processing... [156/1513]
# Currently scraping: Nutrition Science: Lifestyle Medicine
# Processing... [157/1513]
# Currently scraping: Nutrition Science: Obesity and Healthy Weight Loss
# Processing... [158/1513]
# Currently scraping: One-Sided Communication and the MPI Shared Memory Interface
# Processing... [159/1513]
# Currently scraping: PSHE Education: Helping Children Navigate a Complex World
# Processing... [160/1513]
# Currently scraping: Physiotherapy Exercise and Physical Activity for Knee Osteoarthritis (PEAK - ESPAÑOL)
# Processing... [161/1513]
# Currently scraping: Power Dressing in the Zoom Era
# Processing... [162/1513]
# Currently scraping: Teaching Climate and Sustainability in Primary Schools: An Outdoor Learning Approach
# Processing... [163/1513]
# Currently scraping: Teaching the Holocaust: Innovative Approaches to the Challenges We Face
# Processing... [164/1513]
# Currently scraping: The Power of Object-Oriented Programming
# Processing... [165/1513]
# Currently scraping: Transforming Urban Mobility: Governing the Transformation to Sustainable Systems
# Processing... [166/1513]
# Currently scraping: Transgender Healthcare: Caring for Trans Patients
# Processing... [167/1513]
# Currently scraping: Using Infection Control to Combat Antimicrobial Resistance
# Processing... [168/1513]
# Currently scraping: Vehicle-to-Grid Charging for Electric Cars
# Processing... [169/1513]
# Currently scraping: What Drives the Body?
# Processing... [170/1513]
# Currently scraping: What is a Mind?
# Processing... [171/1513]
# Currently scraping: A Beginner’s Guide to Becoming a Blockchain Developer with Overledger
# Processing... [172/1513]
# Currently scraping: AI and Big Data in Global Health Improvement
# Processing... [173/1513]
# Currently scraping: AWS Cloud Technical Essentials
# Processing... [174/1513]
# Currently scraping: Agriculture and Nutrition
# Processing... [175/1513]
# Currently scraping: Application of Digital Health Interventions
# Processing... [176/1513]
# Currently scraping: Applications of AI Technology
# Processing... [177/1513]
# Currently scraping: Artificial Intelligence for Healthcare: Opportunities and Challenges
# Processing... [178/1513]
# Currently scraping: Artificial Intelligence in Bioinformatics
# Processing... [179/1513]
# Currently scraping: Become a Pharmacy Preceptor
# Processing... [180/1513]
# Currently scraping: Blended and Online Learning Design
# Processing... [181/1513]
# Currently scraping: Capacity Building: Core Competencies for Health Promotion
# Processing... [182/1513]
# Currently scraping: Clinical Pharmacokinetics: Dosing and Monitoring
# Processing... [183/1513]
# Currently scraping: Digital Health for Cancer Management: Smart Health Technologies in Complex Diseases
# Processing... [184/1513]
# Currently scraping: Educational Leadership: Improving Schools through Effective Leadership
# Processing... [185/1513]
# Currently scraping: Environmental Challenges: Hierarchy in Property Rights
# Processing... [186/1513]
# Currently scraping: Essentials of Good Pharmacy Practice: The Basics
# Processing... [187/1513]
# Currently scraping: Exploring Teaching and Assessment for Higher Education
# Processing... [188/1513]
# Currently scraping: Indigeneity as a Global Concept
# Processing... [189/1513]
# Currently scraping: Inside the UK Supreme Court: Its Role, Its Work, and Cases that Affect Us All
# Processing... [190/1513]
# Currently scraping: Introduction to Dutch
# Processing... [191/1513]
# Currently scraping: Low-Budget Video Production: Visual Communication for Small Charities
# Processing... [192/1513]
# Currently scraping: Measuring Economic Inequality in Today’s World
# Processing... [193/1513]
# Currently scraping: Music and Intelligence: Can Music Make You Smarter?
# Processing... [194/1513]
# Currently scraping: Playing with Poetry: Creative Writing and Poetics
# Processing... [195/1513]
# Currently scraping: Statistical Shape Modelling: Computing the Human Anatomy
# Processing... [196/1513]
# Currently scraping: Teacher Training: Choosing the Right PGCE for You
# Processing... [197/1513]
# Currently scraping: Teaching Climate Change
# Processing... [198/1513]
# Currently scraping: Urban Mobility for Liveability
# Processing... [199/1513]
# Currently scraping: Cognitive Behavioural Skills to Treat Back Pain: The Back Skills Training (BeST) Programme
# Processing... [200/1513]
# Currently scraping: Conceptual Thinking in Practice
# Processing... [201/1513]
# Currently scraping: Defensive Programming and Debugging
# Processing... [202/1513]
# Currently scraping: Digital Discovery
# Processing... [203/1513]
# Currently scraping: End of Life Care: Challenges and Innovation
# Processing... [204/1513]
# Currently scraping: Helping patients recover from breast cancer treatment: a programme to prevent shoulder problems
# Processing... [205/1513]
# Currently scraping: Introduction to Parallel Programming
# Processing... [206/1513]
# Currently scraping: Introduction to Programming with Scratch
# Processing... [207/1513]
# Currently scraping: Learn English Through TV Drama Series: Adrift
# Processing... [208/1513]
# Currently scraping: Learn English Through TV Drama Series: My Name is Lucky
# Processing... [209/1513]
# Currently scraping: Moons
# Processing... [210/1513]
# Currently scraping: Solving Sustainability Challenges with Te Ao Māori (Māori World View)
# Processing... [211/1513]
# Currently scraping: The Design Thinking Toolbox
# Processing... [212/1513]
# Currently scraping: The Online Educator: People and Pedagogy
# Processing... [213/1513]
# Currently scraping: The School for Change Agents
# Processing... [214/1513]
# Currently scraping: Unleash Your Potential: Global Citizenship
# Processing... [215/1513]
# Currently scraping: Unleash Your Potential: Innovation and Enterprise
# Processing... [216/1513]
# Currently scraping: Unleash Your Potential: Sustainable Futures
# Processing... [217/1513]
# Currently scraping: Young People and Mental Health
# Processing... [218/1513]
# Currently scraping: Crisis Leadership
# Processing... [219/1513]
# Currently scraping: Emotional Intelligence in Practice
# Processing... [220/1513]
# Currently scraping: Environmental Challenges: Rights and Values in Ecosystem Services
# Processing... [221/1513]
# Currently scraping: Exploring the Landscape of Antibiotic Resistance in Microbiomes
# Processing... [222/1513]
# Currently scraping: How Does the Body Use DNA as a Blueprint?
# Processing... [223/1513]
# Currently scraping: Hurricane Tracking with Satellite Data
# Processing... [224/1513]
# Currently scraping: Improving Computing Classroom Practice Through Action Research
# Processing... [225/1513]
# Currently scraping: Irish 102: An Introduction to Irish Language and Culture
# Processing... [226/1513]
# Currently scraping: Irish 202: Irish Language and Culture for Adults
# Processing... [227/1513]
# Currently scraping: Study UK: Preparing for work
# Processing... [228/1513]
# Currently scraping: The Discovery of the Higgs Boson
# Processing... [229/1513]
# Currently scraping: Train the Healthcare Trainer
# Processing... [230/1513]
# Currently scraping: Airway Matters
# Processing... [231/1513]
# Currently scraping: Caring for Older People: a Partnership Model
# Processing... [232/1513]
# Currently scraping: Climate Change and Public Policy
# Processing... [233/1513]
# Currently scraping: Competitive Advantage: Using Information to Build Business Success
# Processing... [234/1513]
# Currently scraping: Dementia Inclusive Hospitals from a Universal Design Approach
# Processing... [235/1513]
# Currently scraping: Digital Tools for Efficient Clinical Trials
# Processing... [236/1513]
# Currently scraping: Filmmaking and Animation Online and in the Classroom
# Processing... [237/1513]
# Currently scraping: Global Education for Teachers
# Processing... [238/1513]
# Currently scraping: HSK Standard Course Level 1: 1.1
# Processing... [239/1513]
# Currently scraping: IT Ethics: Professionalism and Ethics in Computing
# Processing... [240/1513]
# Currently scraping: Improve Student Assessment with Microsoft Forms
# Processing... [241/1513]
# Currently scraping: Inclusive Learning with Microsoft Accessibility Tools
# Processing... [242/1513]
# Currently scraping: Inclusive Management and Leadership Skills
# Processing... [243/1513]
# Currently scraping: Infant Nutrition: from Breastfeeding to Baby's First Solids
# Processing... [244/1513]
# Currently scraping: Introduction to Anatomy: Learning the Anatomical Alphabet
# Processing... [245/1513]
# Currently scraping: Introduction to Norwegian
# Processing... [246/1513]
# Currently scraping: Introduction to Randomised Controlled Trials
# Processing... [247/1513]
# Currently scraping: Investigating Innovation
# Processing... [248/1513]
# Currently scraping: Manage and Create Documents in Microsoft 365
# Processing... [249/1513]
# Currently scraping: Neurological Disorders: How to Provide Care
# Processing... [250/1513]
# Currently scraping: Planning for Autonomous Vehicles: A People-Centred Approach
# Processing... [251/1513]
# Currently scraping: Professional Resilience: Building Skills to Thrive at Work
# Processing... [252/1513]
# Currently scraping: Safeguarding in Collaborative Research and International Development: Contexts, Challenges, and Opportunities
# Processing... [253/1513]
# Currently scraping: Self Care and Wellbeing: A Practical Guide for Health and Social Care
# Processing... [254/1513]
# Currently scraping: Smart Cities: Social Change Through Technology
# Processing... [255/1513]
# Currently scraping: String Music Appreciation
# Processing... [256/1513]
# Currently scraping: Sustainability and Biculturalism: Their Interrelationships and Impacts
# Processing... [257/1513]
# Currently scraping: Teaching English Online
# Processing... [258/1513]
# Currently scraping: Trastorno por déficit de atención con hiperactividad (TDAH)
# Processing... [259/1513]
# Currently scraping: Using Film to Teach Literacy Online and in the Classroom
# Processing... [260/1513]
# Currently scraping: Basic English 1: Elementary
# Processing... [261/1513]
# Currently scraping: Basic English 2: Pre-Intermediate
# Processing... [262/1513]
# Currently scraping: Behavioural Economics: Employee and Customer Behaviour
# Processing... [263/1513]
# Currently scraping: Blended Learning Essentials: Digitally-Enriched Apprenticeships
# Processing... [264/1513]
# Currently scraping: Climate Change and Resilience in Food Systems
# Processing... [265/1513]
# Currently scraping: Cognitive Psychology: Employee and Customer Behaviour
# Processing... [266/1513]
# Currently scraping: Demystifying Targeted Cancer Treatments
# Processing... [267/1513]
# Currently scraping: Digital Skills: Embracing Digital Technology
# Processing... [268/1513]
# Currently scraping: English for Healthcare
# Processing... [269/1513]
# Currently scraping: Entrepreneurship: From Business Idea to Action
# Processing... [270/1513]
# Currently scraping: Environmental Challenges: Justice in Natural Resource Management
# Processing... [271/1513]
# Currently scraping: Ethics in Engineering: Stories About Epic Engineering Fails
# Processing... [272/1513]
# Currently scraping: Exploring Possible Futures: Modeling in Environmental and Energy Economics
# Processing... [273/1513]
# Currently scraping: Food Safety and Nutrition: A Global Approach to Public Health
# Processing... [274/1513]
# Currently scraping: Forensic Psychology: Witness Investigation
# Processing... [275/1513]
# Currently scraping: Innovation Management: Winning in the Age of Disruption
# Processing... [276/1513]
# Currently scraping: Introduction to Applied Linguistics and TESOL
# Processing... [277/1513]
# Currently scraping: Introduction to Business Management
# Processing... [278/1513]
# Currently scraping: Introduction to Health Economics
# Processing... [279/1513]
# Currently scraping: Introduction to Nursing: The Role of Nurses Around the World
# Processing... [280/1513]
# Currently scraping: Introduction to Safeguarding in the International Aid Sector
# Processing... [281/1513]
# Currently scraping: Life Below Water: Conservation, Current Issues, Possible Solutions
# Processing... [282/1513]
# Currently scraping: Lights, Camera, Computer - Action! How Digital Technology is Transforming Film, TV, and Gaming
# Processing... [283/1513]
# Currently scraping: Motion Capture: The Art of Studying Human Activity
# Processing... [284/1513]
# Currently scraping: Music Moves: Why Does Music Make You Move?
# Processing... [285/1513]
# Currently scraping: Plagues, Pestilence and Pandemics: Are You Ready?
# Processing... [286/1513]
# Currently scraping: Preparing for University
# Processing... [287/1513]
# Currently scraping: Principles of Engineering
# Processing... [288/1513]
# Currently scraping: Radical Spirituality: the Early History of the Quakers
# Processing... [289/1513]
# Currently scraping: Robert Burns: Poems, Songs and Legacy
# Processing... [290/1513]
# Currently scraping: Samuel Johnson’s Rasselas: An Introduction
# Processing... [291/1513]
# Currently scraping: Social Psychology: Employee and Customer Behaviour
# Processing... [292/1513]
# Currently scraping: Understanding Autism
# Processing... [293/1513]
# Currently scraping: Understanding Human Behaviour: Introduction to Game Theory and Shared Resources
# Processing... [294/1513]
# Currently scraping: Additive Manufacturing in the Industry: Impact on Sustainability
# Processing... [295/1513]
# Currently scraping: Begin Robotics
# Processing... [296/1513]
# Currently scraping: Business Opportunities in Additive Manufacturing
# Processing... [297/1513]
# Currently scraping: Cancer in the 21st Century: The Genomic Revolution
# Processing... [298/1513]
# Currently scraping: Childhood Adversity: The Impact of Childhood Maltreatment on Mental Health
# Processing... [299/1513]
# Currently scraping: Complete Guide to Financial Planning for Your Business
# Processing... [300/1513]
# Currently scraping: Create a Robust Go to Market Strategy
# Processing... [301/1513]
# Currently scraping: Crushing your Competition: Competitive Strategies to Make your Business Stand Out
# Processing... [302/1513]
# Currently scraping: Digital Skills Awareness for Starting Higher Education
# Processing... [303/1513]
# Currently scraping: Drug Use and Harm Reduction
# Processing... [304/1513]
# Currently scraping: Food as Medicine
# Processing... [305/1513]
# Currently scraping: Genomic Medicine: Harnessing the Power of the Human Genome
# Processing... [306/1513]
# Currently scraping: How to Create a Profitable Pricing Strategy
# Processing... [307/1513]
# Currently scraping: How to Read a Novel
# Processing... [308/1513]
# Currently scraping: Introduction to Acting
# Processing... [309/1513]
# Currently scraping: Introduction to Thermodynamics
# Processing... [310/1513]
# Currently scraping: Jurisprudence: Introduction to the Philosophy of Law
# Processing... [311/1513]
# Currently scraping: Korea in a Global Context
# Processing... [312/1513]
# Currently scraping: Laser Powder Bed Fusion: Optimising LPBF Parameters
# Processing... [313/1513]
# Currently scraping: Maintaining a Mindful Life
# Processing... [314/1513]
# Currently scraping: Mindfulness for Wellbeing and Peak Performance
# Processing... [315/1513]
# Currently scraping: Nutrition and Wellbeing
# Processing... [316/1513]
# Currently scraping: Start Writing Fiction
# Processing... [317/1513]
# Currently scraping: The Monday Campaigns: Lessons in Public Health Promotion
# Processing... [318/1513]
# Currently scraping: The Science of Medicines
# Processing... [319/1513]
# Currently scraping: Understanding Genetic Disorders: How DNA Influences Health
# Processing... [320/1513]
# Currently scraping: University Preparation Course: Getting Ready for Success at University
# Processing... [321/1513]
# Currently scraping: A Nutritional Approach to Agriculture and Food Security
# Processing... [322/1513]
# Currently scraping: Communicative Planning for Urban Mobility
# Processing... [323/1513]
# Currently scraping: Compassion in Fashion: Sustainability and the Global Fur Trade
# Processing... [324/1513]
# Currently scraping: Contemporary Chinese I:  1.2
# Processing... [325/1513]
# Currently scraping: Contemporary Chinese I: 1.1
# Processing... [326/1513]
# Currently scraping: Creating Audio Description: Equality, Diversity, and Inclusion
# Processing... [327/1513]
# Currently scraping: Diagnostics for AMR: Building Back Better from the COVID-19 Pandemic
# Processing... [328/1513]
# Currently scraping: Football: More than a Game
# Processing... [329/1513]
# Currently scraping: Functional Programming in Haskell: Supercharge Your Coding
# Processing... [330/1513]
# Currently scraping: Interpreting Genomic Variation: Fundamental Principles
# Processing... [331/1513]
# Currently scraping: Interpreting Genomic Variation: Inherited Cancer Susceptibility
# Processing... [332/1513]
# Currently scraping: Introduction to Behavioural Activation for Depression
# Processing... [333/1513]
# Currently scraping: Social Entrepreneurship in Educational Technology: Concept Development and Prototyping
# Processing... [334/1513]
# Currently scraping: Social Entrepreneurship in Educational Technology: Developing a Business Plan
# Processing... [335/1513]
# Currently scraping: Social Entrepreneurship in Educational Technology: Ideation and Market Research
# Processing... [336/1513]
# Currently scraping: Sustainable Energy Access for Communities
# Processing... [337/1513]
# Currently scraping: Sustainable Transport and Shared Mobility
# Processing... [338/1513]
# Currently scraping: The Qur'an Between Judaism and Christianity
# Processing... [339/1513]
# Currently scraping: Understanding Anxiety, Depression and CBT
# Processing... [340/1513]
# Currently scraping: World Class Maths: Asian Teaching Methods
# Processing... [341/1513]
# Currently scraping: World Class Maths: Asian Teaching Practice
# Processing... [342/1513]
# Currently scraping: Animal Feed Production: Feed Quality
# Processing... [343/1513]
# Currently scraping: Animal Feed Production: Feed Safety
# Processing... [344/1513]
# Currently scraping: Circular Business Models for Sustainable Urban Food Systems
# Processing... [345/1513]
# Currently scraping: Consumer and Environmental Safety: Food Packaging and Kitchenware
# Processing... [346/1513]
# Currently scraping: Effective Fundraising and Leadership in Arts and Culture
# Processing... [347/1513]
# Currently scraping: Engaging with Controversies in the Food System
# Processing... [348/1513]
# Currently scraping: Explore How Farmers Produce Food Sustainably
# Processing... [349/1513]
# Currently scraping: Farm to Fork: Sustainable Food Production in a Changing Environment
# Processing... [350/1513]
# Currently scraping: Food and Nutrition: The Truth Behind Food Headlines
# Processing... [351/1513]
# Currently scraping: Food for Thought: The Relationship Between Food, Gut and Brain
# Processing... [352/1513]
# Currently scraping: From Waste to Value: How to Tackle Food Waste
# Processing... [353/1513]
# Currently scraping: How Computers Work: Demystifying Computation
# Processing... [354/1513]
# Currently scraping: How Food is Made. Understanding Food Processing Technologies
# Processing... [355/1513]
# Currently scraping: Improving Food Production with Agricultural Technology and Plant Biotechnology
# Processing... [356/1513]
# Currently scraping: Innovation in Arable Farming: Technologies for Sustainable Farming Systems
# Processing... [357/1513]
# Currently scraping: Intellectual Property Management in the Food Sector: Safeguarding Your Trademarks in the Global Marketplace
# Processing... [358/1513]
# Currently scraping: Introduction to Cybersecurity for Teachers
# Processing... [359/1513]
# Currently scraping: Introduction to Databases and SQL
# Processing... [360/1513]
# Currently scraping: Introduction to Food Science
# Processing... [361/1513]
# Currently scraping: Introduction to Machine Learning and AI
# Processing... [362/1513]
# Currently scraping: Introduction to Web Development
# Processing... [363/1513]
# Currently scraping: Object-oriented Programming in Python: Create Your Own Adventure Game
# Processing... [364/1513]
# Currently scraping: Programming 103: Saving and Structuring Data
# Processing... [365/1513]
# Currently scraping: Revolutionising the Food Chain with Technology
# Processing... [366/1513]
# Currently scraping: Robotics With Raspberry Pi: Build and Program Your First Robot Buggy
# Processing... [367/1513]
# Currently scraping: Science Communication and Public Engagement
# Processing... [368/1513]
# Currently scraping: Start a CoderDojo Club
# Processing... [369/1513]
# Currently scraping: Superfoods: Myths and Truths
# Processing... [370/1513]
# Currently scraping: Supporting People with Health Conditions Into Work: Individual Placement and Support (IPS)
# Processing... [371/1513]
# Currently scraping: Teaching Computing Systems and Networks to 5- to 11-year-olds
# Processing... [372/1513]
# Currently scraping: Teaching Programming to 5- to 11-year-olds
# Processing... [373/1513]
# Currently scraping: The Human Microbiome
# Processing... [374/1513]
# Currently scraping: Understanding Food Labels
# Processing... [375/1513]
# Currently scraping: Understanding Food Supply Chains in a Time of Crisis
# Processing... [376/1513]
# Currently scraping: Understanding Mediterranean and Okinawa Diets
# Processing... [377/1513]
# Currently scraping: Accounting With Xero: A Beginner’s Guide
# Processing... [378/1513]
# Currently scraping: Bringing Urban Nature Into the Cities of Tomorrow
# Processing... [379/1513]
# Currently scraping: Chinese Medicine: Treatise on Febrile Diseases Caused by Cold (Shang Han Lun)
# Processing... [380/1513]
# Currently scraping: City Liveability: The Intersections of Place, Mobility, and Health
# Processing... [381/1513]
# Currently scraping: Creating Ethical and Sustainable Cities at the Local Level
# Processing... [382/1513]
# Currently scraping: Cyber Crime Investigation
# Processing... [383/1513]
# Currently scraping: Cyber Security Incident Response for Managers
# Processing... [384/1513]
# Currently scraping: How to Plan a Hackathon: Hacking the Challenges of Digital Education
# Processing... [385/1513]
# Currently scraping: Ideation: The First Step in Engineering Design
# Processing... [386/1513]
# Currently scraping: Innovation in EdTech: Hacking the Challenges of Digital Education
# Processing... [387/1513]
# Currently scraping: Intermediate French: Discovering Worlds of French
# Processing... [388/1513]
# Currently scraping: Intermediate French: People and Places
# Processing... [389/1513]
# Currently scraping: Intermediate French: Traditions and Celebrations
# Processing... [390/1513]
# Currently scraping: Introduction to Digital Forensics: Malware Analysis and Investigations
# Processing... [391/1513]
# Currently scraping: Managing COVID-19 in Primary Care
# Processing... [392/1513]
# Currently scraping: Practical: Cyber Investigator
# Processing... [393/1513]
# Currently scraping: Practical: Malware Analysis and Investigations
# Processing... [394/1513]
# Currently scraping: Research Methods: A Practical Guide to Peer and Community Research
# Processing... [395/1513]
# Currently scraping: Supporting Individuals with Health Conditions Into Work: The Role of the Clinical Team
# Processing... [396/1513]
# Currently scraping: Transforming Citizen Participation
# Processing... [397/1513]
# Currently scraping: Understanding Brain Health: Preventing Dementia
# Processing... [398/1513]
# Currently scraping: Writing and Editing: Drafting
# Processing... [399/1513]
# Currently scraping: Writing and Editing: Revising
# Processing... [400/1513]
# Currently scraping: Writing and Editing: Structure and Organisation
# Processing... [401/1513]
# Currently scraping: Writing and Editing: Word Choice and Word Order
# Processing... [402/1513]
# Currently scraping: Database Architecture, Scale, and NoSQL with Elasticsearch
# Processing... [403/1513]
# Currently scraping: GPU Programming for Scientific Computing and Beyond
# Processing... [404/1513]
# Currently scraping: JSON and Natural Language Processing in PostgreSQL
# Processing... [405/1513]
# Currently scraping: Microsoft Future Ready: Azure Cloud Fundamentals
# Processing... [406/1513]
# Currently scraping: Mini Medical School: Hot Topics in Medical Science
# Processing... [407/1513]
# Currently scraping: Research Methods in Psychology: Using Animal Models to Understand Human Behaviour
# Processing... [408/1513]
# Currently scraping: Assessment of the Newborn
# Processing... [409/1513]
# Currently scraping: Brand Strategy and Communication
# Processing... [410/1513]
# Currently scraping: Climate Solutions: India
# Processing... [411/1513]
# Currently scraping: Creating Strategies for Influencer Marketing
# Processing... [412/1513]
# Currently scraping: Creative Communication Beyond VR and AR
# Processing... [413/1513]
# Currently scraping: Database Design and Basic SQL in PostgreSQL
# Processing... [414/1513]
# Currently scraping: Dead Interesting: Uncovering Roman Britain in Old Museum Collections
# Processing... [415/1513]
# Currently scraping: Digital Playground: Where Luxury Fashion is Finding its Sense of Humour
# Processing... [416/1513]
# Currently scraping: Enabling Community-Based Leadership in Design: Sustainable Development of Historic Faith Buildings
# Processing... [417/1513]
# Currently scraping: Fashion and Gaming: How Luxury Fashion Brands Use Gamification
# Processing... [418/1513]
# Currently scraping: Future-proofing the Health Workforce
# Processing... [419/1513]
# Currently scraping: Get Started Teaching Computing in Primary Schools: Preparing to teach 5 - 11 year olds
# Processing... [420/1513]
# Currently scraping: Intermediate PostgreSQL
# Processing... [421/1513]
# Currently scraping: Intermediate Spanish: Places and Travel
# Processing... [422/1513]
# Currently scraping: Intermediate Spanish: Spanish for Education and Work
# Processing... [423/1513]
# Currently scraping: Intermediate Spanish: The Worlds of Spanish
# Processing... [424/1513]
# Currently scraping: Maternity Care: Building Relationships Really Does Save Lives
# Processing... [425/1513]
# Currently scraping: Networking with Python: Socket Programming for Communication
# Processing... [426/1513]
# Currently scraping: Placemaking and Public Space Design: Unlocking Place Potential
# Processing... [427/1513]
# Currently scraping: Programming 102: Think Like a Computer Scientist
# Processing... [428/1513]
# Currently scraping: Programming Pedagogy in Secondary Schools: Inspiring Computing Teaching
# Processing... [429/1513]
# Currently scraping: Scratch to Python: Moving from Block- to Text-based Programming
# Processing... [430/1513]
# Currently scraping: Strategic Design for Social Media
# Processing... [431/1513]
# Currently scraping: Sustainable Cities: Governing Urban Adaptation Under Climate Change
# Processing... [432/1513]
# Currently scraping: Teach Computing in Schools: Creating a Curriculum for Ages 11 to 16
# Processing... [433/1513]
# Currently scraping: Teaching Physical Computing to 5- to 11-year-olds
# Processing... [434/1513]
# Currently scraping: Creating Meaningful and Inclusive Museum Practices
# Processing... [435/1513]
# Currently scraping: Creating and Measuring Success in eCommerce
# Processing... [436/1513]
# Currently scraping: Cultivating Diversity through Research and Insights
# Processing... [437/1513]
# Currently scraping: Cultural Appropriation vs Cultural Appreciation
# Processing... [438/1513]
# Currently scraping: Fashion Values: Economy
# Processing... [439/1513]
# Currently scraping: Fashion and the Climate Crisis: An Introduction to Sustainability
# Processing... [440/1513]
# Currently scraping: Groupthink: Understanding the Need for a Diverse Workplace
# Processing... [441/1513]
# Currently scraping: Grow and Scale Your eCommerce Business
# Processing... [442/1513]
# Currently scraping: How Artificial Intelligence Can Support Healthcare
# Processing... [443/1513]
# Currently scraping: How to Get Started in eCommerce
# Processing... [444/1513]
# Currently scraping: Improving Your Image: Dental Photography in Practice
# Processing... [445/1513]
# Currently scraping: Improving Your Study Techniques
# Processing... [446/1513]
# Currently scraping: Instructional Design: Course Development
# Processing... [447/1513]
# Currently scraping: Instructional Design: Course Planning and Pedagogy
# Processing... [448/1513]
# Currently scraping: Instructional Design: Educational Media
# Processing... [449/1513]
# Currently scraping: Instructional Design: Facilitation Skills
# Processing... [450/1513]
# Currently scraping: Intermediate Python
# Processing... [451/1513]
# Currently scraping: Mathematics for Computer Science: Essential Skills
# Processing... [452/1513]
# Currently scraping: Music Psychology: Why Does "Bohemian Rhapsody" Feel so Good?
# Processing... [453/1513]
# Currently scraping: People, Networks and Neighbours: Understanding Social Dynamics
# Processing... [454/1513]
# Currently scraping: Quality Improvement in Healthcare: the Case for Change
# Processing... [455/1513]
# Currently scraping: Research and Prepare: Understand eCommerce Customers, Products, and Propositions
# Processing... [456/1513]
# Currently scraping: The Scientific Revolution: Understanding the Roots of Modern Science
# Processing... [457/1513]
# Currently scraping: Anarchy in the UK: A History of Punk from 1976-78
# Processing... [458/1513]
# Currently scraping: Championing Change: Human Rights and the Climate Crisis
# Processing... [459/1513]
# Currently scraping: Safeguarding Adults: Level 3 Training
# Processing... [460/1513]
# Currently scraping: TESOL Strategies: Supporting ESL Students in Mainstream Classrooms
# Processing... [461/1513]
# Currently scraping: The Museum as a Site and Source for Learning
# Processing... [462/1513]
# Currently scraping: Beyond the Sustainable Development Goals (SDGs): Addressing Sustainability and Development
# Processing... [463/1513]
# Currently scraping: Irish 101:  An Introduction to Irish Language and Culture
# Processing... [464/1513]
# Currently scraping: Loss of a Baby in Multiple Pregnancy: Supporting Grieving Parents
# Processing... [465/1513]
# Currently scraping: Practise your PTE Academic Speaking Skills
# Processing... [466/1513]
# Currently scraping: Retinopathy of Prematurity: Practical Approaches to Prevent Blindness
# Processing... [467/1513]
# Currently scraping: Rome: A Virtual Tour of the Ancient City
# Processing... [468/1513]
# Currently scraping: Women in Arts: From 1900 until today
# Processing... [469/1513]
# Currently scraping: From World War to White Heat: the RAF in the Cold War
# Processing... [470/1513]
# Currently scraping: Promoting Democracy in the Classroom: A Practical Guide for Teachers
# Processing... [471/1513]
# Currently scraping: Renewable Energy: Achieving Sustainability through Bioenergy
# Processing... [472/1513]
# Currently scraping: Service Science and Sustainability
# Processing... [473/1513]
# Currently scraping: A Beginner's Guide to Environmental Science: Wicked Problems and Possible Solutions
# Processing... [474/1513]
# Currently scraping: A Survey of Substance Use Disorder
# Processing... [475/1513]
# Currently scraping: Addressing Postnatal Depression as a Healthcare Professional
# Processing... [476/1513]
# Currently scraping: Allergies: When the Immune System Backfires
# Processing... [477/1513]
# Currently scraping: An Introduction to Computer Networking for Teachers
# Processing... [478/1513]
# Currently scraping: An Introduction to Innovation in Healthcare
# Processing... [479/1513]
# Currently scraping: Brand Identity: How Branding Works and Building Your Personal Brand
# Processing... [480/1513]
# Currently scraping: Brand Personality: How to Tell Your Story with Authenticity and Relevance
# Processing... [481/1513]
# Currently scraping: Brand Purpose: Marketing Yourself and Building Meaningful Connections
# Processing... [482/1513]
# Currently scraping: Design and Prototype Embedded Computer Systems
# Processing... [483/1513]
# Currently scraping: Designing for a Diverse and Inclusive Future
# Processing... [484/1513]
# Currently scraping: EduWeight:  Weight Management for Adult Patients with Chronic Disease
# Processing... [485/1513]
# Currently scraping: Enlightening the Dark Ages: Early Medieval Archaeology in Italy
# Processing... [486/1513]
# Currently scraping: Ethical Practices to Guide Innovation
# Processing... [487/1513]
# Currently scraping: Exploring English: Shakespeare
# Processing... [488/1513]
# Currently scraping: Global Shocks: How to Manage Change in the Global Business Environment
# Processing... [489/1513]
# Currently scraping: Impact of Technology: How To Lead Classroom Discussions
# Processing... [490/1513]
# Currently scraping: Intermediate Korean: Exploring the Language and Culture of Korea
# Processing... [491/1513]
# Currently scraping: Introduction to Data Science for Business
# Processing... [492/1513]
# Currently scraping: Introduction to Frisian
# Processing... [493/1513]
# Currently scraping: Introduction to Programming with Python
# Processing... [494/1513]
# Currently scraping: Learning for a Sustainable Future: Live at COP26
# Processing... [495/1513]
# Currently scraping: Ocean Science in Action: Addressing Marine Ecosystems and Food Security
# Processing... [496/1513]
# Currently scraping: Programming 101: An Introduction to Python for Educators
# Processing... [497/1513]
# Currently scraping: Programming Pedagogy in Primary Schools: Developing Computing Teaching
# Processing... [498/1513]
# Currently scraping: Programming with GUIs
# Processing... [499/1513]
# Currently scraping: Public Health Incidents Involving Lead
# Processing... [500/1513]
# Currently scraping: Real Climate Action: How to Engage People in Climate Change
# Processing... [501/1513]
# Currently scraping: Successful Agile for Digital Teams
# Processing... [502/1513]
# Currently scraping: Sustainability Through Film
# Processing... [503/1513]
# Currently scraping: Teaching Data and Information to 5- to 11-year-olds
# Processing... [504/1513]
# Currently scraping: Teaching Young Learners Online
# Processing... [505/1513]
# Currently scraping: The Neurobiology of Addiction
# Processing... [506/1513]
# Currently scraping: Understanding ADHD: Current Research and Practice
# Processing... [507/1513]
# Currently scraping: Understanding Computer Systems
# Processing... [508/1513]
# Currently scraping: Understanding Maths and Logic in Computer Science
# Processing... [509/1513]
# Currently scraping: Understanding the Impact of Stigma on Addiction Treatment
# Processing... [510/1513]
# Currently scraping: Working with Patients with Limited Health Literacy
# Processing... [511/1513]
# Currently scraping: An Introduction to Artificial Intelligence in the Tourism Industry
# Processing... [512/1513]
# Currently scraping: An Introduction to Leading with Kindness and Compassion in Health and Social Care
# Processing... [513/1513]
# ...
# Processing... [1342/1513]
# Currently scraping: High Stakes Leadership: Leading in Times of Crisis
# Processing... [1343/1513]
# Currently scraping: Many Faces: Understanding the Complexities of Chinese Culture
# Processing... [1344/1513]
# Currently scraping: Migration, Mobilities and Citizenship
# Processing... [1345/1513]
# Currently scraping: Preparing for Graduate Study in the US: A Course for International Students
# Processing... [1346/1513]
# Currently scraping: Prison Health: Managing Outbreaks of Tuberculosis in Prisons
# Processing... [1347/1513]
# Currently scraping: An Introduction to Japanese Subcultures
# Processing... [1348/1513]
# Currently scraping: Personalised Care: Peer Leadership Foundation - Step Two
# Processing... [1349/1513]
# Currently scraping: Testing Times in the Classroom: Challenges of 21st Century Education
# Processing... [1350/1513]
# Currently scraping: Understanding Gender Inequality
# Processing... [1351/1513]
# Currently scraping: Introduction to Breastfeeding for Medical Students
# Processing... [1352/1513]
# Currently scraping: Making Blended Education Work
# Processing... [1353/1513]
# Currently scraping: Maths Puzzles: Cryptarithms, Symbologies and Secret Codes
# Processing... [1354/1513]
# Currently scraping: Building Alliances in Global Health: From Global Institutions to Local Communities
# Processing... [1355/1513]
# Currently scraping: Logical and Critical Thinking
# Processing... [1356/1513]
# Currently scraping: Making Babies in the 21st Century
# Processing... [1357/1513]
# Currently scraping: Supporting Physical Development in Early Childhood
# Processing... [1358/1513]
# Currently scraping: Web Application Technologies and Django
# Processing... [1359/1513]
# Currently scraping: How to Write Your First Song
# Processing... [1360/1513]
# Currently scraping: Improving the Health of Women, Children and Adolescents: from Evidence to Action
# Processing... [1361/1513]
# Currently scraping: Making Successful Decisions through the Strategy, Law & Ethics Model
# Processing... [1362/1513]
# Currently scraping: Next Generation Biosecurity: Responding to 21st Century Biorisks
# Processing... [1363/1513]
# Currently scraping: Why Religion Matters: Religious Literacy, Culture and Diversity
# Processing... [1364/1513]
# Currently scraping: A Global History of Sex and Gender: Bodies and Power in the Modern World
# Processing... [1365/1513]
# Currently scraping: Ageing and The Brain: The Impact of Neurodegenerative Diseases
# Processing... [1366/1513]
# Currently scraping: Complete Guide To Link Building: Building High-Quality Backlinks for SEO
# Processing... [1367/1513]
# Currently scraping: Introducing Personal Lines Insurance
# Processing... [1368/1513]
# Currently scraping: Personalised Care: Peer Leadership Foundation - Step One
# Processing... [1369/1513]
# Currently scraping: Who Made My Clothes?
# Processing... [1370/1513]
# Currently scraping: Become a Better Presenter: Improve Your Public Speaking Skills
# Processing... [1371/1513]
# Currently scraping: Build a Startup from Scratch: the Venture Design Process
# Processing... [1372/1513]
# Currently scraping: Understanding and Teaching Evolution
# Processing... [1373/1513]
# Currently scraping: An Introduction to Recreational Math: Fun, Games, and Puzzles
# Processing... [1374/1513]
# Currently scraping: Disease Outbreaks in Low and Middle Income Countries
# Processing... [1375/1513]
# Currently scraping: History of Slavery in the British Caribbean
# Processing... [1376/1513]
# Currently scraping: Mapper: Navigating Digital Career Tools
# Processing... [1377/1513]
# Currently scraping: Mental Health in Construction
# Processing... [1378/1513]
# Currently scraping: Mouth Care Matters
# Processing... [1379/1513]
# Currently scraping: Beyond the Ballot: Women’s Rights and Suffrage from 1866 to Today
# Processing... [1380/1513]
# Currently scraping: Education Research that Matters: Doing Research in Your Learning Community
# Processing... [1381/1513]
# Currently scraping: Genomic Medicine and Research: A Community Approach
# Processing... [1382/1513]
# Currently scraping: Global Ethics: An Introduction
# Processing... [1383/1513]
# Currently scraping: IUCN Red List of Ecosystems: The Global Standard for Assessing Risks to Ecosystems
# Processing... [1384/1513]
# Currently scraping: Identifying Food Fraud
# Processing... [1385/1513]
# Currently scraping: Integrated Healthcare for Children with Developmental Disabilities
# Processing... [1386/1513]
# Currently scraping: Introduction to Health Technology Assessment
# Processing... [1387/1513]
# Currently scraping: Medicine Administration for Carers
# Processing... [1388/1513]
# Currently scraping: Peterloo to the Pankhursts: Radicalism and Reform in the 19th Century
# Processing... [1389/1513]
# Currently scraping: Planning and Managing Global Health Programmes: Promoting Quality, Accountability, and Equity
# Processing... [1390/1513]
# Currently scraping: Pop Art
# Processing... [1391/1513]
# Currently scraping: Python in High Performance Computing
# Processing... [1392/1513]
# Currently scraping: Shakespeare: Context and Stagecraft
# Processing... [1393/1513]
# Currently scraping: The European Union: Crisis and Recovery
# Processing... [1394/1513]
# Currently scraping: The Path to Happiness and Good Quality of Life
# Processing... [1395/1513]
# Currently scraping: Journey to birth
# Processing... [1396/1513]
# Currently scraping: Professional Development for Early Career Teachers
# Processing... [1397/1513]
# Currently scraping: Social Innovation: Global Solutions for a Sustainable Future
# Processing... [1398/1513]
# Currently scraping: Technology Metals for a Green Future
# Processing... [1399/1513]
# Currently scraping: Upcycling: From Green Ideas to Starting a Business
# Processing... [1400/1513]
# Currently scraping: Forensic Facial Reconstruction: Finding Mr. X
# Processing... [1401/1513]
# Currently scraping: How to Get A Graduate Job
# Processing... [1402/1513]
# Currently scraping: How to Succeed in Your EPQ: the Nuts and Bolts of Completing Your Project
# Processing... [1403/1513]
# Currently scraping: Technical Report Writing for Engineers
# Processing... [1404/1513]
# Currently scraping: The Global Challenge of Vector Borne Diseases and How to Control Them
# Processing... [1405/1513]
# Currently scraping: A History of Public Health in Post-War Britain
# Processing... [1406/1513]
# Currently scraping: How to Succeed in Your Welsh Bacc: the Individual Project Essentials
# Processing... [1407/1513]
# Currently scraping: Innovative Leadership: Developing Curiosity
# Processing... [1408/1513]
# Currently scraping: Online Recruitment and Onboarding: Providing Continuity for Business and Candidates
# Processing... [1409/1513]
# Currently scraping: Sut i Lwyddo yn dy Fagloriaeth: Hanfodion y Prosiect Unigol
# Processing... [1410/1513]
# Currently scraping: The Role of Personal Assistants in Disability Support
# Processing... [1411/1513]
# Currently scraping: What is International Development?
# Processing... [1412/1513]
# Currently scraping: Building a Future with Robots
# Processing... [1413/1513]
# Currently scraping: Discover Dentistry
# Processing... [1414/1513]
# Currently scraping: Exploring Play: The Importance of Play in Everyday Life
# Processing... [1415/1513]
# Currently scraping: Health Technology Assessment: Choosing Which Treatments Get Funded
# Processing... [1416/1513]
# Currently scraping: Introduction to Data for Business Leaders
# Processing... [1417/1513]
# Currently scraping: It Starts with Your Heart: Understanding Heart and Circulatory Diseases
# Processing... [1418/1513]
# Currently scraping: Making Sense of Data in the Media
# Processing... [1419/1513]
# Currently scraping: Measuring and Valuing Health
# Processing... [1420/1513]
# Currently scraping: Population 10 Billion: Researching Global Issues
# Processing... [1421/1513]
# Currently scraping: Salary Negotiation for Women in the Workplace
# Processing... [1422/1513]
# Currently scraping: Social Enterprise: Business Doing Good
# Processing... [1423/1513]
# Currently scraping: Social Enterprise: Growing a Sustainable Business
# Processing... [1424/1513]
# Currently scraping: Social Enterprise: Turning Ideas into Action
# Processing... [1425/1513]
# Currently scraping: Social Innovation in South Korea
# Processing... [1426/1513]
# Currently scraping: The Musculoskeletal System: The Science of Staying Active into Old Age
# Processing... [1427/1513]
# Currently scraping: Sino-Japanese Interactions  Through Rare Books
# Processing... [1428/1513]
# Currently scraping: How to Become a Lawyer
# Processing... [1429/1513]
# Currently scraping: Introduction to Innovation and Technology in Legal Services
# Processing... [1430/1513]
# Currently scraping: The Laws of Digital Data, Content and Artificial Intelligence (AI)
# Processing... [1431/1513]
# Currently scraping: Global Health and Disability
# Processing... [1432/1513]
# Currently scraping: Sustainable Construction and Development
# Processing... [1433/1513]
# Currently scraping: Create Accessible Interfaces
# Processing... [1434/1513]
# Currently scraping: Getting Started with Your Raspberry Pi
# Processing... [1435/1513]
# Currently scraping: Archaeology and the Battle of Dunbar 1650: From the Scottish Battlefield to the New World
# Processing... [1436/1513]
# Currently scraping: Understanding Mental Health: Continuum, Culture and Social Media
# Processing... [1437/1513]
# Currently scraping: World War 1: Trauma, Memory, Controversy
# Processing... [1438/1513]
# Currently scraping: Construction Ethics and Compliance
# Processing... [1439/1513]
# Currently scraping: Lever des Fonds pour ma Startup
# Processing... [1440/1513]
# Currently scraping: Quality in Construction
# Processing... [1441/1513]
# Currently scraping: Raising Funds for Your Startup
# Processing... [1442/1513]
# Currently scraping: Soils: Introducing the World Beneath Our Feet
# Processing... [1443/1513]
# Currently scraping: The Tudors
# Processing... [1444/1513]
# Currently scraping: Apply Creative Machine Learning
# Processing... [1445/1513]
# Currently scraping: Create Expressive Videogames
# Processing... [1446/1513]
# Currently scraping: English Football: a Social History
# Processing... [1447/1513]
# Currently scraping: Impact Investing
# Processing... [1448/1513]
# Currently scraping: Improving Health Assessments for People with an Intellectual Disability
# Processing... [1449/1513]
# Currently scraping: Introduction to Korean Philosophy
# Processing... [1450/1513]
# Currently scraping: Introduction to Virtual, Augmented and Mixed Reality
# Processing... [1451/1513]
# Currently scraping: La Salud de la Mujeres en el Postparto
# Processing... [1452/1513]
# Currently scraping: Mergers and Acquisitions: Accounting Principles
# Processing... [1453/1513]
# Currently scraping: Modern Sculpture: An Introduction to Art History
# Processing... [1454/1513]
# Currently scraping: The Book of Kells: Exploring an Irish Medieval Masterpiece
# Processing... [1455/1513]
# Currently scraping: Why We Post: the Anthropology of Social Media
# Processing... [1456/1513]
# Currently scraping: Women’s Health After Motherhood
# Processing... [1457/1513]
# Currently scraping: Electrical Engineering: Sensing, Powering and Controlling
# Processing... [1458/1513]
# Currently scraping: Global Health, Conflict and Violence
# Processing... [1459/1513]
# Currently scraping: How to Learn Online: Getting Started
# Processing... [1460/1513]
# Currently scraping: Programming for Everybody: Python Data Structures
# Processing... [1461/1513]
# Currently scraping: COVID-19: Psychological First Aid
# Processing... [1462/1513]
# Currently scraping: Coaching in Education: Addressing the Need for Deep Communication
# Processing... [1463/1513]
# Currently scraping: Digital Transformation in the Classroom
# Processing... [1464/1513]
# Currently scraping: Discovering Your PhD Potential: Writing a Research Proposal
# Processing... [1465/1513]
# Currently scraping: Learning in the Network Age
# Processing... [1466/1513]
# Currently scraping: Supercomputing
# Processing... [1467/1513]
# Currently scraping: Becoming a Teacher
# Processing... [1468/1513]
# Currently scraping: Developing Your Research Project
# Processing... [1469/1513]
# Currently scraping: Mergers and Acquisitions: Free Cash Flow Modeling
# Processing... [1470/1513]
# Currently scraping: The Mind is Flat: The Shocking Shallowness of Human Psychology
# Processing... [1471/1513]
# Currently scraping: Anxiety in Children and Young People during COVID-19
# Processing... [1472/1513]
# Currently scraping: English for the Workplace
# Processing... [1473/1513]
# Currently scraping: Liver Disease: Looking after Your Liver
# Processing... [1474/1513]
# Currently scraping: Liver Transplant: the Ins and Outs
# Processing... [1475/1513]
# Currently scraping: Norwegian for Beginners 3
# Processing... [1476/1513]
# Currently scraping: Preserving Norwegian Stave Churches
# Processing... [1477/1513]
# Currently scraping: Introduction to Physical Computing
# Processing... [1478/1513]
# Currently scraping: Addressing Violence Through Patient Care
# Processing... [1479/1513]
# Currently scraping: COVID-19: Effective Nursing in Times of Crisis
# Processing... [1480/1513]
# Currently scraping: Mergers and Acquisitions: Structuring the Deal
# Processing... [1481/1513]
# Currently scraping: Understanding Data in the Tourism Industry
# Processing... [1482/1513]
# Currently scraping: Education Research That Matters: Ways of Researching
# Processing... [1483/1513]
# Currently scraping: Education Research that Matters: Applying Research to Your Teaching Practice
# Processing... [1484/1513]
# Currently scraping: Human Rights and International Criminal Law: An Introduction
# Processing... [1485/1513]
# Currently scraping: Exercise Prescription for the Prevention and Treatment of Disease
# Processing... [1486/1513]
# Currently scraping: Fashion's Future: The Sustainable Development Goals
# Processing... [1487/1513]
# Currently scraping: Project Management Principles, Practices and Systems
# Processing... [1488/1513]
# Currently scraping: Shakespeare: Print and Performance
# Processing... [1489/1513]
# Currently scraping: Challenging Wealth and Income Inequality
# Processing... [1490/1513]
# Currently scraping: Design a Feminist Chatbot
# Processing... [1491/1513]
# Currently scraping: Health and Wellbeing in the Ancient World
# Processing... [1492/1513]
# Currently scraping: How To Start Your Career In Games Development
# Processing... [1493/1513]
# Currently scraping: Mergers and Acquisitions: Advanced Theory
# Processing... [1494/1513]
# Currently scraping: Norwegian for Beginners 2
# Processing... [1495/1513]
# Currently scraping: The History of the Book in the Early Modern Period: 1450 to 1800
# Processing... [1496/1513]
# Currently scraping: Understanding Modern Business and Organisations
# Processing... [1497/1513]
# Currently scraping: Why Biology Matters: The Genome and You
# Processing... [1498/1513]
# Currently scraping: Understanding Quantum Computers
# Processing... [1499/1513]
# Currently scraping: Exploring Japanese Avant-garde Art Through Butoh Dance
# Processing... [1500/1513]
# Currently scraping: Gender Representation in the Media
# Processing... [1501/1513]
# Currently scraping: Introduction to Humanitarian Logistics
# Processing... [1502/1513]
# Currently scraping: The Korean Alphabet: An Introduction to Hangeul
# Processing... [1503/1513]
# Currently scraping: Mergers and Acquisitions: Concepts and Theories
# Processing... [1504/1513]
# Currently scraping: Social Innovation in Rural Areas
# Processing... [1505/1513]
# Currently scraping: Care Home Nursing: Changing Perceptions
# Processing... [1506/1513]
# Currently scraping: So You Want to Study Life Science?
# Processing... [1507/1513]
# Currently scraping: Norwegian for Beginners 1
# Processing... [1508/1513]
# Currently scraping: From Notation to Performance: Understanding Musical Scores
# Processing... [1509/1513]
# Currently scraping: Introduction to Financial Accounting
# Processing... [1510/1513]
# Currently scraping: Introduction to the Travel & Tourism Industry: Passport to the World
# Processing... [1511/1513]
# Currently scraping: Aging Populations: Lessons In Healthy Aging From Japan
# Processing... [1512/1513]
# Currently scraping: Japanese Culture Through Rare Books
# Processing... [1513/1513]
# Courses it couldn't access: []
# Couldn't access 0 courses
# Time it took to scrape: 0:47:30.216982
